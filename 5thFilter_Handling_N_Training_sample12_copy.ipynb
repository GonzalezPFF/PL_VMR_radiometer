# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0'
input_pkl_path_v1 = os.path.join(data_dir, 'input_nn_ver1.pkl')
#input_pkl_path_v2 = os.path.join(data_dir, 'input_nn_ver2.pkl')

# %%
df = pd.read_pickle(input_pkl_path_v1)
#df = pd.read_pickle(input_pkl_path_v2)

# %% [markdown]
# **------------------NOISE ADDING----------------------**

# %%
def add_noise(tsky, trx=75.0, snr=1000.0):
    tsys = trx + tsky
    tnoise = tsys / snr
    tcal = tsky + tnoise * np.random.standard_normal(tsky.shape)
    return tcal

# %%
original_spectrum = np.array(df['SPECTRA_Tb[K]'].iloc[0])

# %%
frequencies = np.linspace(20.0, 26.0, len(original_spectrum))

# %%
noisy_spectrum = add_noise(original_spectrum)

# %%
df['SPECTRA_Tb[K]_NOISY'] = df['SPECTRA_Tb[K]'].apply(lambda spec: add_noise(np.array(spec)))

# %% [markdown]
# **TRANING WAY 1: USING DIFFERENT COLUMNS BETWEEN PL AND H2O**

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['SPECTRA_Tb[K]_NOISY'].tolist())
PL = np.array(df['PL[mbar]'].tolist())
H2O = np.array(df['H2O[vmr]'].tolist())
Y = np.concatenate([H2O, PL], axis=1)

# %%
print(H2O.shape, PL.shape)
# Out:
# (21024, 67) (21024, 67)

# %%
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.4, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)

# %%
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **SECOND FRAMEWORK TORCH**

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **-NORMALIZATION-**

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_val_scaled = scaler.transform(X_val)
#X_test_scaled = scaler.transform(X_test)
X_train = scaler_x.fit_transform(X_train)
X_val = scaler_x.transform(X_val)
X_test = scaler_x.transform(X_test)

# %%
scaler_y = StandardScaler()
Y_train = scaler_y.fit_transform(Y_train)
Y_val   = scaler_y.transform(Y_val)
Y_test  = scaler_y.transform(Y_test)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **-----------------------**

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
Y_val   = torch.tensor(Y_val, dtype=torch.float32)
X_test  = torch.tensor(X_test, dtype=torch.float32)
Y_test  = torch.tensor(Y_test, dtype=torch.float32)

# %%
batch_size = 64

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds  = TensorDataset(X_test, Y_test)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
class PedroSplitMLP(nn.Module):
    def __init__(self):
        super(PedroSplitMLP, self).__init__()
        self.shared_fc1 = nn.Linear(12001, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.shared_fc2 = nn.Linear(1024, 512)
        self.dropout2 = nn.Dropout(p=0.2)
        self.shared_fc3 = nn.Linear(512, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.shared_fc4 = nn.Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)

        # Separate heads
        self.h2o_head = nn.Linear(128, 67)
        self.pl_head = nn.Linear(128, 67)

    def forward(self, x):
        x = torch.relu(self.shared_fc1(x))
        x = self.dropout1(x)
        x = torch.relu(self.shared_fc2(x))
        x = self.dropout2(x)
        x = torch.relu(self.shared_fc3(x))
        x = self.dropout3(x)
        x = torch.relu(self.shared_fc4(x))
        x = self.dropout4(x)

        h2o_out = self.h2o_head(x)
        pl_out = self.pl_head(x)
        return h2o_out, pl_out

model = PedroSplitMLP()

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super(WeightedMSELoss, self).__init__()
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def forward(self, pred, target):
        diff = pred - target
        weighted_diff = diff * self.weights
        loss = torch.mean(weighted_diff ** 2)
        return loss

def smoothness_penalty(h2o_pred, alpha=0.0):
    diff = h2o_pred[:, 1:] - h2o_pred[:, :-1]
    return alpha * torch.mean(diff ** 2)

# Construct weights to emphasize lower pressures (higher in atmosphere)
n_levels = 67
pl_weights = np.linspace(1.0, 0.5, n_levels)      # Normal weights for PL
h2o_weights = np.logspace(np.log10(2.0), np.log10(0.8), n_levels)     # Emphasize high-altitude H2O, modified for higher-pressure performance

pl_weights_tensor = torch.tensor(pl_weights, dtype=torch.float32)
h2o_weights_tensor = torch.tensor(h2o_weights, dtype=torch.float32)

combined_weights = np.concatenate([pl_weights, h2o_weights])
criterion_h2o = WeightedMSELoss(weights=h2o_weights_tensor)
criterion_pl  = WeightedMSELoss(weights=pl_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
# Out:
# /tmp/ipython-input-25-2473438858.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.weights = torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, loader, val_loader, criterion_h2o, criterion_pl, optimizer, epochs, save_path, alpha, lambda_h2o):
    train_losses, val_losses = [], []
    val_mae_list, val_rmse_list = [], []

    best_val_loss = float('inf')
    patience = 20
    counter = 0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        for xb, yb in loader:
            optimizer.zero_grad()

            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            loss_h2o = criterion_h2o(h2o_pred, h2o_target)
            loss_pl = criterion_pl(pl_pred, pl_target)
            smooth_loss = smoothness_penalty(h2o_pred, alpha=alpha)

            loss = lambda_h2o * loss_h2o + loss_pl + smooth_loss
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(loader))

        # VALIDATION
        model.eval()
        val_loss_total = 0
        y_true_h2o, y_pred_h2o = [], []
        y_true_pl, y_pred_pl = [], []

        with torch.no_grad():
            for xb, yb in val_loader:
                h2o_pred, pl_pred = model(xb)
                h2o_target = yb[:, :n_levels]
                pl_target = yb[:, n_levels:]

                loss_h2o_val = criterion_h2o(h2o_pred, h2o_target)
                loss_pl_val = criterion_pl(pl_pred, pl_target)
                smooth_loss_val = smoothness_penalty(h2o_pred, alpha=alpha)

                batch_val_loss = lambda_h2o * loss_h2o_val + loss_pl_val + smooth_loss_val
                val_loss_total += batch_val_loss.item()

                y_true_h2o.append(h2o_target.cpu().numpy())
                y_pred_h2o.append(h2o_pred.cpu().numpy())

                y_true_pl.append(pl_target.cpu().numpy())
                y_pred_pl.append(pl_pred.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_losses.append(val_loss)

        y_true_h2o = np.concatenate(y_true_h2o, axis=0)
        y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

        y_true_pl = np.concatenate(y_true_pl, axis=0)
        y_pred_pl = np.concatenate(y_pred_pl, axis=0)

        # METRICS
        val_mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
        val_rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

        val_mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
        val_rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

        val_mae_list.append((val_mae_h2o, val_mae_pl))
        val_rmse_list.append((val_rmse_h2o, val_rmse_pl))

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        # EARLY STOPPING
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), save_path)
            counter = 0
            print(f"✅ Model improved and saved (val_loss = {best_val_loss:.4f})")
        else:
            counter += 1
            if counter >= patience:
                print(f"⛔ Early stopping at epoch {epoch+1}")
                break

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f} | "
              f"MAE H2O: {val_mae_h2o:.4f} | RMSE H2O: {val_rmse_h2o:.4f} | "
              f"MAE PL: {val_mae_pl:.4f} | RMSE PL: {val_rmse_pl:.4f} | LR: {current_lr:.1e}")

    model.load_state_dict(torch.load(save_path))
    return train_losses, val_losses, val_mae_list, val_rmse_list

# %%
def evaluate(model, loader):
    model.eval()
    y_true_h2o, y_pred_h2o = [], []
    y_true_pl, y_pred_pl = [], []

    with torch.no_grad():
        for xb, yb in loader:
            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            y_true_h2o.append(h2o_target.cpu().numpy())
            y_pred_h2o.append(h2o_pred.cpu().numpy())

            y_true_pl.append(pl_target.cpu().numpy())
            y_pred_pl.append(pl_pred.cpu().numpy())

    y_true_h2o = np.concatenate(y_true_h2o, axis=0)
    y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

    y_true_pl = np.concatenate(y_true_pl, axis=0)
    y_pred_pl = np.concatenate(y_pred_pl, axis=0)

    return (y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl)

# %%
save_path = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model12.pth'

# %%
epochs = 100
alpha = 1.0  # Regularization strength for smoothness penalty
lambda_h2o=0.3
train_losses, val_losses, val_mae, val_rmse = train(
    model,
    train_loader,
    val_loader,
    criterion_h2o,
    criterion_pl,
    optimizer,
    epochs,
    save_path=save_path,
    alpha=alpha,
    lambda_h2o=lambda_h2o
)
# Out:
# ✅ Model improved and saved (val_loss = 0.6812)
# Epoch 1/100 | Train Loss: 0.7873 | Val Loss: 0.6812 | MAE H2O: 0.5449 | RMSE H2O: 0.7084 | MAE PL: 0.4092 | RMSE PL: 0.8228 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.6807)
# Epoch 2/100 | Train Loss: 0.7041 | Val Loss: 0.6807 | MAE H2O: 0.5632 | RMSE H2O: 0.7277 | MAE PL: 0.3990 | RMSE PL: 0.8172 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.6585)
# Epoch 3/100 | Train Loss: 0.6820 | Val Loss: 0.6585 | MAE H2O: 0.5389 | RMSE H2O: 0.7075 | MAE PL: 0.3701 | RMSE PL: 0.8083 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5759)
# Epoch 4/100 | Train Loss: 0.6471 | Val Loss: 0.5759 | MAE H2O: 0.5219 | RMSE H2O: 0.7019 | MAE PL: 0.2992 | RMSE PL: 0.6613 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5661)
# Epoch 5/100 | Train Loss: 0.5913 | Val Loss: 0.5661 | MAE H2O: 0.4699 | RMSE H2O: 0.6531 | MAE PL: 0.3166 | RMSE PL: 0.7272 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5043)
# Epoch 6/100 | Train Loss: 0.5641 | Val Loss: 0.5043 | MAE H2O: 0.4473 | RMSE H2O: 0.6251 | MAE PL: 0.2654 | RMSE PL: 0.6529 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4921)
# Epoch 7/100 | Train Loss: 0.5528 | Val Loss: 0.4921 | MAE H2O: 0.4413 | RMSE H2O: 0.6234 | MAE PL: 0.2539 | RMSE PL: 0.6270 | LR: 5.0e-04
# Epoch 8/100 | Train Loss: 0.5384 | Val Loss: 0.5012 | MAE H2O: 0.4625 | RMSE H2O: 0.6516 | MAE PL: 0.2470 | RMSE PL: 0.6054 | LR: 5.0e-04
# Epoch 9/100 | Train Loss: 0.5298 | Val Loss: 0.4928 | MAE H2O: 0.4468 | RMSE H2O: 0.6299 | MAE PL: 0.2731 | RMSE PL: 0.6361 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4913)
# Epoch 10/100 | Train Loss: 0.5190 | Val Loss: 0.4913 | MAE H2O: 0.4569 | RMSE H2O: 0.6383 | MAE PL: 0.2382 | RMSE PL: 0.6005 | LR: 5.0e-04
# Epoch 11/100 | Train Loss: 0.5110 | Val Loss: 0.5279 | MAE H2O: 0.4752 | RMSE H2O: 0.6622 | MAE PL: 0.2533 | RMSE PL: 0.6294 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4866)
# Epoch 12/100 | Train Loss: 0.5121 | Val Loss: 0.4866 | MAE H2O: 0.4355 | RMSE H2O: 0.6160 | MAE PL: 0.2580 | RMSE PL: 0.6324 | LR: 5.0e-04
# Epoch 13/100 | Train Loss: 0.5058 | Val Loss: 0.5041 | MAE H2O: 0.4415 | RMSE H2O: 0.6270 | MAE PL: 0.2638 | RMSE PL: 0.6392 | LR: 5.0e-04
# Epoch 14/100 | Train Loss: 0.5034 | Val Loss: 0.5058 | MAE H2O: 0.4595 | RMSE H2O: 0.6420 | MAE PL: 0.2552 | RMSE PL: 0.6320 | LR: 5.0e-04
# Epoch 15/100 | Train Loss: 0.5017 | Val Loss: 0.5142 | MAE H2O: 0.4566 | RMSE H2O: 0.6450 | MAE PL: 0.2559 | RMSE PL: 0.6340 | LR: 5.0e-04
# Epoch 16/100 | Train Loss: 0.5074 | Val Loss: 0.4977 | MAE H2O: 0.4356 | RMSE H2O: 0.6253 | MAE PL: 0.2563 | RMSE PL: 0.6377 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4731)
# Epoch 17/100 | Train Loss: 0.5015 | Val Loss: 0.4731 | MAE H2O: 0.4340 | RMSE H2O: 0.6234 | MAE PL: 0.2391 | RMSE PL: 0.5882 | LR: 5.0e-04
# Epoch 18/100 | Train Loss: 0.4998 | Val Loss: 0.5070 | MAE H2O: 0.4478 | RMSE H2O: 0.6346 | MAE PL: 0.2636 | RMSE PL: 0.6427 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4516)
# Epoch 19/100 | Train Loss: 0.5005 | Val Loss: 0.4516 | MAE H2O: 0.4388 | RMSE H2O: 0.6201 | MAE PL: 0.2397 | RMSE PL: 0.5668 | LR: 5.0e-04
# Epoch 20/100 | Train Loss: 0.4982 | Val Loss: 0.4933 | MAE H2O: 0.4404 | RMSE H2O: 0.6302 | MAE PL: 0.2367 | RMSE PL: 0.6028 | LR: 5.0e-04
# Epoch 21/100 | Train Loss: 0.4986 | Val Loss: 0.4578 | MAE H2O: 0.4244 | RMSE H2O: 0.6040 | MAE PL: 0.2480 | RMSE PL: 0.5936 | LR: 5.0e-04
# Epoch 22/100 | Train Loss: 0.5031 | Val Loss: 0.5285 | MAE H2O: 0.4378 | RMSE H2O: 0.6240 | MAE PL: 0.2727 | RMSE PL: 0.6865 | LR: 5.0e-04
# Epoch 23/100 | Train Loss: 0.4925 | Val Loss: 0.4711 | MAE H2O: 0.4259 | RMSE H2O: 0.6055 | MAE PL: 0.2549 | RMSE PL: 0.6128 | LR: 5.0e-04
# Epoch 24/100 | Train Loss: 0.4953 | Val Loss: 0.5263 | MAE H2O: 0.4519 | RMSE H2O: 0.6371 | MAE PL: 0.2570 | RMSE PL: 0.6654 | LR: 2.5e-04
# Epoch 25/100 | Train Loss: 0.4809 | Val Loss: 0.4743 | MAE H2O: 0.4300 | RMSE H2O: 0.6178 | MAE PL: 0.2506 | RMSE PL: 0.6025 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4508)
# Epoch 26/100 | Train Loss: 0.4803 | Val Loss: 0.4508 | MAE H2O: 0.4280 | RMSE H2O: 0.6083 | MAE PL: 0.2365 | RMSE PL: 0.5768 | LR: 2.5e-04
# Epoch 27/100 | Train Loss: 0.4748 | Val Loss: 0.4533 | MAE H2O: 0.4189 | RMSE H2O: 0.6055 | MAE PL: 0.2420 | RMSE PL: 0.5893 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4395)
# Epoch 28/100 | Train Loss: 0.4728 | Val Loss: 0.4395 | MAE H2O: 0.4243 | RMSE H2O: 0.6084 | MAE PL: 0.2341 | RMSE PL: 0.5564 | LR: 2.5e-04
# Epoch 29/100 | Train Loss: 0.4761 | Val Loss: 0.5086 | MAE H2O: 0.4510 | RMSE H2O: 0.6402 | MAE PL: 0.2454 | RMSE PL: 0.6216 | LR: 2.5e-04
# Epoch 30/100 | Train Loss: 0.4698 | Val Loss: 0.4743 | MAE H2O: 0.4383 | RMSE H2O: 0.6261 | MAE PL: 0.2389 | RMSE PL: 0.5874 | LR: 2.5e-04
# Epoch 31/100 | Train Loss: 0.4745 | Val Loss: 0.5260 | MAE H2O: 0.4527 | RMSE H2O: 0.6461 | MAE PL: 0.2591 | RMSE PL: 0.6519 | LR: 2.5e-04
# Epoch 32/100 | Train Loss: 0.4759 | Val Loss: 0.5092 | MAE H2O: 0.4446 | RMSE H2O: 0.6334 | MAE PL: 0.2552 | RMSE PL: 0.6358 | LR: 2.5e-04
# Epoch 33/100 | Train Loss: 0.4672 | Val Loss: 0.4557 | MAE H2O: 0.4273 | RMSE H2O: 0.6106 | MAE PL: 0.2388 | RMSE PL: 0.5861 | LR: 1.3e-04
# Epoch 34/100 | Train Loss: 0.4655 | Val Loss: 0.4671 | MAE H2O: 0.4359 | RMSE H2O: 0.6202 | MAE PL: 0.2462 | RMSE PL: 0.6002 | LR: 1.3e-04
# Epoch 35/100 | Train Loss: 0.4644 | Val Loss: 0.4715 | MAE H2O: 0.4265 | RMSE H2O: 0.6126 | MAE PL: 0.2442 | RMSE PL: 0.6045 | LR: 1.3e-04
# Epoch 36/100 | Train Loss: 0.4643 | Val Loss: 0.4609 | MAE H2O: 0.4283 | RMSE H2O: 0.6128 | MAE PL: 0.2336 | RMSE PL: 0.5852 | LR: 1.3e-04
# Epoch 37/100 | Train Loss: 0.4904 | Val Loss: 0.4546 | MAE H2O: 0.4152 | RMSE H2O: 0.6003 | MAE PL: 0.2418 | RMSE PL: 0.5935 | LR: 1.3e-04
# Epoch 38/100 | Train Loss: 0.4639 | Val Loss: 0.4686 | MAE H2O: 0.4187 | RMSE H2O: 0.6018 | MAE PL: 0.2543 | RMSE PL: 0.6161 | LR: 6.3e-05
# Epoch 39/100 | Train Loss: 0.4544 | Val Loss: 0.4643 | MAE H2O: 0.4244 | RMSE H2O: 0.6097 | MAE PL: 0.2425 | RMSE PL: 0.5973 | LR: 6.3e-05
# Epoch 40/100 | Train Loss: 0.4561 | Val Loss: 0.4620 | MAE H2O: 0.4337 | RMSE H2O: 0.6181 | MAE PL: 0.2350 | RMSE PL: 0.5839 | LR: 6.3e-05
# Epoch 41/100 | Train Loss: 0.4538 | Val Loss: 0.4582 | MAE H2O: 0.4261 | RMSE H2O: 0.6104 | MAE PL: 0.2358 | RMSE PL: 0.5837 | LR: 6.3e-05
# Epoch 42/100 | Train Loss: 0.4517 | Val Loss: 0.4564 | MAE H2O: 0.4233 | RMSE H2O: 0.6051 | MAE PL: 0.2447 | RMSE PL: 0.5974 | LR: 6.3e-05
# Epoch 43/100 | Train Loss: 0.4526 | Val Loss: 0.4708 | MAE H2O: 0.4316 | RMSE H2O: 0.6167 | MAE PL: 0.2404 | RMSE PL: 0.5990 | LR: 3.1e-05
# Epoch 44/100 | Train Loss: 0.4519 | Val Loss: 0.4589 | MAE H2O: 0.4257 | RMSE H2O: 0.6096 | MAE PL: 0.2375 | RMSE PL: 0.5882 | LR: 3.1e-05
# Epoch 45/100 | Train Loss: 0.4494 | Val Loss: 0.4758 | MAE H2O: 0.4329 | RMSE H2O: 0.6206 | MAE PL: 0.2364 | RMSE PL: 0.5973 | LR: 3.1e-05
# Epoch 46/100 | Train Loss: 0.4511 | Val Loss: 0.4871 | MAE H2O: 0.4376 | RMSE H2O: 0.6249 | MAE PL: 0.2431 | RMSE PL: 0.6113 | LR: 3.1e-05
# Epoch 47/100 | Train Loss: 0.4487 | Val Loss: 0.4660 | MAE H2O: 0.4313 | RMSE H2O: 0.6162 | MAE PL: 0.2389 | RMSE PL: 0.5932 | LR: 3.1e-05
# ⛔ Early stopping at epoch 48

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correct unpacking from evaluate
(y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl) = evaluate(model, test_loader)

# Concatenate outputs
y_pred_test_scaled = np.concatenate([y_pred_h2o, y_pred_pl], axis=1)
y_true_test_scaled = np.concatenate([y_true_h2o, y_true_pl], axis=1)

# Inverse transform
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_true_test = scaler_y.inverse_transform(y_true_test_scaled)

# Split again
y_pred_h2o = y_pred_test[:, :67]
y_pred_pl  = y_pred_test[:, 67:]

y_true_h2o = y_true_test[:, :67]
y_true_pl  = y_true_test[:, 67:]

# Optionally concatenate to compute overall metrics
y_true_test = np.concatenate([y_true_pl, y_true_h2o], axis=1)
y_pred_test = np.concatenate([y_pred_pl, y_pred_h2o], axis=1)

# Compute test metrics
test_mae = mean_absolute_error(y_true_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"\n✅ Test MAE:  {test_mae:.4f}")
print(f"✅ Test RMSE: {test_rmse:.4f}")

# You can also compute them separately:
mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

print(f"\n🌊 H2O  → MAE: {mae_h2o:.4f} | RMSE: {rmse_h2o:.4f}")
print(f"📉 PL   → MAE: {mae_pl:.4f} | RMSE: {rmse_pl:.4f}")
# Out:
# ✅ Test MAE:  1.9956
# ✅ Test RMSE: 7.5465
#
# 🌊 H2O  → MAE: 0.0007 | RMSE: 0.0015
# 📉 PL   → MAE: 3.9905 | RMSE: 10.6724

# %%
output_index = 120  # index within concatenated output (0–133)

plt.figure(figsize=(10, 5))
plt.plot(y_true_test[:, output_index], label='True', alpha=0.7)
plt.plot(y_pred_test[:, output_index], label='Predicted', alpha=0.7)
plt.title(f"True vs Predicted - Output #{output_index}")
plt.xlabel("Sample index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose a sample index
i = 120

# Extract profiles for test sample i
pl_profile_true = y_true_pl[i]
h2o_profile_true = y_true_h2o[i]

pl_profile_pred = y_pred_pl[i]
h2o_profile_pred = y_pred_h2o[i]

# Plot profile
plt.figure(figsize=(7, 6))
plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
plt.gca().invert_yaxis()
plt.xlabel("H2O content [vmr]")
plt.ylabel("Pressure Layer [mbar]")
#plt.ylim(0, 1000)
plt.title("H2O content vs Pressure Level")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for i in range(3):
    pl_profile_true = y_true_pl[i]
    h2o_profile_true = y_true_h2o[i]
    pl_profile_pred = y_pred_pl[i]
    h2o_profile_pred = y_pred_h2o[i]

    plt.figure(figsize=(7, 6))
    plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
    plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
    plt.gca().invert_yaxis()
    plt.xlabel("H2O content [vmr]")
    plt.ylabel("Pressure Layer [mbar]")
    #plt.ylim(0, 1000)
    plt.title(f"H2O vs PL — Test Sample #{i}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#torch.save(model.state_dict(), save_path)

# %%
save_path_final = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model12_final.pth'
torch.save(model.state_dict(), save_path_final)
