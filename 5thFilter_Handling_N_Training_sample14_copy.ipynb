# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0'
input_pkl_path_v1 = os.path.join(data_dir, 'input_nn_ver1.pkl')
#input_pkl_path_v2 = os.path.join(data_dir, 'input_nn_ver2.pkl')

# %%
df = pd.read_pickle(input_pkl_path_v1)
#df = pd.read_pickle(input_pkl_path_v2)

# %% [markdown]
# **------------------NOISE ADDING----------------------**

# %%
def add_noise(tsky, trx=75.0, snr=1000.0):
    tsys = trx + tsky
    tnoise = tsys / snr
    tcal = tsky + tnoise * np.random.standard_normal(tsky.shape)
    return tcal

# %%
original_spectrum = np.array(df['SPECTRA_Tb[K]'].iloc[0])

# %%
frequencies = np.linspace(20.0, 26.0, len(original_spectrum))

# %%
noisy_spectrum = add_noise(original_spectrum)

# %%
df['SPECTRA_Tb[K]_NOISY'] = df['SPECTRA_Tb[K]'].apply(lambda spec: add_noise(np.array(spec)))

# %% [markdown]
# **TRANING WAY 1: USING DIFFERENT COLUMNS BETWEEN PL AND H2O**

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['SPECTRA_Tb[K]_NOISY'].tolist())
PL = np.array(df['PL[mbar]'].tolist())
H2O = np.array(df['H2O[vmr]'].tolist())
Y = np.concatenate([H2O, PL], axis=1)

# %%
print(H2O.shape, PL.shape)
# Out:
# (21024, 67) (21024, 67)

# %%
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.4, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)

# %%
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **SECOND FRAMEWORK TORCH**

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **-NORMALIZATION-**

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_val_scaled = scaler.transform(X_val)
#X_test_scaled = scaler.transform(X_test)
X_train = scaler_x.fit_transform(X_train)
X_val = scaler_x.transform(X_val)
X_test = scaler_x.transform(X_test)

# %%
scaler_y = StandardScaler()
Y_train = scaler_y.fit_transform(Y_train)
Y_val   = scaler_y.transform(Y_val)
Y_test  = scaler_y.transform(Y_test)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **-----------------------**

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
Y_val   = torch.tensor(Y_val, dtype=torch.float32)
X_test  = torch.tensor(X_test, dtype=torch.float32)
Y_test  = torch.tensor(Y_test, dtype=torch.float32)

# %%
batch_size = 64

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds  = TensorDataset(X_test, Y_test)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
class PedroSplitMLP_v2(nn.Module):
    def __init__(self):
        super(PedroSplitMLP_v2, self).__init__()
        self.shared = nn.Sequential(
            nn.Linear(12001, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(1024, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.1)
        )

        # Output heads
        self.h2o_head = nn.Linear(128, 67)
        self.pl_head = nn.Linear(128, 67)

    def forward(self, x):
        x = self.shared(x)
        h2o_out = self.h2o_head(x)
        pl_out = self.pl_head(x)
        return h2o_out, pl_out

model = PedroSplitMLP_v2()

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super(WeightedMSELoss, self).__init__()
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def forward(self, pred, target):
        diff = pred - target
        weighted_diff = diff * self.weights
        loss = torch.mean(weighted_diff ** 2)
        return loss

def smoothness_penalty(h2o_pred, alpha):
    diff = h2o_pred[:, 1:] - h2o_pred[:, :-1]
    return alpha * torch.mean(diff ** 2)

# Construct weights to emphasize lower pressures (higher in atmosphere)
n_levels = 67

equal_weights = torch.ones(n_levels, dtype=torch.float32)
criterion_h2o = WeightedMSELoss(weights=equal_weights)
criterion_pl  = WeightedMSELoss(weights=equal_weights)
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
# Out:
# /tmp/ipython-input-25-2868369312.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.weights = torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, loader, val_loader, criterion_h2o, criterion_pl, optimizer, epochs, save_path, alpha, lambda_h2o):
    train_losses, val_losses = [], []
    val_mae_list, val_rmse_list = [], []

    best_val_loss = float('inf')
    patience = 20
    counter = 0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        for xb, yb in loader:
            optimizer.zero_grad()

            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            loss_h2o = criterion_h2o(h2o_pred, h2o_target)
            loss_pl = criterion_pl(pl_pred, pl_target)
            smooth_loss = smoothness_penalty(h2o_pred, alpha=alpha)

            loss = lambda_h2o * loss_h2o + loss_pl + smooth_loss
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(loader))

        # VALIDATION
        model.eval()
        val_loss_total = 0
        y_true_h2o, y_pred_h2o = [], []
        y_true_pl, y_pred_pl = [], []

        with torch.no_grad():
            for xb, yb in val_loader:
                h2o_pred, pl_pred = model(xb)
                h2o_target = yb[:, :n_levels]
                pl_target = yb[:, n_levels:]

                loss_h2o_val = criterion_h2o(h2o_pred, h2o_target)
                loss_pl_val = criterion_pl(pl_pred, pl_target)
                smooth_loss_val = smoothness_penalty(h2o_pred, alpha=alpha)

                batch_val_loss = lambda_h2o * loss_h2o_val + loss_pl_val + smooth_loss_val
                val_loss_total += batch_val_loss.item()

                y_true_h2o.append(h2o_target.cpu().numpy())
                y_pred_h2o.append(h2o_pred.cpu().numpy())

                y_true_pl.append(pl_target.cpu().numpy())
                y_pred_pl.append(pl_pred.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_losses.append(val_loss)

        y_true_h2o = np.concatenate(y_true_h2o, axis=0)
        y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

        y_true_pl = np.concatenate(y_true_pl, axis=0)
        y_pred_pl = np.concatenate(y_pred_pl, axis=0)

        # METRICS
        val_mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
        val_rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

        val_mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
        val_rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

        val_mae_list.append((val_mae_h2o, val_mae_pl))
        val_rmse_list.append((val_rmse_h2o, val_rmse_pl))

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        # EARLY STOPPING
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), save_path)
            counter = 0
            print(f"✅ Model improved and saved (val_loss = {best_val_loss:.4f})")
        else:
            counter += 1
            if counter >= patience:
                print(f"⛔ Early stopping at epoch {epoch+1}")
                break

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f} | "
              f"MAE H2O: {val_mae_h2o:.4f} | RMSE H2O: {val_rmse_h2o:.4f} | "
              f"MAE PL: {val_mae_pl:.4f} | RMSE PL: {val_rmse_pl:.4f} | LR: {current_lr:.1e}")

    model.load_state_dict(torch.load(save_path))
    return train_losses, val_losses, val_mae_list, val_rmse_list

# %%
def evaluate(model, loader):
    model.eval()
    y_true_h2o, y_pred_h2o = [], []
    y_true_pl, y_pred_pl = [], []

    with torch.no_grad():
        for xb, yb in loader:
            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            y_true_h2o.append(h2o_target.cpu().numpy())
            y_pred_h2o.append(h2o_pred.cpu().numpy())

            y_true_pl.append(pl_target.cpu().numpy())
            y_pred_pl.append(pl_pred.cpu().numpy())

    y_true_h2o = np.concatenate(y_true_h2o, axis=0)
    y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

    y_true_pl = np.concatenate(y_true_pl, axis=0)
    y_pred_pl = np.concatenate(y_pred_pl, axis=0)

    return (y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl)

# %%
save_path = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model14.pth'

# %%
epochs = 300
alpha = 0.05  # Regularization strength for smoothness penalty
lambda_h2o=0.3
train_losses, val_losses, val_mae, val_rmse = train(
    model,
    train_loader,
    val_loader,
    criterion_h2o,
    criterion_pl,
    optimizer,
    epochs,
    save_path=save_path,
    alpha=alpha,
    lambda_h2o=lambda_h2o
)
# Out:
# ✅ Model improved and saved (val_loss = 0.8114)
# Epoch 1/300 | Train Loss: 0.6505 | Val Loss: 0.8114 | MAE H2O: 0.4678 | RMSE H2O: 0.6476 | MAE PL: 0.4040 | RMSE PL: 0.8274 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.6573)
# Epoch 2/300 | Train Loss: 0.5892 | Val Loss: 0.6573 | MAE H2O: 0.4405 | RMSE H2O: 0.6234 | MAE PL: 0.3355 | RMSE PL: 0.7348 | LR: 5.0e-04
# Epoch 3/300 | Train Loss: 0.5754 | Val Loss: 0.6759 | MAE H2O: 0.4678 | RMSE H2O: 0.6571 | MAE PL: 0.3697 | RMSE PL: 0.7389 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5808)
# Epoch 4/300 | Train Loss: 0.5858 | Val Loss: 0.5808 | MAE H2O: 0.4277 | RMSE H2O: 0.6132 | MAE PL: 0.2905 | RMSE PL: 0.6837 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4875)
# Epoch 5/300 | Train Loss: 0.5665 | Val Loss: 0.4875 | MAE H2O: 0.4341 | RMSE H2O: 0.6242 | MAE PL: 0.2642 | RMSE PL: 0.6085 | LR: 5.0e-04
# Epoch 6/300 | Train Loss: 0.5710 | Val Loss: 0.5634 | MAE H2O: 0.4336 | RMSE H2O: 0.6203 | MAE PL: 0.2854 | RMSE PL: 0.6690 | LR: 5.0e-04
# Epoch 7/300 | Train Loss: 0.5929 | Val Loss: 0.5542 | MAE H2O: 0.4367 | RMSE H2O: 0.6186 | MAE PL: 0.2821 | RMSE PL: 0.6626 | LR: 5.0e-04
# Epoch 8/300 | Train Loss: 0.5642 | Val Loss: 0.5657 | MAE H2O: 0.4236 | RMSE H2O: 0.6164 | MAE PL: 0.2779 | RMSE PL: 0.6717 | LR: 5.0e-04
# Epoch 9/300 | Train Loss: 0.5539 | Val Loss: 0.5355 | MAE H2O: 0.4345 | RMSE H2O: 0.6247 | MAE PL: 0.2851 | RMSE PL: 0.6465 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4242)
# Epoch 10/300 | Train Loss: 0.5300 | Val Loss: 0.4242 | MAE H2O: 0.4045 | RMSE H2O: 0.5880 | MAE PL: 0.2413 | RMSE PL: 0.5659 | LR: 5.0e-04
# Epoch 11/300 | Train Loss: 0.5293 | Val Loss: 0.4744 | MAE H2O: 0.4169 | RMSE H2O: 0.6017 | MAE PL: 0.2658 | RMSE PL: 0.6045 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4123)
# Epoch 12/300 | Train Loss: 0.5177 | Val Loss: 0.4123 | MAE H2O: 0.4031 | RMSE H2O: 0.5866 | MAE PL: 0.2328 | RMSE PL: 0.5557 | LR: 5.0e-04
# Epoch 13/300 | Train Loss: 0.5173 | Val Loss: 0.4459 | MAE H2O: 0.4181 | RMSE H2O: 0.5971 | MAE PL: 0.2457 | RMSE PL: 0.5819 | LR: 5.0e-04
# Epoch 14/300 | Train Loss: 0.5104 | Val Loss: 0.4203 | MAE H2O: 0.3991 | RMSE H2O: 0.5821 | MAE PL: 0.2383 | RMSE PL: 0.5641 | LR: 5.0e-04
# Epoch 15/300 | Train Loss: 0.5020 | Val Loss: 0.4803 | MAE H2O: 0.4008 | RMSE H2O: 0.5895 | MAE PL: 0.2562 | RMSE PL: 0.6127 | LR: 5.0e-04
# Epoch 16/300 | Train Loss: 0.5054 | Val Loss: 0.4454 | MAE H2O: 0.4062 | RMSE H2O: 0.6030 | MAE PL: 0.2348 | RMSE PL: 0.5796 | LR: 5.0e-04
# Epoch 17/300 | Train Loss: 0.5061 | Val Loss: 0.4429 | MAE H2O: 0.4034 | RMSE H2O: 0.5833 | MAE PL: 0.2653 | RMSE PL: 0.5833 | LR: 2.5e-04
# Epoch 18/300 | Train Loss: 0.4803 | Val Loss: 0.4361 | MAE H2O: 0.3982 | RMSE H2O: 0.5780 | MAE PL: 0.2499 | RMSE PL: 0.5791 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3965)
# Epoch 19/300 | Train Loss: 0.4762 | Val Loss: 0.3965 | MAE H2O: 0.3929 | RMSE H2O: 0.5756 | MAE PL: 0.2270 | RMSE PL: 0.5448 | LR: 2.5e-04
# Epoch 20/300 | Train Loss: 0.4645 | Val Loss: 0.4424 | MAE H2O: 0.3931 | RMSE H2O: 0.5771 | MAE PL: 0.2509 | RMSE PL: 0.5847 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3946)
# Epoch 21/300 | Train Loss: 0.4716 | Val Loss: 0.3946 | MAE H2O: 0.3924 | RMSE H2O: 0.5738 | MAE PL: 0.2255 | RMSE PL: 0.5435 | LR: 2.5e-04
# Epoch 22/300 | Train Loss: 0.4615 | Val Loss: 0.3973 | MAE H2O: 0.3906 | RMSE H2O: 0.5735 | MAE PL: 0.2317 | RMSE PL: 0.5461 | LR: 2.5e-04
# Epoch 23/300 | Train Loss: 0.4686 | Val Loss: 0.3979 | MAE H2O: 0.3922 | RMSE H2O: 0.5759 | MAE PL: 0.2239 | RMSE PL: 0.5458 | LR: 2.5e-04
# Epoch 24/300 | Train Loss: 0.4631 | Val Loss: 0.4053 | MAE H2O: 0.3932 | RMSE H2O: 0.5833 | MAE PL: 0.2258 | RMSE PL: 0.5503 | LR: 2.5e-04
# Epoch 25/300 | Train Loss: 0.4671 | Val Loss: 0.3961 | MAE H2O: 0.3948 | RMSE H2O: 0.5768 | MAE PL: 0.2298 | RMSE PL: 0.5440 | LR: 2.5e-04
# Epoch 26/300 | Train Loss: 0.4563 | Val Loss: 0.4032 | MAE H2O: 0.3920 | RMSE H2O: 0.5744 | MAE PL: 0.2331 | RMSE PL: 0.5512 | LR: 1.3e-04
# Epoch 27/300 | Train Loss: 0.4551 | Val Loss: 0.4110 | MAE H2O: 0.3953 | RMSE H2O: 0.5782 | MAE PL: 0.2450 | RMSE PL: 0.5570 | LR: 1.3e-04
# Epoch 28/300 | Train Loss: 0.4557 | Val Loss: 0.3952 | MAE H2O: 0.3921 | RMSE H2O: 0.5787 | MAE PL: 0.2213 | RMSE PL: 0.5426 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3856)
# Epoch 29/300 | Train Loss: 0.4511 | Val Loss: 0.3856 | MAE H2O: 0.3922 | RMSE H2O: 0.5755 | MAE PL: 0.2170 | RMSE PL: 0.5346 | LR: 1.3e-04
# Epoch 30/300 | Train Loss: 0.4508 | Val Loss: 0.3928 | MAE H2O: 0.3931 | RMSE H2O: 0.5774 | MAE PL: 0.2281 | RMSE PL: 0.5407 | LR: 1.3e-04
# Epoch 31/300 | Train Loss: 0.4485 | Val Loss: 0.3858 | MAE H2O: 0.3954 | RMSE H2O: 0.5785 | MAE PL: 0.2268 | RMSE PL: 0.5338 | LR: 1.3e-04
# Epoch 32/300 | Train Loss: 0.4432 | Val Loss: 0.3891 | MAE H2O: 0.3915 | RMSE H2O: 0.5732 | MAE PL: 0.2225 | RMSE PL: 0.5386 | LR: 1.3e-04
# Epoch 33/300 | Train Loss: 0.4491 | Val Loss: 0.3937 | MAE H2O: 0.3884 | RMSE H2O: 0.5709 | MAE PL: 0.2298 | RMSE PL: 0.5436 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3816)
# Epoch 34/300 | Train Loss: 0.4505 | Val Loss: 0.3816 | MAE H2O: 0.3863 | RMSE H2O: 0.5688 | MAE PL: 0.2184 | RMSE PL: 0.5330 | LR: 1.3e-04
# Epoch 35/300 | Train Loss: 0.4495 | Val Loss: 0.3963 | MAE H2O: 0.3918 | RMSE H2O: 0.5740 | MAE PL: 0.2238 | RMSE PL: 0.5449 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3812)
# Epoch 36/300 | Train Loss: 0.4458 | Val Loss: 0.3812 | MAE H2O: 0.3888 | RMSE H2O: 0.5710 | MAE PL: 0.2212 | RMSE PL: 0.5319 | LR: 1.3e-04
# Epoch 37/300 | Train Loss: 0.4470 | Val Loss: 0.3863 | MAE H2O: 0.3922 | RMSE H2O: 0.5741 | MAE PL: 0.2206 | RMSE PL: 0.5356 | LR: 1.3e-04
# Epoch 38/300 | Train Loss: 0.4423 | Val Loss: 0.3849 | MAE H2O: 0.3911 | RMSE H2O: 0.5720 | MAE PL: 0.2249 | RMSE PL: 0.5350 | LR: 1.3e-04
# Epoch 39/300 | Train Loss: 0.4396 | Val Loss: 0.3972 | MAE H2O: 0.3896 | RMSE H2O: 0.5726 | MAE PL: 0.2209 | RMSE PL: 0.5462 | LR: 1.3e-04
# Epoch 40/300 | Train Loss: 0.4440 | Val Loss: 0.3843 | MAE H2O: 0.3852 | RMSE H2O: 0.5694 | MAE PL: 0.2169 | RMSE PL: 0.5353 | LR: 1.3e-04
# Epoch 41/300 | Train Loss: 0.4418 | Val Loss: 0.3931 | MAE H2O: 0.3923 | RMSE H2O: 0.5748 | MAE PL: 0.2248 | RMSE PL: 0.5418 | LR: 6.3e-05
# Epoch 42/300 | Train Loss: 0.4384 | Val Loss: 0.3943 | MAE H2O: 0.3952 | RMSE H2O: 0.5825 | MAE PL: 0.2265 | RMSE PL: 0.5405 | LR: 6.3e-05
# Epoch 43/300 | Train Loss: 0.4392 | Val Loss: 0.3838 | MAE H2O: 0.3906 | RMSE H2O: 0.5745 | MAE PL: 0.2240 | RMSE PL: 0.5331 | LR: 6.3e-05
# Epoch 44/300 | Train Loss: 0.4394 | Val Loss: 0.3830 | MAE H2O: 0.3906 | RMSE H2O: 0.5717 | MAE PL: 0.2282 | RMSE PL: 0.5333 | LR: 6.3e-05
# Epoch 45/300 | Train Loss: 0.4383 | Val Loss: 0.3884 | MAE H2O: 0.3952 | RMSE H2O: 0.5806 | MAE PL: 0.2152 | RMSE PL: 0.5356 | LR: 6.3e-05
# Epoch 46/300 | Train Loss: 0.4390 | Val Loss: 0.3833 | MAE H2O: 0.3874 | RMSE H2O: 0.5694 | MAE PL: 0.2178 | RMSE PL: 0.5343 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3775)
# Epoch 47/300 | Train Loss: 0.4371 | Val Loss: 0.3775 | MAE H2O: 0.3893 | RMSE H2O: 0.5732 | MAE PL: 0.2090 | RMSE PL: 0.5278 | LR: 3.1e-05
# Epoch 48/300 | Train Loss: 0.4331 | Val Loss: 0.3782 | MAE H2O: 0.3853 | RMSE H2O: 0.5698 | MAE PL: 0.2125 | RMSE PL: 0.5295 | LR: 3.1e-05
# Epoch 49/300 | Train Loss: 0.4305 | Val Loss: 0.3795 | MAE H2O: 0.3926 | RMSE H2O: 0.5772 | MAE PL: 0.2110 | RMSE PL: 0.5284 | LR: 3.1e-05
# Epoch 50/300 | Train Loss: 0.4312 | Val Loss: 0.3803 | MAE H2O: 0.3926 | RMSE H2O: 0.5747 | MAE PL: 0.2101 | RMSE PL: 0.5299 | LR: 3.1e-05
# Epoch 51/300 | Train Loss: 0.4319 | Val Loss: 0.3905 | MAE H2O: 0.3920 | RMSE H2O: 0.5706 | MAE PL: 0.2241 | RMSE PL: 0.5406 | LR: 3.1e-05
# Epoch 52/300 | Train Loss: 0.4292 | Val Loss: 0.3779 | MAE H2O: 0.3856 | RMSE H2O: 0.5692 | MAE PL: 0.2187 | RMSE PL: 0.5293 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3747)
# Epoch 53/300 | Train Loss: 0.4342 | Val Loss: 0.3747 | MAE H2O: 0.3865 | RMSE H2O: 0.5700 | MAE PL: 0.2127 | RMSE PL: 0.5261 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3742)
# Epoch 54/300 | Train Loss: 0.4275 | Val Loss: 0.3742 | MAE H2O: 0.3884 | RMSE H2O: 0.5726 | MAE PL: 0.2068 | RMSE PL: 0.5248 | LR: 1.6e-05
# Epoch 55/300 | Train Loss: 0.4272 | Val Loss: 0.3752 | MAE H2O: 0.3887 | RMSE H2O: 0.5716 | MAE PL: 0.2084 | RMSE PL: 0.5261 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3662)
# Epoch 56/300 | Train Loss: 0.4260 | Val Loss: 0.3662 | MAE H2O: 0.3840 | RMSE H2O: 0.5661 | MAE PL: 0.2081 | RMSE PL: 0.5191 | LR: 1.6e-05
# Epoch 57/300 | Train Loss: 0.4271 | Val Loss: 0.3746 | MAE H2O: 0.3881 | RMSE H2O: 0.5729 | MAE PL: 0.2110 | RMSE PL: 0.5251 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3640)
# Epoch 58/300 | Train Loss: 0.4206 | Val Loss: 0.3640 | MAE H2O: 0.3851 | RMSE H2O: 0.5666 | MAE PL: 0.2000 | RMSE PL: 0.5169 | LR: 1.6e-05
# Epoch 59/300 | Train Loss: 0.4184 | Val Loss: 0.3647 | MAE H2O: 0.3812 | RMSE H2O: 0.5643 | MAE PL: 0.2010 | RMSE PL: 0.5183 | LR: 1.6e-05
# Epoch 60/300 | Train Loss: 0.4239 | Val Loss: 0.3661 | MAE H2O: 0.3869 | RMSE H2O: 0.5703 | MAE PL: 0.1995 | RMSE PL: 0.5178 | LR: 1.6e-05
# Epoch 61/300 | Train Loss: 0.4229 | Val Loss: 0.3661 | MAE H2O: 0.3858 | RMSE H2O: 0.5668 | MAE PL: 0.2060 | RMSE PL: 0.5188 | LR: 1.6e-05
# Epoch 62/300 | Train Loss: 0.4237 | Val Loss: 0.3668 | MAE H2O: 0.3822 | RMSE H2O: 0.5660 | MAE PL: 0.2024 | RMSE PL: 0.5198 | LR: 1.6e-05
# Epoch 63/300 | Train Loss: 0.4198 | Val Loss: 0.3647 | MAE H2O: 0.3845 | RMSE H2O: 0.5658 | MAE PL: 0.2014 | RMSE PL: 0.5178 | LR: 7.8e-06
# Epoch 64/300 | Train Loss: 0.4209 | Val Loss: 0.3774 | MAE H2O: 0.3920 | RMSE H2O: 0.5760 | MAE PL: 0.2161 | RMSE PL: 0.5266 | LR: 7.8e-06
# Epoch 65/300 | Train Loss: 0.4143 | Val Loss: 0.3669 | MAE H2O: 0.3928 | RMSE H2O: 0.5724 | MAE PL: 0.1962 | RMSE PL: 0.5179 | LR: 7.8e-06
# Epoch 66/300 | Train Loss: 0.4198 | Val Loss: 0.3702 | MAE H2O: 0.3937 | RMSE H2O: 0.5759 | MAE PL: 0.1975 | RMSE PL: 0.5199 | LR: 7.8e-06
# Epoch 67/300 | Train Loss: 0.4238 | Val Loss: 0.3739 | MAE H2O: 0.3848 | RMSE H2O: 0.5698 | MAE PL: 0.2052 | RMSE PL: 0.5254 | LR: 7.8e-06
# Epoch 68/300 | Train Loss: 0.4166 | Val Loss: 0.3664 | MAE H2O: 0.3855 | RMSE H2O: 0.5667 | MAE PL: 0.2027 | RMSE PL: 0.5191 | LR: 3.9e-06
# Epoch 69/300 | Train Loss: 0.4273 | Val Loss: 0.3759 | MAE H2O: 0.3893 | RMSE H2O: 0.5732 | MAE PL: 0.2089 | RMSE PL: 0.5262 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3610)
# Epoch 70/300 | Train Loss: 0.4138 | Val Loss: 0.3610 | MAE H2O: 0.3824 | RMSE H2O: 0.5665 | MAE PL: 0.2019 | RMSE PL: 0.5140 | LR: 3.9e-06
# Epoch 71/300 | Train Loss: 0.4132 | Val Loss: 0.3720 | MAE H2O: 0.3877 | RMSE H2O: 0.5712 | MAE PL: 0.2103 | RMSE PL: 0.5230 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3594)
# Epoch 72/300 | Train Loss: 0.4111 | Val Loss: 0.3594 | MAE H2O: 0.3825 | RMSE H2O: 0.5656 | MAE PL: 0.1930 | RMSE PL: 0.5128 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3587)
# Epoch 73/300 | Train Loss: 0.4137 | Val Loss: 0.3587 | MAE H2O: 0.3831 | RMSE H2O: 0.5651 | MAE PL: 0.1968 | RMSE PL: 0.5121 | LR: 3.9e-06
# Epoch 74/300 | Train Loss: 0.4116 | Val Loss: 0.3602 | MAE H2O: 0.3834 | RMSE H2O: 0.5670 | MAE PL: 0.2007 | RMSE PL: 0.5131 | LR: 3.9e-06
# Epoch 75/300 | Train Loss: 0.4155 | Val Loss: 0.3770 | MAE H2O: 0.3860 | RMSE H2O: 0.5676 | MAE PL: 0.2133 | RMSE PL: 0.5290 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3576)
# Epoch 76/300 | Train Loss: 0.4089 | Val Loss: 0.3576 | MAE H2O: 0.3816 | RMSE H2O: 0.5640 | MAE PL: 0.1958 | RMSE PL: 0.5115 | LR: 3.9e-06
# Epoch 77/300 | Train Loss: 0.4144 | Val Loss: 0.3654 | MAE H2O: 0.3881 | RMSE H2O: 0.5723 | MAE PL: 0.2055 | RMSE PL: 0.5164 | LR: 3.9e-06
# Epoch 78/300 | Train Loss: 0.4162 | Val Loss: 0.3599 | MAE H2O: 0.3846 | RMSE H2O: 0.5674 | MAE PL: 0.1925 | RMSE PL: 0.5127 | LR: 3.9e-06
# Epoch 79/300 | Train Loss: 0.4133 | Val Loss: 0.3580 | MAE H2O: 0.3824 | RMSE H2O: 0.5642 | MAE PL: 0.1960 | RMSE PL: 0.5118 | LR: 3.9e-06
# Epoch 80/300 | Train Loss: 0.4139 | Val Loss: 0.3638 | MAE H2O: 0.3868 | RMSE H2O: 0.5707 | MAE PL: 0.1935 | RMSE PL: 0.5154 | LR: 3.9e-06
# Epoch 81/300 | Train Loss: 0.4099 | Val Loss: 0.3584 | MAE H2O: 0.3860 | RMSE H2O: 0.5680 | MAE PL: 0.1939 | RMSE PL: 0.5110 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3567)
# Epoch 82/300 | Train Loss: 0.4073 | Val Loss: 0.3567 | MAE H2O: 0.3846 | RMSE H2O: 0.5665 | MAE PL: 0.1962 | RMSE PL: 0.5098 | LR: 2.0e-06
# Epoch 83/300 | Train Loss: 0.4129 | Val Loss: 0.3617 | MAE H2O: 0.3844 | RMSE H2O: 0.5641 | MAE PL: 0.2004 | RMSE PL: 0.5154 | LR: 2.0e-06
# Epoch 84/300 | Train Loss: 0.4099 | Val Loss: 0.3570 | MAE H2O: 0.3832 | RMSE H2O: 0.5663 | MAE PL: 0.1929 | RMSE PL: 0.5102 | LR: 2.0e-06
# Epoch 85/300 | Train Loss: 0.4104 | Val Loss: 0.3571 | MAE H2O: 0.3812 | RMSE H2O: 0.5644 | MAE PL: 0.1944 | RMSE PL: 0.5110 | LR: 2.0e-06
# Epoch 86/300 | Train Loss: 0.4118 | Val Loss: 0.3660 | MAE H2O: 0.3890 | RMSE H2O: 0.5710 | MAE PL: 0.1935 | RMSE PL: 0.5174 | LR: 2.0e-06
# Epoch 87/300 | Train Loss: 0.4075 | Val Loss: 0.3863 | MAE H2O: 0.3907 | RMSE H2O: 0.5742 | MAE PL: 0.2108 | RMSE PL: 0.5355 | LR: 9.8e-07
# Epoch 88/300 | Train Loss: 0.4151 | Val Loss: 0.3705 | MAE H2O: 0.3830 | RMSE H2O: 0.5675 | MAE PL: 0.2044 | RMSE PL: 0.5229 | LR: 9.8e-07
# Epoch 89/300 | Train Loss: 0.4089 | Val Loss: 0.3711 | MAE H2O: 0.3866 | RMSE H2O: 0.5724 | MAE PL: 0.2038 | RMSE PL: 0.5219 | LR: 9.8e-07
# Epoch 90/300 | Train Loss: 0.4118 | Val Loss: 0.3621 | MAE H2O: 0.3812 | RMSE H2O: 0.5645 | MAE PL: 0.1993 | RMSE PL: 0.5157 | LR: 9.8e-07
# Epoch 91/300 | Train Loss: 0.4072 | Val Loss: 0.3606 | MAE H2O: 0.3842 | RMSE H2O: 0.5666 | MAE PL: 0.1944 | RMSE PL: 0.5136 | LR: 9.8e-07
# Epoch 92/300 | Train Loss: 0.4111 | Val Loss: 0.3617 | MAE H2O: 0.3875 | RMSE H2O: 0.5694 | MAE PL: 0.1948 | RMSE PL: 0.5138 | LR: 4.9e-07
# Epoch 93/300 | Train Loss: 0.4102 | Val Loss: 0.3597 | MAE H2O: 0.3836 | RMSE H2O: 0.5654 | MAE PL: 0.1967 | RMSE PL: 0.5131 | LR: 4.9e-07
# Epoch 94/300 | Train Loss: 0.4100 | Val Loss: 0.3704 | MAE H2O: 0.3815 | RMSE H2O: 0.5646 | MAE PL: 0.2114 | RMSE PL: 0.5236 | LR: 4.9e-07
# Epoch 95/300 | Train Loss: 0.4140 | Val Loss: 0.3834 | MAE H2O: 0.3889 | RMSE H2O: 0.5768 | MAE PL: 0.2081 | RMSE PL: 0.5321 | LR: 4.9e-07
# Epoch 96/300 | Train Loss: 0.4087 | Val Loss: 0.3569 | MAE H2O: 0.3837 | RMSE H2O: 0.5649 | MAE PL: 0.1934 | RMSE PL: 0.5105 | LR: 4.9e-07
# ✅ Model improved and saved (val_loss = 0.3556)
# Epoch 97/300 | Train Loss: 0.4059 | Val Loss: 0.3556 | MAE H2O: 0.3814 | RMSE H2O: 0.5638 | MAE PL: 0.1943 | RMSE PL: 0.5096 | LR: 4.9e-07
# Epoch 98/300 | Train Loss: 0.4076 | Val Loss: 0.3752 | MAE H2O: 0.3904 | RMSE H2O: 0.5783 | MAE PL: 0.2002 | RMSE PL: 0.5238 | LR: 4.9e-07
# Epoch 99/300 | Train Loss: 0.4121 | Val Loss: 0.3668 | MAE H2O: 0.3861 | RMSE H2O: 0.5695 | MAE PL: 0.2002 | RMSE PL: 0.5187 | LR: 4.9e-07
# Epoch 100/300 | Train Loss: 0.4128 | Val Loss: 0.3573 | MAE H2O: 0.3846 | RMSE H2O: 0.5660 | MAE PL: 0.1910 | RMSE PL: 0.5106 | LR: 4.9e-07
# Epoch 101/300 | Train Loss: 0.4155 | Val Loss: 0.3886 | MAE H2O: 0.3969 | RMSE H2O: 0.5791 | MAE PL: 0.2064 | RMSE PL: 0.5362 | LR: 4.9e-07
# Epoch 102/300 | Train Loss: 0.4101 | Val Loss: 0.3632 | MAE H2O: 0.3883 | RMSE H2O: 0.5706 | MAE PL: 0.1968 | RMSE PL: 0.5149 | LR: 2.4e-07
# Epoch 103/300 | Train Loss: 0.4128 | Val Loss: 0.3577 | MAE H2O: 0.3852 | RMSE H2O: 0.5676 | MAE PL: 0.1948 | RMSE PL: 0.5103 | LR: 2.4e-07
# Epoch 104/300 | Train Loss: 0.4122 | Val Loss: 0.3622 | MAE H2O: 0.3859 | RMSE H2O: 0.5689 | MAE PL: 0.1927 | RMSE PL: 0.5145 | LR: 2.4e-07
# Epoch 105/300 | Train Loss: 0.4107 | Val Loss: 0.3575 | MAE H2O: 0.3848 | RMSE H2O: 0.5642 | MAE PL: 0.1918 | RMSE PL: 0.5114 | LR: 2.4e-07
# ✅ Model improved and saved (val_loss = 0.3546)
# Epoch 106/300 | Train Loss: 0.4125 | Val Loss: 0.3546 | MAE H2O: 0.3812 | RMSE H2O: 0.5625 | MAE PL: 0.1900 | RMSE PL: 0.5091 | LR: 2.4e-07
# Epoch 107/300 | Train Loss: 0.4129 | Val Loss: 0.3592 | MAE H2O: 0.3872 | RMSE H2O: 0.5679 | MAE PL: 0.1994 | RMSE PL: 0.5118 | LR: 2.4e-07
# Epoch 108/300 | Train Loss: 0.4088 | Val Loss: 0.3600 | MAE H2O: 0.3842 | RMSE H2O: 0.5676 | MAE PL: 0.1939 | RMSE PL: 0.5127 | LR: 2.4e-07
# Epoch 109/300 | Train Loss: 0.4094 | Val Loss: 0.3646 | MAE H2O: 0.3832 | RMSE H2O: 0.5685 | MAE PL: 0.1961 | RMSE PL: 0.5169 | LR: 2.4e-07
# Epoch 110/300 | Train Loss: 0.4122 | Val Loss: 0.3645 | MAE H2O: 0.3874 | RMSE H2O: 0.5696 | MAE PL: 0.1941 | RMSE PL: 0.5164 | LR: 2.4e-07
# Epoch 111/300 | Train Loss: 0.4115 | Val Loss: 0.3613 | MAE H2O: 0.3853 | RMSE H2O: 0.5686 | MAE PL: 0.1952 | RMSE PL: 0.5136 | LR: 1.2e-07
# Epoch 112/300 | Train Loss: 0.4071 | Val Loss: 0.3585 | MAE H2O: 0.3846 | RMSE H2O: 0.5656 | MAE PL: 0.1924 | RMSE PL: 0.5118 | LR: 1.2e-07
# Epoch 113/300 | Train Loss: 0.4098 | Val Loss: 0.3663 | MAE H2O: 0.3826 | RMSE H2O: 0.5663 | MAE PL: 0.2023 | RMSE PL: 0.5192 | LR: 1.2e-07
# Epoch 114/300 | Train Loss: 0.4104 | Val Loss: 0.3578 | MAE H2O: 0.3844 | RMSE H2O: 0.5662 | MAE PL: 0.1917 | RMSE PL: 0.5109 | LR: 1.2e-07
# Epoch 115/300 | Train Loss: 0.4080 | Val Loss: 0.3553 | MAE H2O: 0.3815 | RMSE H2O: 0.5628 | MAE PL: 0.1918 | RMSE PL: 0.5096 | LR: 1.2e-07
# Epoch 116/300 | Train Loss: 0.4065 | Val Loss: 0.3577 | MAE H2O: 0.3822 | RMSE H2O: 0.5632 | MAE PL: 0.1946 | RMSE PL: 0.5119 | LR: 6.1e-08
# Epoch 117/300 | Train Loss: 0.4114 | Val Loss: 0.3590 | MAE H2O: 0.3866 | RMSE H2O: 0.5686 | MAE PL: 0.1964 | RMSE PL: 0.5114 | LR: 6.1e-08
# Epoch 118/300 | Train Loss: 0.4119 | Val Loss: 0.3575 | MAE H2O: 0.3860 | RMSE H2O: 0.5663 | MAE PL: 0.1870 | RMSE PL: 0.5106 | LR: 6.1e-08
# Epoch 119/300 | Train Loss: 0.4096 | Val Loss: 0.3622 | MAE H2O: 0.3900 | RMSE H2O: 0.5748 | MAE PL: 0.1984 | RMSE PL: 0.5125 | LR: 6.1e-08
# Epoch 120/300 | Train Loss: 0.4094 | Val Loss: 0.3558 | MAE H2O: 0.3822 | RMSE H2O: 0.5632 | MAE PL: 0.1925 | RMSE PL: 0.5100 | LR: 6.1e-08
# Epoch 121/300 | Train Loss: 0.4074 | Val Loss: 0.3555 | MAE H2O: 0.3829 | RMSE H2O: 0.5638 | MAE PL: 0.1947 | RMSE PL: 0.5095 | LR: 3.1e-08
# Epoch 122/300 | Train Loss: 0.4094 | Val Loss: 0.3553 | MAE H2O: 0.3782 | RMSE H2O: 0.5623 | MAE PL: 0.1902 | RMSE PL: 0.5098 | LR: 3.1e-08
# Epoch 123/300 | Train Loss: 0.4116 | Val Loss: 0.3644 | MAE H2O: 0.3827 | RMSE H2O: 0.5650 | MAE PL: 0.2012 | RMSE PL: 0.5178 | LR: 3.1e-08
# Epoch 124/300 | Train Loss: 0.4120 | Val Loss: 0.3874 | MAE H2O: 0.3918 | RMSE H2O: 0.5755 | MAE PL: 0.2254 | RMSE PL: 0.5362 | LR: 3.1e-08
# Epoch 125/300 | Train Loss: 0.4113 | Val Loss: 0.3746 | MAE H2O: 0.3847 | RMSE H2O: 0.5690 | MAE PL: 0.2083 | RMSE PL: 0.5262 | LR: 3.1e-08
# ⛔ Early stopping at epoch 126

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correct unpacking from evaluate
(y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl) = evaluate(model, test_loader)

# Concatenate outputs
y_pred_test_scaled = np.concatenate([y_pred_h2o, y_pred_pl], axis=1)
y_true_test_scaled = np.concatenate([y_true_h2o, y_true_pl], axis=1)

# Inverse transform
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_true_test = scaler_y.inverse_transform(y_true_test_scaled)

# Split again
y_pred_h2o = y_pred_test[:, :67]
y_pred_pl  = y_pred_test[:, 67:]

y_true_h2o = y_true_test[:, :67]
y_true_pl  = y_true_test[:, 67:]

# Optionally concatenate to compute overall metrics
y_true_test = np.concatenate([y_true_pl, y_true_h2o], axis=1)
y_pred_test = np.concatenate([y_pred_pl, y_pred_h2o], axis=1)

# Compute test metrics
test_mae = mean_absolute_error(y_true_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"\n✅ Test MAE:  {test_mae:.4f}")
print(f"✅ Test RMSE: {test_rmse:.4f}")

# You can also compute them separately:
mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

print(f"\n🌊 H2O  → MAE: {mae_h2o:.4f} | RMSE: {rmse_h2o:.4f}")
print(f"📉 PL   → MAE: {mae_pl:.4f} | RMSE: {rmse_pl:.4f}")
# Out:
# ✅ Test MAE:  1.3000
# ✅ Test RMSE: 4.5765
#
# 🌊 H2O  → MAE: 0.0005 | RMSE: 0.0013
# 📉 PL   → MAE: 2.5994 | RMSE: 6.4722

# %%
output_index = 120  # index within concatenated output (0–133)

plt.figure(figsize=(10, 5))
plt.plot(y_true_test[:, output_index], label='True', alpha=0.7)
plt.plot(y_pred_test[:, output_index], label='Predicted', alpha=0.7)
plt.title(f"True vs Predicted - Output #{output_index}")
plt.xlabel("Sample index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose a sample index
i = 120

# Extract profiles for test sample i
pl_profile_true = y_true_pl[i]
h2o_profile_true = y_true_h2o[i]

pl_profile_pred = y_pred_pl[i]
h2o_profile_pred = y_pred_h2o[i]

# Plot profile
plt.figure(figsize=(7, 6))
plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
plt.gca().invert_yaxis()
plt.xlabel("H2O content [vmr]")
plt.ylabel("Pressure Layer [mbar]")
#plt.ylim(0, 1000)
plt.title("H2O content vs Pressure Level")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for i in range(3):
    pl_profile_true = y_true_pl[i]
    h2o_profile_true = y_true_h2o[i]
    pl_profile_pred = y_pred_pl[i]
    h2o_profile_pred = y_pred_h2o[i]

    plt.figure(figsize=(7, 6))
    plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
    plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
    plt.gca().invert_yaxis()
    plt.xlabel("H2O content [vmr]")
    plt.ylabel("Pressure Layer [mbar]")
    #plt.ylim(0, 1000)
    plt.title(f"H2O vs PL — Test Sample #{i}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#torch.save(model.state_dict(), save_path)

# %%
save_path_final = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model14_final.pth'
torch.save(model.state_dict(), save_path_final)
