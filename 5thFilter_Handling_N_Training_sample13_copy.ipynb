# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0'
input_pkl_path_v1 = os.path.join(data_dir, 'input_nn_ver1.pkl')
#input_pkl_path_v2 = os.path.join(data_dir, 'input_nn_ver2.pkl')

# %%
df = pd.read_pickle(input_pkl_path_v1)
#df = pd.read_pickle(input_pkl_path_v2)

# %% [markdown]
# **------------------NOISE ADDING----------------------**

# %%
def add_noise(tsky, trx=75.0, snr=1000.0):
    tsys = trx + tsky
    tnoise = tsys / snr
    tcal = tsky + tnoise * np.random.standard_normal(tsky.shape)
    return tcal

# %%
original_spectrum = np.array(df['SPECTRA_Tb[K]'].iloc[0])

# %%
frequencies = np.linspace(20.0, 26.0, len(original_spectrum))

# %%
noisy_spectrum = add_noise(original_spectrum)

# %%
df['SPECTRA_Tb[K]_NOISY'] = df['SPECTRA_Tb[K]'].apply(lambda spec: add_noise(np.array(spec)))

# %% [markdown]
# **TRANING WAY 1: USING DIFFERENT COLUMNS BETWEEN PL AND H2O**

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['SPECTRA_Tb[K]_NOISY'].tolist())
PL = np.array(df['PL[mbar]'].tolist())
H2O = np.array(df['H2O[vmr]'].tolist())
Y = np.concatenate([H2O, PL], axis=1)

# %%
print(H2O.shape, PL.shape)
# Out:
# (21024, 67) (21024, 67)

# %%
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.4, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)

# %%
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **SECOND FRAMEWORK TORCH**

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **-NORMALIZATION-**

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_val_scaled = scaler.transform(X_val)
#X_test_scaled = scaler.transform(X_test)
X_train = scaler_x.fit_transform(X_train)
X_val = scaler_x.transform(X_val)
X_test = scaler_x.transform(X_test)

# %%
scaler_y = StandardScaler()
Y_train = scaler_y.fit_transform(Y_train)
Y_val   = scaler_y.transform(Y_val)
Y_test  = scaler_y.transform(Y_test)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **-----------------------**

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
Y_val   = torch.tensor(Y_val, dtype=torch.float32)
X_test  = torch.tensor(X_test, dtype=torch.float32)
Y_test  = torch.tensor(Y_test, dtype=torch.float32)

# %%
batch_size = 64

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds  = TensorDataset(X_test, Y_test)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
class PedroSplitMLP_v2(nn.Module):
    def __init__(self):
        super(PedroSplitMLP_v2, self).__init__()
        self.shared = nn.Sequential(
            nn.Linear(12001, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(1024, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.1)
        )

        # Output heads
        self.h2o_head = nn.Linear(128, 67)
        self.pl_head = nn.Linear(128, 67)

    def forward(self, x):
        x = self.shared(x)
        h2o_out = self.h2o_head(x)
        pl_out = self.pl_head(x)
        return h2o_out, pl_out

model = PedroSplitMLP_v2()

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super(WeightedMSELoss, self).__init__()
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def forward(self, pred, target):
        diff = pred - target
        weighted_diff = diff * self.weights
        loss = torch.mean(weighted_diff ** 2)
        return loss

def smoothness_penalty(h2o_pred, alpha):
    diff = h2o_pred[:, 1:] - h2o_pred[:, :-1]
    return alpha * torch.mean(diff ** 2)

# Construct weights to emphasize lower pressures (higher in atmosphere)
n_levels = 67

equal_weights = torch.ones(n_levels, dtype=torch.float32)
criterion_h2o = WeightedMSELoss(weights=equal_weights)
criterion_pl  = WeightedMSELoss(weights=equal_weights)
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
# Out:
# /tmp/ipython-input-25-2868369312.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.weights = torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, loader, val_loader, criterion_h2o, criterion_pl, optimizer, epochs, save_path, alpha, lambda_h2o):
    train_losses, val_losses = [], []
    val_mae_list, val_rmse_list = [], []

    best_val_loss = float('inf')
    patience = 20
    counter = 0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        for xb, yb in loader:
            optimizer.zero_grad()

            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            loss_h2o = criterion_h2o(h2o_pred, h2o_target)
            loss_pl = criterion_pl(pl_pred, pl_target)
            smooth_loss = smoothness_penalty(h2o_pred, alpha=alpha)

            loss = lambda_h2o * loss_h2o + loss_pl + smooth_loss
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(loader))

        # VALIDATION
        model.eval()
        val_loss_total = 0
        y_true_h2o, y_pred_h2o = [], []
        y_true_pl, y_pred_pl = [], []

        with torch.no_grad():
            for xb, yb in val_loader:
                h2o_pred, pl_pred = model(xb)
                h2o_target = yb[:, :n_levels]
                pl_target = yb[:, n_levels:]

                loss_h2o_val = criterion_h2o(h2o_pred, h2o_target)
                loss_pl_val = criterion_pl(pl_pred, pl_target)
                smooth_loss_val = smoothness_penalty(h2o_pred, alpha=alpha)

                batch_val_loss = lambda_h2o * loss_h2o_val + loss_pl_val + smooth_loss_val
                val_loss_total += batch_val_loss.item()

                y_true_h2o.append(h2o_target.cpu().numpy())
                y_pred_h2o.append(h2o_pred.cpu().numpy())

                y_true_pl.append(pl_target.cpu().numpy())
                y_pred_pl.append(pl_pred.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_losses.append(val_loss)

        y_true_h2o = np.concatenate(y_true_h2o, axis=0)
        y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

        y_true_pl = np.concatenate(y_true_pl, axis=0)
        y_pred_pl = np.concatenate(y_pred_pl, axis=0)

        # METRICS
        val_mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
        val_rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

        val_mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
        val_rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

        val_mae_list.append((val_mae_h2o, val_mae_pl))
        val_rmse_list.append((val_rmse_h2o, val_rmse_pl))

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        # EARLY STOPPING
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), save_path)
            counter = 0
            print(f"✅ Model improved and saved (val_loss = {best_val_loss:.4f})")
        else:
            counter += 1
            if counter >= patience:
                print(f"⛔ Early stopping at epoch {epoch+1}")
                break

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f} | "
              f"MAE H2O: {val_mae_h2o:.4f} | RMSE H2O: {val_rmse_h2o:.4f} | "
              f"MAE PL: {val_mae_pl:.4f} | RMSE PL: {val_rmse_pl:.4f} | LR: {current_lr:.1e}")

    model.load_state_dict(torch.load(save_path))
    return train_losses, val_losses, val_mae_list, val_rmse_list

# %%
def evaluate(model, loader):
    model.eval()
    y_true_h2o, y_pred_h2o = [], []
    y_true_pl, y_pred_pl = [], []

    with torch.no_grad():
        for xb, yb in loader:
            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            y_true_h2o.append(h2o_target.cpu().numpy())
            y_pred_h2o.append(h2o_pred.cpu().numpy())

            y_true_pl.append(pl_target.cpu().numpy())
            y_pred_pl.append(pl_pred.cpu().numpy())

    y_true_h2o = np.concatenate(y_true_h2o, axis=0)
    y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

    y_true_pl = np.concatenate(y_true_pl, axis=0)
    y_pred_pl = np.concatenate(y_pred_pl, axis=0)

    return (y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl)

# %%
save_path = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model13.pth'

# %%
epochs = 100
alpha = 0.05  # Regularization strength for smoothness penalty
lambda_h2o=0.3
train_losses, val_losses, val_mae, val_rmse = train(
    model,
    train_loader,
    val_loader,
    criterion_h2o,
    criterion_pl,
    optimizer,
    epochs,
    save_path=save_path,
    alpha=alpha,
    lambda_h2o=lambda_h2o
)
# Out:
# ✅ Model improved and saved (val_loss = 0.6167)
# Epoch 1/100 | Train Loss: 0.6360 | Val Loss: 0.6167 | MAE H2O: 0.4565 | RMSE H2O: 0.6387 | MAE PL: 0.2959 | RMSE PL: 0.7027 | LR: 5.0e-04
# Epoch 2/100 | Train Loss: 0.5741 | Val Loss: 0.6237 | MAE H2O: 0.4401 | RMSE H2O: 0.6228 | MAE PL: 0.3040 | RMSE PL: 0.7120 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5883)
# Epoch 3/100 | Train Loss: 0.5808 | Val Loss: 0.5883 | MAE H2O: 0.4361 | RMSE H2O: 0.6214 | MAE PL: 0.2981 | RMSE PL: 0.6871 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5229)
# Epoch 4/100 | Train Loss: 0.5783 | Val Loss: 0.5229 | MAE H2O: 0.4285 | RMSE H2O: 0.6097 | MAE PL: 0.2887 | RMSE PL: 0.6410 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4920)
# Epoch 5/100 | Train Loss: 0.5725 | Val Loss: 0.4920 | MAE H2O: 0.4116 | RMSE H2O: 0.5989 | MAE PL: 0.2728 | RMSE PL: 0.6197 | LR: 5.0e-04
# Epoch 6/100 | Train Loss: 0.5556 | Val Loss: 0.5568 | MAE H2O: 0.4288 | RMSE H2O: 0.6098 | MAE PL: 0.2916 | RMSE PL: 0.6670 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4867)
# Epoch 7/100 | Train Loss: 0.5287 | Val Loss: 0.4867 | MAE H2O: 0.4177 | RMSE H2O: 0.6028 | MAE PL: 0.2721 | RMSE PL: 0.6142 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4354)
# Epoch 8/100 | Train Loss: 0.5420 | Val Loss: 0.4354 | MAE H2O: 0.4006 | RMSE H2O: 0.5880 | MAE PL: 0.2478 | RMSE PL: 0.5756 | LR: 5.0e-04
# Epoch 9/100 | Train Loss: 0.5359 | Val Loss: 0.5066 | MAE H2O: 0.4089 | RMSE H2O: 0.5972 | MAE PL: 0.2631 | RMSE PL: 0.6317 | LR: 5.0e-04
# Epoch 10/100 | Train Loss: 0.5261 | Val Loss: 0.4491 | MAE H2O: 0.3979 | RMSE H2O: 0.5854 | MAE PL: 0.2507 | RMSE PL: 0.5881 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4324)
# Epoch 11/100 | Train Loss: 0.5072 | Val Loss: 0.4324 | MAE H2O: 0.4053 | RMSE H2O: 0.5916 | MAE PL: 0.2429 | RMSE PL: 0.5719 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4308)
# Epoch 12/100 | Train Loss: 0.5154 | Val Loss: 0.4308 | MAE H2O: 0.4037 | RMSE H2O: 0.5887 | MAE PL: 0.2442 | RMSE PL: 0.5714 | LR: 5.0e-04
# Epoch 13/100 | Train Loss: 0.5051 | Val Loss: 0.4570 | MAE H2O: 0.4016 | RMSE H2O: 0.5851 | MAE PL: 0.2609 | RMSE PL: 0.5948 | LR: 5.0e-04
# Epoch 14/100 | Train Loss: 0.5050 | Val Loss: 0.4988 | MAE H2O: 0.4036 | RMSE H2O: 0.5896 | MAE PL: 0.2651 | RMSE PL: 0.6276 | LR: 5.0e-04
# Epoch 15/100 | Train Loss: 0.4970 | Val Loss: 0.4718 | MAE H2O: 0.3955 | RMSE H2O: 0.5783 | MAE PL: 0.2611 | RMSE PL: 0.6089 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4247)
# Epoch 16/100 | Train Loss: 0.5234 | Val Loss: 0.4247 | MAE H2O: 0.3995 | RMSE H2O: 0.5813 | MAE PL: 0.2430 | RMSE PL: 0.5681 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4005)
# Epoch 17/100 | Train Loss: 0.5001 | Val Loss: 0.4005 | MAE H2O: 0.3953 | RMSE H2O: 0.5768 | MAE PL: 0.2322 | RMSE PL: 0.5480 | LR: 5.0e-04
# Epoch 18/100 | Train Loss: 0.4902 | Val Loss: 0.4782 | MAE H2O: 0.3964 | RMSE H2O: 0.5799 | MAE PL: 0.2694 | RMSE PL: 0.6137 | LR: 5.0e-04
# Epoch 19/100 | Train Loss: 0.4970 | Val Loss: 0.4123 | MAE H2O: 0.3979 | RMSE H2O: 0.5821 | MAE PL: 0.2353 | RMSE PL: 0.5571 | LR: 5.0e-04
# Epoch 20/100 | Train Loss: 0.4974 | Val Loss: 0.4310 | MAE H2O: 0.3930 | RMSE H2O: 0.5789 | MAE PL: 0.2379 | RMSE PL: 0.5745 | LR: 5.0e-04
# Epoch 21/100 | Train Loss: 0.4950 | Val Loss: 0.4366 | MAE H2O: 0.3998 | RMSE H2O: 0.5784 | MAE PL: 0.2524 | RMSE PL: 0.5794 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.3962)
# Epoch 22/100 | Train Loss: 0.4723 | Val Loss: 0.3962 | MAE H2O: 0.3982 | RMSE H2O: 0.5807 | MAE PL: 0.2288 | RMSE PL: 0.5428 | LR: 5.0e-04
# Epoch 23/100 | Train Loss: 0.4842 | Val Loss: 0.4584 | MAE H2O: 0.3920 | RMSE H2O: 0.5773 | MAE PL: 0.2483 | RMSE PL: 0.5982 | LR: 5.0e-04
# Epoch 24/100 | Train Loss: 0.4855 | Val Loss: 0.4289 | MAE H2O: 0.3924 | RMSE H2O: 0.5736 | MAE PL: 0.2426 | RMSE PL: 0.5741 | LR: 5.0e-04
# Epoch 25/100 | Train Loss: 0.4760 | Val Loss: 0.4065 | MAE H2O: 0.3940 | RMSE H2O: 0.5774 | MAE PL: 0.2307 | RMSE PL: 0.5532 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.3960)
# Epoch 26/100 | Train Loss: 0.4717 | Val Loss: 0.3960 | MAE H2O: 0.3933 | RMSE H2O: 0.5792 | MAE PL: 0.2265 | RMSE PL: 0.5431 | LR: 5.0e-04
# Epoch 27/100 | Train Loss: 0.4733 | Val Loss: 0.4599 | MAE H2O: 0.3901 | RMSE H2O: 0.5750 | MAE PL: 0.2643 | RMSE PL: 0.5999 | LR: 5.0e-04
# Epoch 28/100 | Train Loss: 0.4629 | Val Loss: 0.4145 | MAE H2O: 0.3989 | RMSE H2O: 0.5872 | MAE PL: 0.2297 | RMSE PL: 0.5574 | LR: 5.0e-04
# Epoch 29/100 | Train Loss: 0.4688 | Val Loss: 0.3979 | MAE H2O: 0.3937 | RMSE H2O: 0.5789 | MAE PL: 0.2194 | RMSE PL: 0.5449 | LR: 5.0e-04
# Epoch 30/100 | Train Loss: 0.4734 | Val Loss: 0.4183 | MAE H2O: 0.3937 | RMSE H2O: 0.5715 | MAE PL: 0.2385 | RMSE PL: 0.5655 | LR: 5.0e-04
# Epoch 31/100 | Train Loss: 0.4681 | Val Loss: 0.4409 | MAE H2O: 0.3952 | RMSE H2O: 0.5736 | MAE PL: 0.2525 | RMSE PL: 0.5844 | LR: 2.5e-04
# Epoch 32/100 | Train Loss: 0.4568 | Val Loss: 0.4202 | MAE H2O: 0.3897 | RMSE H2O: 0.5718 | MAE PL: 0.2399 | RMSE PL: 0.5671 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3797)
# Epoch 33/100 | Train Loss: 0.4625 | Val Loss: 0.3797 | MAE H2O: 0.3850 | RMSE H2O: 0.5667 | MAE PL: 0.2199 | RMSE PL: 0.5319 | LR: 2.5e-04
# Epoch 34/100 | Train Loss: 0.4626 | Val Loss: 0.3835 | MAE H2O: 0.3936 | RMSE H2O: 0.5770 | MAE PL: 0.2190 | RMSE PL: 0.5322 | LR: 2.5e-04
# Epoch 35/100 | Train Loss: 0.4603 | Val Loss: 0.3854 | MAE H2O: 0.3853 | RMSE H2O: 0.5670 | MAE PL: 0.2242 | RMSE PL: 0.5371 | LR: 2.5e-04
# Epoch 36/100 | Train Loss: 0.4470 | Val Loss: 0.3989 | MAE H2O: 0.3918 | RMSE H2O: 0.5761 | MAE PL: 0.2276 | RMSE PL: 0.5468 | LR: 2.5e-04
# Epoch 37/100 | Train Loss: 0.4559 | Val Loss: 0.4138 | MAE H2O: 0.3961 | RMSE H2O: 0.5833 | MAE PL: 0.2225 | RMSE PL: 0.5579 | LR: 2.5e-04
# Epoch 38/100 | Train Loss: 0.4479 | Val Loss: 0.4254 | MAE H2O: 0.3978 | RMSE H2O: 0.5829 | MAE PL: 0.2334 | RMSE PL: 0.5683 | LR: 1.3e-04
# Epoch 39/100 | Train Loss: 0.4420 | Val Loss: 0.4013 | MAE H2O: 0.3866 | RMSE H2O: 0.5703 | MAE PL: 0.2344 | RMSE PL: 0.5506 | LR: 1.3e-04
# Epoch 40/100 | Train Loss: 0.4450 | Val Loss: 0.3930 | MAE H2O: 0.3970 | RMSE H2O: 0.5842 | MAE PL: 0.2176 | RMSE PL: 0.5388 | LR: 1.3e-04
# Epoch 41/100 | Train Loss: 0.4409 | Val Loss: 0.3829 | MAE H2O: 0.3919 | RMSE H2O: 0.5732 | MAE PL: 0.2198 | RMSE PL: 0.5330 | LR: 1.3e-04
# Epoch 42/100 | Train Loss: 0.4429 | Val Loss: 0.3909 | MAE H2O: 0.3876 | RMSE H2O: 0.5691 | MAE PL: 0.2293 | RMSE PL: 0.5416 | LR: 1.3e-04
# Epoch 43/100 | Train Loss: 0.4357 | Val Loss: 0.3822 | MAE H2O: 0.3942 | RMSE H2O: 0.5766 | MAE PL: 0.2219 | RMSE PL: 0.5311 | LR: 6.3e-05
# Epoch 44/100 | Train Loss: 0.4398 | Val Loss: 0.3871 | MAE H2O: 0.3907 | RMSE H2O: 0.5752 | MAE PL: 0.2215 | RMSE PL: 0.5361 | LR: 6.3e-05
# Epoch 45/100 | Train Loss: 0.4394 | Val Loss: 0.3807 | MAE H2O: 0.3902 | RMSE H2O: 0.5724 | MAE PL: 0.2128 | RMSE PL: 0.5311 | LR: 6.3e-05
# Epoch 46/100 | Train Loss: 0.4349 | Val Loss: 0.3827 | MAE H2O: 0.3867 | RMSE H2O: 0.5696 | MAE PL: 0.2181 | RMSE PL: 0.5338 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3780)
# Epoch 47/100 | Train Loss: 0.4293 | Val Loss: 0.3780 | MAE H2O: 0.3868 | RMSE H2O: 0.5708 | MAE PL: 0.2186 | RMSE PL: 0.5290 | LR: 6.3e-05
# Epoch 48/100 | Train Loss: 0.4354 | Val Loss: 0.3961 | MAE H2O: 0.3951 | RMSE H2O: 0.5767 | MAE PL: 0.2226 | RMSE PL: 0.5440 | LR: 6.3e-05
# Epoch 49/100 | Train Loss: 0.4361 | Val Loss: 0.3806 | MAE H2O: 0.3929 | RMSE H2O: 0.5741 | MAE PL: 0.2219 | RMSE PL: 0.5302 | LR: 6.3e-05
# Epoch 50/100 | Train Loss: 0.4347 | Val Loss: 0.3872 | MAE H2O: 0.3937 | RMSE H2O: 0.5770 | MAE PL: 0.2107 | RMSE PL: 0.5356 | LR: 6.3e-05
# Epoch 51/100 | Train Loss: 0.4296 | Val Loss: 0.3861 | MAE H2O: 0.3872 | RMSE H2O: 0.5728 | MAE PL: 0.2179 | RMSE PL: 0.5360 | LR: 6.3e-05
# Epoch 52/100 | Train Loss: 0.4312 | Val Loss: 0.3836 | MAE H2O: 0.3878 | RMSE H2O: 0.5713 | MAE PL: 0.2172 | RMSE PL: 0.5341 | LR: 3.1e-05
# Epoch 53/100 | Train Loss: 0.4399 | Val Loss: 0.4025 | MAE H2O: 0.3893 | RMSE H2O: 0.5716 | MAE PL: 0.2287 | RMSE PL: 0.5513 | LR: 3.1e-05
# Epoch 54/100 | Train Loss: 0.4266 | Val Loss: 0.3827 | MAE H2O: 0.3877 | RMSE H2O: 0.5685 | MAE PL: 0.2149 | RMSE PL: 0.5341 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3768)
# Epoch 55/100 | Train Loss: 0.4287 | Val Loss: 0.3768 | MAE H2O: 0.3879 | RMSE H2O: 0.5703 | MAE PL: 0.2167 | RMSE PL: 0.5280 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3751)
# Epoch 56/100 | Train Loss: 0.4228 | Val Loss: 0.3751 | MAE H2O: 0.3860 | RMSE H2O: 0.5691 | MAE PL: 0.2179 | RMSE PL: 0.5268 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3745)
# Epoch 57/100 | Train Loss: 0.4264 | Val Loss: 0.3745 | MAE H2O: 0.3877 | RMSE H2O: 0.5690 | MAE PL: 0.2064 | RMSE PL: 0.5262 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3738)
# Epoch 58/100 | Train Loss: 0.4263 | Val Loss: 0.3738 | MAE H2O: 0.3902 | RMSE H2O: 0.5728 | MAE PL: 0.2034 | RMSE PL: 0.5244 | LR: 3.1e-05
# Epoch 59/100 | Train Loss: 0.4245 | Val Loss: 0.3775 | MAE H2O: 0.3871 | RMSE H2O: 0.5729 | MAE PL: 0.2043 | RMSE PL: 0.5278 | LR: 3.1e-05
# Epoch 60/100 | Train Loss: 0.4207 | Val Loss: 0.3781 | MAE H2O: 0.3873 | RMSE H2O: 0.5674 | MAE PL: 0.2182 | RMSE PL: 0.5300 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3680)
# Epoch 61/100 | Train Loss: 0.4257 | Val Loss: 0.3680 | MAE H2O: 0.3829 | RMSE H2O: 0.5651 | MAE PL: 0.2086 | RMSE PL: 0.5211 | LR: 3.1e-05
# Epoch 62/100 | Train Loss: 0.4225 | Val Loss: 0.3746 | MAE H2O: 0.3876 | RMSE H2O: 0.5720 | MAE PL: 0.2090 | RMSE PL: 0.5255 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3678)
# Epoch 63/100 | Train Loss: 0.4188 | Val Loss: 0.3678 | MAE H2O: 0.3862 | RMSE H2O: 0.5692 | MAE PL: 0.2072 | RMSE PL: 0.5197 | LR: 3.1e-05
# Epoch 64/100 | Train Loss: 0.4219 | Val Loss: 0.3694 | MAE H2O: 0.3836 | RMSE H2O: 0.5662 | MAE PL: 0.2077 | RMSE PL: 0.5223 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3669)
# Epoch 65/100 | Train Loss: 0.4208 | Val Loss: 0.3669 | MAE H2O: 0.3893 | RMSE H2O: 0.5720 | MAE PL: 0.2048 | RMSE PL: 0.5180 | LR: 3.1e-05
# Epoch 66/100 | Train Loss: 0.4190 | Val Loss: 0.3695 | MAE H2O: 0.3852 | RMSE H2O: 0.5690 | MAE PL: 0.2083 | RMSE PL: 0.5214 | LR: 3.1e-05
# Epoch 67/100 | Train Loss: 0.4237 | Val Loss: 0.3703 | MAE H2O: 0.3877 | RMSE H2O: 0.5686 | MAE PL: 0.2098 | RMSE PL: 0.5222 | LR: 3.1e-05
# Epoch 68/100 | Train Loss: 0.4227 | Val Loss: 0.3900 | MAE H2O: 0.3867 | RMSE H2O: 0.5708 | MAE PL: 0.2194 | RMSE PL: 0.5401 | LR: 3.1e-05
# Epoch 69/100 | Train Loss: 0.4201 | Val Loss: 0.3693 | MAE H2O: 0.3861 | RMSE H2O: 0.5677 | MAE PL: 0.2097 | RMSE PL: 0.5215 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3664)
# Epoch 70/100 | Train Loss: 0.4176 | Val Loss: 0.3664 | MAE H2O: 0.3826 | RMSE H2O: 0.5656 | MAE PL: 0.2070 | RMSE PL: 0.5196 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3641)
# Epoch 71/100 | Train Loss: 0.4173 | Val Loss: 0.3641 | MAE H2O: 0.3798 | RMSE H2O: 0.5617 | MAE PL: 0.2083 | RMSE PL: 0.5187 | LR: 3.1e-05
# Epoch 72/100 | Train Loss: 0.4219 | Val Loss: 0.3773 | MAE H2O: 0.3869 | RMSE H2O: 0.5723 | MAE PL: 0.2068 | RMSE PL: 0.5278 | LR: 3.1e-05
# Epoch 73/100 | Train Loss: 0.4217 | Val Loss: 0.3789 | MAE H2O: 0.3923 | RMSE H2O: 0.5755 | MAE PL: 0.2016 | RMSE PL: 0.5283 | LR: 3.1e-05
# Epoch 74/100 | Train Loss: 0.4224 | Val Loss: 0.3705 | MAE H2O: 0.3876 | RMSE H2O: 0.5674 | MAE PL: 0.2086 | RMSE PL: 0.5229 | LR: 3.1e-05
# Epoch 75/100 | Train Loss: 0.4197 | Val Loss: 0.3667 | MAE H2O: 0.3826 | RMSE H2O: 0.5634 | MAE PL: 0.2061 | RMSE PL: 0.5205 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3630)
# Epoch 76/100 | Train Loss: 0.4167 | Val Loss: 0.3630 | MAE H2O: 0.3811 | RMSE H2O: 0.5642 | MAE PL: 0.1981 | RMSE PL: 0.5168 | LR: 3.1e-05
# Epoch 77/100 | Train Loss: 0.4152 | Val Loss: 0.3644 | MAE H2O: 0.3817 | RMSE H2O: 0.5644 | MAE PL: 0.2024 | RMSE PL: 0.5180 | LR: 3.1e-05
# Epoch 78/100 | Train Loss: 0.4199 | Val Loss: 0.3641 | MAE H2O: 0.3828 | RMSE H2O: 0.5638 | MAE PL: 0.2055 | RMSE PL: 0.5179 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3620)
# Epoch 79/100 | Train Loss: 0.4133 | Val Loss: 0.3620 | MAE H2O: 0.3816 | RMSE H2O: 0.5649 | MAE PL: 0.2019 | RMSE PL: 0.5156 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3619)
# Epoch 80/100 | Train Loss: 0.4140 | Val Loss: 0.3619 | MAE H2O: 0.3795 | RMSE H2O: 0.5626 | MAE PL: 0.2033 | RMSE PL: 0.5161 | LR: 3.1e-05
# Epoch 81/100 | Train Loss: 0.4195 | Val Loss: 0.3819 | MAE H2O: 0.3823 | RMSE H2O: 0.5638 | MAE PL: 0.2155 | RMSE PL: 0.5348 | LR: 3.1e-05
# Epoch 82/100 | Train Loss: 0.4178 | Val Loss: 0.3627 | MAE H2O: 0.3810 | RMSE H2O: 0.5614 | MAE PL: 0.2059 | RMSE PL: 0.5173 | LR: 3.1e-05
# Epoch 83/100 | Train Loss: 0.4187 | Val Loss: 0.3660 | MAE H2O: 0.3845 | RMSE H2O: 0.5652 | MAE PL: 0.2020 | RMSE PL: 0.5193 | LR: 3.1e-05
# Epoch 84/100 | Train Loss: 0.4177 | Val Loss: 0.3717 | MAE H2O: 0.3802 | RMSE H2O: 0.5656 | MAE PL: 0.2046 | RMSE PL: 0.5246 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3609)
# Epoch 85/100 | Train Loss: 0.4194 | Val Loss: 0.3609 | MAE H2O: 0.3784 | RMSE H2O: 0.5607 | MAE PL: 0.1979 | RMSE PL: 0.5158 | LR: 3.1e-05
# Epoch 86/100 | Train Loss: 0.4159 | Val Loss: 0.3652 | MAE H2O: 0.3883 | RMSE H2O: 0.5718 | MAE PL: 0.2072 | RMSE PL: 0.5163 | LR: 3.1e-05
# Epoch 87/100 | Train Loss: 0.4148 | Val Loss: 0.3684 | MAE H2O: 0.3816 | RMSE H2O: 0.5627 | MAE PL: 0.2047 | RMSE PL: 0.5224 | LR: 3.1e-05
# Epoch 88/100 | Train Loss: 0.4142 | Val Loss: 0.3629 | MAE H2O: 0.3778 | RMSE H2O: 0.5590 | MAE PL: 0.2019 | RMSE PL: 0.5183 | LR: 3.1e-05
# Epoch 89/100 | Train Loss: 0.4186 | Val Loss: 0.3654 | MAE H2O: 0.3790 | RMSE H2O: 0.5587 | MAE PL: 0.2071 | RMSE PL: 0.5208 | LR: 3.1e-05
# Epoch 90/100 | Train Loss: 0.4127 | Val Loss: 0.3620 | MAE H2O: 0.3834 | RMSE H2O: 0.5650 | MAE PL: 0.2036 | RMSE PL: 0.5154 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3593)
# Epoch 91/100 | Train Loss: 0.4191 | Val Loss: 0.3593 | MAE H2O: 0.3798 | RMSE H2O: 0.5619 | MAE PL: 0.1972 | RMSE PL: 0.5139 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3558)
# Epoch 92/100 | Train Loss: 0.4143 | Val Loss: 0.3558 | MAE H2O: 0.3777 | RMSE H2O: 0.5566 | MAE PL: 0.1952 | RMSE PL: 0.5122 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3548)
# Epoch 93/100 | Train Loss: 0.4079 | Val Loss: 0.3548 | MAE H2O: 0.3745 | RMSE H2O: 0.5553 | MAE PL: 0.2006 | RMSE PL: 0.5116 | LR: 1.6e-05
# Epoch 94/100 | Train Loss: 0.4105 | Val Loss: 0.3721 | MAE H2O: 0.3745 | RMSE H2O: 0.5582 | MAE PL: 0.2114 | RMSE PL: 0.5273 | LR: 1.6e-05
# Epoch 95/100 | Train Loss: 0.4074 | Val Loss: 0.3680 | MAE H2O: 0.3833 | RMSE H2O: 0.5660 | MAE PL: 0.2115 | RMSE PL: 0.5209 | LR: 1.6e-05
# Epoch 96/100 | Train Loss: 0.4091 | Val Loss: 0.3606 | MAE H2O: 0.3782 | RMSE H2O: 0.5584 | MAE PL: 0.1979 | RMSE PL: 0.5162 | LR: 1.6e-05
# Epoch 97/100 | Train Loss: 0.4112 | Val Loss: 0.3561 | MAE H2O: 0.3785 | RMSE H2O: 0.5574 | MAE PL: 0.1935 | RMSE PL: 0.5121 | LR: 1.6e-05
# Epoch 98/100 | Train Loss: 0.4105 | Val Loss: 0.3585 | MAE H2O: 0.3736 | RMSE H2O: 0.5537 | MAE PL: 0.2034 | RMSE PL: 0.5157 | LR: 7.8e-06
# Epoch 99/100 | Train Loss: 0.4128 | Val Loss: 0.3557 | MAE H2O: 0.3764 | RMSE H2O: 0.5560 | MAE PL: 0.1965 | RMSE PL: 0.5123 | LR: 7.8e-06
# Epoch 100/100 | Train Loss: 0.4063 | Val Loss: 0.3586 | MAE H2O: 0.3778 | RMSE H2O: 0.5578 | MAE PL: 0.1977 | RMSE PL: 0.5146 | LR: 7.8e-06

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correct unpacking from evaluate
(y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl) = evaluate(model, test_loader)

# Concatenate outputs
y_pred_test_scaled = np.concatenate([y_pred_h2o, y_pred_pl], axis=1)
y_true_test_scaled = np.concatenate([y_true_h2o, y_true_pl], axis=1)

# Inverse transform
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_true_test = scaler_y.inverse_transform(y_true_test_scaled)

# Split again
y_pred_h2o = y_pred_test[:, :67]
y_pred_pl  = y_pred_test[:, 67:]

y_true_h2o = y_true_test[:, :67]
y_true_pl  = y_true_test[:, 67:]

# Optionally concatenate to compute overall metrics
y_true_test = np.concatenate([y_true_pl, y_true_h2o], axis=1)
y_pred_test = np.concatenate([y_pred_pl, y_pred_h2o], axis=1)

# Compute test metrics
test_mae = mean_absolute_error(y_true_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"\n✅ Test MAE:  {test_mae:.4f}")
print(f"✅ Test RMSE: {test_rmse:.4f}")

# You can also compute them separately:
mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

print(f"\n🌊 H2O  → MAE: {mae_h2o:.4f} | RMSE: {rmse_h2o:.4f}")
print(f"📉 PL   → MAE: {mae_pl:.4f} | RMSE: {rmse_pl:.4f}")
# Out:
# ✅ Test MAE:  1.4242
# ✅ Test RMSE: 4.9900
#
# 🌊 H2O  → MAE: 0.0005 | RMSE: 0.0012
# 📉 PL   → MAE: 2.8479 | RMSE: 7.0569

# %%
output_index = 120  # index within concatenated output (0–133)

plt.figure(figsize=(10, 5))
plt.plot(y_true_test[:, output_index], label='True', alpha=0.7)
plt.plot(y_pred_test[:, output_index], label='Predicted', alpha=0.7)
plt.title(f"True vs Predicted - Output #{output_index}")
plt.xlabel("Sample index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose a sample index
i = 120

# Extract profiles for test sample i
pl_profile_true = y_true_pl[i]
h2o_profile_true = y_true_h2o[i]

pl_profile_pred = y_pred_pl[i]
h2o_profile_pred = y_pred_h2o[i]

# Plot profile
plt.figure(figsize=(7, 6))
plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
plt.gca().invert_yaxis()
plt.xlabel("H2O content [vmr]")
plt.ylabel("Pressure Layer [mbar]")
#plt.ylim(0, 1000)
plt.title("H2O content vs Pressure Level")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for i in range(3):
    pl_profile_true = y_true_pl[i]
    h2o_profile_true = y_true_h2o[i]
    pl_profile_pred = y_pred_pl[i]
    h2o_profile_pred = y_pred_h2o[i]

    plt.figure(figsize=(7, 6))
    plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
    plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
    plt.gca().invert_yaxis()
    plt.xlabel("H2O content [vmr]")
    plt.ylabel("Pressure Layer [mbar]")
    #plt.ylim(0, 1000)
    plt.title(f"H2O vs PL — Test Sample #{i}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#torch.save(model.state_dict(), save_path)

# %%
save_path_final = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model13_final.pth'
torch.save(model.state_dict(), save_path_final)
