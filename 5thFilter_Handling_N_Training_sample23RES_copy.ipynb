# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0'
input_pkl_path_v1 = os.path.join(data_dir, 'input_nn_ver1.pkl')
#input_pkl_path_v2 = os.path.join(data_dir, 'input_nn_ver2.pkl')

# %%
df = pd.read_pickle(input_pkl_path_v1)
#df = pd.read_pickle(input_pkl_path_v2)

# %% [markdown]
# **------------------NOISE ADDING----------------------**

# %%
def add_noise(tsky, trx=75.0, snr=1000.0):
    tsys = trx + tsky
    tnoise = tsys / snr
    tcal = tsky + tnoise * np.random.standard_normal(tsky.shape)
    return tcal

# %%
original_spectrum = np.array(df['SPECTRA_Tb[K]'].iloc[0])

# %%
frequencies = np.linspace(20.0, 26.0, len(original_spectrum))

# %%
noisy_spectrum = add_noise(original_spectrum)

# %%
df['SPECTRA_Tb[K]_NOISY'] = df['SPECTRA_Tb[K]']

# %% [markdown]
# **TRANING WAY 1: USING DIFFERENT COLUMNS BETWEEN PL AND H2O**

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['SPECTRA_Tb[K]_NOISY'].tolist())
PL = np.array(df['PL[mbar]'].tolist())
H2O = np.array(df['H2O[vmr]'].tolist())
Y = np.concatenate([H2O, PL], axis=1)

# %%
print(H2O.shape, PL.shape)
# Out:
# (21024, 67) (21024, 67)

# %%
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.4, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)

# %%
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **SECOND FRAMEWORK TORCH**

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **-NORMALIZATION-**

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_val_scaled = scaler.transform(X_val)
#X_test_scaled = scaler.transform(X_test)
X_train = scaler_x.fit_transform(X_train)
X_val = scaler_x.transform(X_val)
X_test = scaler_x.transform(X_test)

# %%
scaler_y = StandardScaler()
Y_train = scaler_y.fit_transform(Y_train)
Y_val   = scaler_y.transform(Y_val)
Y_test  = scaler_y.transform(Y_test)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **-----------------------**

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
Y_val   = torch.tensor(Y_val, dtype=torch.float32)
X_test  = torch.tensor(X_test, dtype=torch.float32)
Y_test  = torch.tensor(Y_test, dtype=torch.float32)

# %%
batch_size = 64

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds  = TensorDataset(X_test, Y_test)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, out_features, dropout=0.2):
        super(ResidualBlock, self).__init__()
        self.linear = nn.Linear(in_features, out_features)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

        # Project input if dimensions don’t match
        self.shortcut = nn.Identity()
        if in_features != out_features:
            self.shortcut = nn.Linear(in_features, out_features)

    def forward(self, x):
        identity = self.shortcut(x)
        out = self.linear(x)
        out = self.relu(out)
        out = self.dropout(out)
        return identity + out  # Residual connection

# %%
class PedroSplitMLPResidual(nn.Module):
    def __init__(self):
        super(PedroSplitMLPResidual, self).__init__()
        self.fc_in = nn.Linear(12001, 1024)
        self.dropout_in = nn.Dropout(0.2)

        # Residual blocks
        self.res1 = ResidualBlock(1024, 512, dropout=0.2)
        self.res2 = ResidualBlock(512, 256, dropout=0.2)
        self.res3 = ResidualBlock(256, 128, dropout=0.2)

        # Output heads
        self.h2o_head = nn.Linear(128, 67)
        self.pl_head = nn.Linear(128, 67)

    def forward(self, x):
        x = torch.relu(self.fc_in(x))
        x = self.dropout_in(x)

        x = self.res1(x)
        x = self.res2(x)
        x = self.res3(x)

        h2o_out = self.h2o_head(x)
        pl_out = self.pl_head(x)
        return h2o_out, pl_out

model = PedroSplitMLPResidual()

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super(WeightedMSELoss, self).__init__()
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def forward(self, pred, target):
        diff = pred - target
        weighted_diff = diff * self.weights
        loss = torch.mean(weighted_diff ** 2)
        return loss

def smoothness_penalty(h2o_pred, alpha):
    diff = h2o_pred[:, 1:] - h2o_pred[:, :-1]
    return alpha * torch.mean(diff ** 2)

# Construct weights to emphasize lower pressures (higher in atmosphere)
n_levels = 67
pl_weights = np.linspace(1.0, 0.5, n_levels)      # Normal weights for PL
h2o_weights = np.logspace(np.log10(2.0), np.log10(0.8), n_levels)     # Emphasize high-altitude H2O, modified for higher-pressure performance

pl_weights_tensor = torch.tensor(pl_weights, dtype=torch.float32)
h2o_weights_tensor = torch.tensor(h2o_weights, dtype=torch.float32)

combined_weights = np.concatenate([pl_weights, h2o_weights])
criterion_h2o = WeightedMSELoss(weights=h2o_weights_tensor)
criterion_pl  = WeightedMSELoss(weights=pl_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
# Out:
# /tmp/ipython-input-26-2966828005.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.weights = torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, loader, val_loader, criterion_h2o, criterion_pl, optimizer, epochs, save_path, alpha, lambda_h2o):
    train_losses, val_losses = [], []
    val_mae_list, val_rmse_list = [], []

    best_val_loss = float('inf')
    patience = 10
    counter = 0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        for xb, yb in loader:
            optimizer.zero_grad()

            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            loss_h2o = criterion_h2o(h2o_pred, h2o_target)
            loss_pl = criterion_pl(pl_pred, pl_target)
            smooth_loss = smoothness_penalty(h2o_pred, alpha=alpha)

            loss = lambda_h2o * loss_h2o + loss_pl + smooth_loss
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(loader))

        # VALIDATION
        model.eval()
        val_loss_total = 0
        y_true_h2o, y_pred_h2o = [], []
        y_true_pl, y_pred_pl = [], []

        with torch.no_grad():
            for xb, yb in val_loader:
                h2o_pred, pl_pred = model(xb)
                h2o_target = yb[:, :n_levels]
                pl_target = yb[:, n_levels:]

                loss_h2o_val = criterion_h2o(h2o_pred, h2o_target)
                loss_pl_val = criterion_pl(pl_pred, pl_target)
                smooth_loss_val = smoothness_penalty(h2o_pred, alpha=alpha)

                batch_val_loss = lambda_h2o * loss_h2o_val + loss_pl_val + smooth_loss_val
                val_loss_total += batch_val_loss.item()

                y_true_h2o.append(h2o_target.cpu().numpy())
                y_pred_h2o.append(h2o_pred.cpu().numpy())

                y_true_pl.append(pl_target.cpu().numpy())
                y_pred_pl.append(pl_pred.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_losses.append(val_loss)

        y_true_h2o = np.concatenate(y_true_h2o, axis=0)
        y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

        y_true_pl = np.concatenate(y_true_pl, axis=0)
        y_pred_pl = np.concatenate(y_pred_pl, axis=0)

        # METRICS
        val_mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
        val_rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

        val_mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
        val_rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

        val_mae_list.append((val_mae_h2o, val_mae_pl))
        val_rmse_list.append((val_rmse_h2o, val_rmse_pl))

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        # EARLY STOPPING
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), save_path)
            counter = 0
            print(f"✅ Model improved and saved (val_loss = {best_val_loss:.4f})")
        else:
            counter += 1
            if counter >= patience:
                print(f"⛔ Early stopping at epoch {epoch+1}")
                break

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f} | "
              f"MAE H2O: {val_mae_h2o:.4f} | RMSE H2O: {val_rmse_h2o:.4f} | "
              f"MAE PL: {val_mae_pl:.4f} | RMSE PL: {val_rmse_pl:.4f} | LR: {current_lr:.1e}")

    model.load_state_dict(torch.load(save_path))
    return train_losses, val_losses, val_mae_list, val_rmse_list

# %%
def evaluate(model, loader):
    model.eval()
    y_true_h2o, y_pred_h2o = [], []
    y_true_pl, y_pred_pl = [], []

    with torch.no_grad():
        for xb, yb in loader:
            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            y_true_h2o.append(h2o_target.cpu().numpy())
            y_pred_h2o.append(h2o_pred.cpu().numpy())

            y_true_pl.append(pl_target.cpu().numpy())
            y_pred_pl.append(pl_pred.cpu().numpy())

    y_true_h2o = np.concatenate(y_true_h2o, axis=0)
    y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

    y_true_pl = np.concatenate(y_true_pl, axis=0)
    y_pred_pl = np.concatenate(y_pred_pl, axis=0)

    return (y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl)

# %%
save_path = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model23RES.pth'

# %%
epochs = 300
alpha = 0.01  # Regularization strength for smoothness penalty
lambda_h2o=0.3
train_losses, val_losses, val_mae, val_rmse = train(
    model,
    train_loader,
    val_loader,
    criterion_h2o,
    criterion_pl,
    optimizer,
    epochs,
    save_path=save_path,
    alpha=alpha,
    lambda_h2o=lambda_h2o
)
# Out:
# ✅ Model improved and saved (val_loss = 0.5903)
# Epoch 1/300 | Train Loss: 0.8817 | Val Loss: 0.5903 | MAE H2O: 0.4931 | RMSE H2O: 0.6767 | MAE PL: 0.3847 | RMSE PL: 0.7144 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5665)
# Epoch 2/300 | Train Loss: 0.5883 | Val Loss: 0.5665 | MAE H2O: 0.4811 | RMSE H2O: 0.6625 | MAE PL: 0.3414 | RMSE PL: 0.6993 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5445)
# Epoch 3/300 | Train Loss: 0.5449 | Val Loss: 0.5445 | MAE H2O: 0.4797 | RMSE H2O: 0.6655 | MAE PL: 0.3030 | RMSE PL: 0.6468 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4831)
# Epoch 4/300 | Train Loss: 0.5370 | Val Loss: 0.4831 | MAE H2O: 0.4379 | RMSE H2O: 0.6209 | MAE PL: 0.3146 | RMSE PL: 0.6215 | LR: 5.0e-04
# Epoch 5/300 | Train Loss: 0.5231 | Val Loss: 0.4838 | MAE H2O: 0.4260 | RMSE H2O: 0.6119 | MAE PL: 0.3034 | RMSE PL: 0.6293 | LR: 5.0e-04
# Epoch 6/300 | Train Loss: 0.5131 | Val Loss: 0.5301 | MAE H2O: 0.4615 | RMSE H2O: 0.6553 | MAE PL: 0.3128 | RMSE PL: 0.6480 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4705)
# Epoch 7/300 | Train Loss: 0.5074 | Val Loss: 0.4705 | MAE H2O: 0.4230 | RMSE H2O: 0.6105 | MAE PL: 0.2892 | RMSE PL: 0.6147 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4592)
# Epoch 8/300 | Train Loss: 0.5068 | Val Loss: 0.4592 | MAE H2O: 0.4092 | RMSE H2O: 0.5953 | MAE PL: 0.2730 | RMSE PL: 0.6110 | LR: 5.0e-04
# Epoch 9/300 | Train Loss: 0.4983 | Val Loss: 0.4791 | MAE H2O: 0.4370 | RMSE H2O: 0.6068 | MAE PL: 0.3183 | RMSE PL: 0.6368 | LR: 5.0e-04
# Epoch 10/300 | Train Loss: 0.4960 | Val Loss: 0.4807 | MAE H2O: 0.4216 | RMSE H2O: 0.6055 | MAE PL: 0.2960 | RMSE PL: 0.6420 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4542)
# Epoch 11/300 | Train Loss: 0.4910 | Val Loss: 0.4542 | MAE H2O: 0.4195 | RMSE H2O: 0.6038 | MAE PL: 0.2776 | RMSE PL: 0.5943 | LR: 5.0e-04
# Epoch 12/300 | Train Loss: 0.4909 | Val Loss: 0.4613 | MAE H2O: 0.4203 | RMSE H2O: 0.6053 | MAE PL: 0.2609 | RMSE PL: 0.5925 | LR: 5.0e-04
# Epoch 13/300 | Train Loss: 0.4813 | Val Loss: 0.4915 | MAE H2O: 0.4232 | RMSE H2O: 0.6194 | MAE PL: 0.2778 | RMSE PL: 0.6102 | LR: 5.0e-04
# Epoch 14/300 | Train Loss: 0.4884 | Val Loss: 0.4783 | MAE H2O: 0.4390 | RMSE H2O: 0.6216 | MAE PL: 0.3136 | RMSE PL: 0.6065 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4463)
# Epoch 15/300 | Train Loss: 0.4906 | Val Loss: 0.4463 | MAE H2O: 0.4117 | RMSE H2O: 0.5955 | MAE PL: 0.2713 | RMSE PL: 0.5934 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4417)
# Epoch 16/300 | Train Loss: 0.4813 | Val Loss: 0.4417 | MAE H2O: 0.4077 | RMSE H2O: 0.5933 | MAE PL: 0.2588 | RMSE PL: 0.5808 | LR: 5.0e-04
# Epoch 17/300 | Train Loss: 0.4829 | Val Loss: 0.4863 | MAE H2O: 0.4550 | RMSE H2O: 0.6388 | MAE PL: 0.3017 | RMSE PL: 0.6145 | LR: 5.0e-04
# Epoch 18/300 | Train Loss: 0.4809 | Val Loss: 0.4535 | MAE H2O: 0.4287 | RMSE H2O: 0.6048 | MAE PL: 0.2773 | RMSE PL: 0.5852 | LR: 5.0e-04
# Epoch 19/300 | Train Loss: 0.4742 | Val Loss: 0.4463 | MAE H2O: 0.4264 | RMSE H2O: 0.6044 | MAE PL: 0.2770 | RMSE PL: 0.5822 | LR: 5.0e-04
# Epoch 20/300 | Train Loss: 0.4794 | Val Loss: 0.4703 | MAE H2O: 0.4266 | RMSE H2O: 0.6026 | MAE PL: 0.2885 | RMSE PL: 0.6216 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4361)
# Epoch 21/300 | Train Loss: 0.4763 | Val Loss: 0.4361 | MAE H2O: 0.4113 | RMSE H2O: 0.5901 | MAE PL: 0.2729 | RMSE PL: 0.5775 | LR: 5.0e-04
# Epoch 22/300 | Train Loss: 0.4738 | Val Loss: 0.4923 | MAE H2O: 0.4155 | RMSE H2O: 0.6130 | MAE PL: 0.2897 | RMSE PL: 0.6450 | LR: 5.0e-04
# Epoch 23/300 | Train Loss: 0.4717 | Val Loss: 0.4603 | MAE H2O: 0.4063 | RMSE H2O: 0.5983 | MAE PL: 0.2602 | RMSE PL: 0.6046 | LR: 5.0e-04
# Epoch 24/300 | Train Loss: 0.4706 | Val Loss: 0.4383 | MAE H2O: 0.4195 | RMSE H2O: 0.6047 | MAE PL: 0.2629 | RMSE PL: 0.5694 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4359)
# Epoch 25/300 | Train Loss: 0.4658 | Val Loss: 0.4359 | MAE H2O: 0.4215 | RMSE H2O: 0.5999 | MAE PL: 0.2504 | RMSE PL: 0.5668 | LR: 5.0e-04
# Epoch 26/300 | Train Loss: 0.4689 | Val Loss: 0.4489 | MAE H2O: 0.4125 | RMSE H2O: 0.5976 | MAE PL: 0.2650 | RMSE PL: 0.5817 | LR: 5.0e-04
# Epoch 27/300 | Train Loss: 0.4659 | Val Loss: 0.4470 | MAE H2O: 0.4185 | RMSE H2O: 0.6005 | MAE PL: 0.2460 | RMSE PL: 0.5785 | LR: 5.0e-04
# Epoch 28/300 | Train Loss: 0.4676 | Val Loss: 0.4548 | MAE H2O: 0.3998 | RMSE H2O: 0.5908 | MAE PL: 0.2930 | RMSE PL: 0.6137 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4282)
# Epoch 29/300 | Train Loss: 0.4687 | Val Loss: 0.4282 | MAE H2O: 0.3956 | RMSE H2O: 0.5814 | MAE PL: 0.2513 | RMSE PL: 0.5745 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4279)
# Epoch 30/300 | Train Loss: 0.4656 | Val Loss: 0.4279 | MAE H2O: 0.3988 | RMSE H2O: 0.5868 | MAE PL: 0.2388 | RMSE PL: 0.5625 | LR: 5.0e-04
# Epoch 31/300 | Train Loss: 0.4648 | Val Loss: 0.4422 | MAE H2O: 0.4070 | RMSE H2O: 0.5925 | MAE PL: 0.2703 | RMSE PL: 0.5831 | LR: 5.0e-04
# Epoch 32/300 | Train Loss: 0.4622 | Val Loss: 0.4485 | MAE H2O: 0.4232 | RMSE H2O: 0.6046 | MAE PL: 0.2723 | RMSE PL: 0.5760 | LR: 5.0e-04
# Epoch 33/300 | Train Loss: 0.4623 | Val Loss: 0.4521 | MAE H2O: 0.4088 | RMSE H2O: 0.6009 | MAE PL: 0.2470 | RMSE PL: 0.5765 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4252)
# Epoch 34/300 | Train Loss: 0.4601 | Val Loss: 0.4252 | MAE H2O: 0.4073 | RMSE H2O: 0.5857 | MAE PL: 0.2610 | RMSE PL: 0.5651 | LR: 5.0e-04
# Epoch 35/300 | Train Loss: 0.4626 | Val Loss: 0.4457 | MAE H2O: 0.4149 | RMSE H2O: 0.5941 | MAE PL: 0.2777 | RMSE PL: 0.5885 | LR: 5.0e-04
# Epoch 36/300 | Train Loss: 0.4572 | Val Loss: 0.4391 | MAE H2O: 0.3972 | RMSE H2O: 0.5842 | MAE PL: 0.2679 | RMSE PL: 0.5902 | LR: 5.0e-04
# Epoch 37/300 | Train Loss: 0.4602 | Val Loss: 0.4678 | MAE H2O: 0.4098 | RMSE H2O: 0.5977 | MAE PL: 0.2646 | RMSE PL: 0.6173 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4205)
# Epoch 38/300 | Train Loss: 0.4595 | Val Loss: 0.4205 | MAE H2O: 0.3989 | RMSE H2O: 0.5818 | MAE PL: 0.2588 | RMSE PL: 0.5617 | LR: 5.0e-04
# Epoch 39/300 | Train Loss: 0.4558 | Val Loss: 0.4261 | MAE H2O: 0.3965 | RMSE H2O: 0.5862 | MAE PL: 0.2456 | RMSE PL: 0.5605 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4158)
# Epoch 40/300 | Train Loss: 0.4577 | Val Loss: 0.4158 | MAE H2O: 0.4016 | RMSE H2O: 0.5772 | MAE PL: 0.2373 | RMSE PL: 0.5539 | LR: 5.0e-04
# Epoch 41/300 | Train Loss: 0.4605 | Val Loss: 0.4810 | MAE H2O: 0.4096 | RMSE H2O: 0.5961 | MAE PL: 0.2799 | RMSE PL: 0.6353 | LR: 5.0e-04
# Epoch 42/300 | Train Loss: 0.4579 | Val Loss: 0.4649 | MAE H2O: 0.4149 | RMSE H2O: 0.6063 | MAE PL: 0.2687 | RMSE PL: 0.5866 | LR: 5.0e-04
# Epoch 43/300 | Train Loss: 0.4565 | Val Loss: 0.4396 | MAE H2O: 0.4200 | RMSE H2O: 0.6058 | MAE PL: 0.2445 | RMSE PL: 0.5715 | LR: 5.0e-04
# Epoch 44/300 | Train Loss: 0.4521 | Val Loss: 0.4302 | MAE H2O: 0.4035 | RMSE H2O: 0.5898 | MAE PL: 0.2588 | RMSE PL: 0.5620 | LR: 5.0e-04
# Epoch 45/300 | Train Loss: 0.4574 | Val Loss: 0.4232 | MAE H2O: 0.3926 | RMSE H2O: 0.5790 | MAE PL: 0.2476 | RMSE PL: 0.5666 | LR: 5.0e-04
# Epoch 46/300 | Train Loss: 0.4531 | Val Loss: 0.4484 | MAE H2O: 0.3948 | RMSE H2O: 0.5958 | MAE PL: 0.2367 | RMSE PL: 0.5779 | LR: 2.5e-04
# Epoch 47/300 | Train Loss: 0.4411 | Val Loss: 0.4342 | MAE H2O: 0.3853 | RMSE H2O: 0.5796 | MAE PL: 0.2440 | RMSE PL: 0.5815 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4132)
# Epoch 48/300 | Train Loss: 0.4374 | Val Loss: 0.4132 | MAE H2O: 0.3913 | RMSE H2O: 0.5728 | MAE PL: 0.2417 | RMSE PL: 0.5573 | LR: 2.5e-04
# Epoch 49/300 | Train Loss: 0.4358 | Val Loss: 0.4163 | MAE H2O: 0.3894 | RMSE H2O: 0.5776 | MAE PL: 0.2352 | RMSE PL: 0.5550 | LR: 2.5e-04
# Epoch 50/300 | Train Loss: 0.4336 | Val Loss: 0.4140 | MAE H2O: 0.3846 | RMSE H2O: 0.5702 | MAE PL: 0.2329 | RMSE PL: 0.5617 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4087)
# Epoch 51/300 | Train Loss: 0.4359 | Val Loss: 0.4087 | MAE H2O: 0.3890 | RMSE H2O: 0.5719 | MAE PL: 0.2215 | RMSE PL: 0.5466 | LR: 2.5e-04
# Epoch 52/300 | Train Loss: 0.4340 | Val Loss: 0.4113 | MAE H2O: 0.3848 | RMSE H2O: 0.5700 | MAE PL: 0.2275 | RMSE PL: 0.5498 | LR: 2.5e-04
# Epoch 53/300 | Train Loss: 0.4318 | Val Loss: 0.4214 | MAE H2O: 0.3912 | RMSE H2O: 0.5767 | MAE PL: 0.2357 | RMSE PL: 0.5546 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4022)
# Epoch 54/300 | Train Loss: 0.4305 | Val Loss: 0.4022 | MAE H2O: 0.3819 | RMSE H2O: 0.5663 | MAE PL: 0.2283 | RMSE PL: 0.5425 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4017)
# Epoch 55/300 | Train Loss: 0.4286 | Val Loss: 0.4017 | MAE H2O: 0.3774 | RMSE H2O: 0.5597 | MAE PL: 0.2256 | RMSE PL: 0.5502 | LR: 2.5e-04
# Epoch 56/300 | Train Loss: 0.4339 | Val Loss: 0.4174 | MAE H2O: 0.3936 | RMSE H2O: 0.5707 | MAE PL: 0.2473 | RMSE PL: 0.5682 | LR: 2.5e-04
# Epoch 57/300 | Train Loss: 0.4348 | Val Loss: 0.4053 | MAE H2O: 0.3740 | RMSE H2O: 0.5612 | MAE PL: 0.2271 | RMSE PL: 0.5536 | LR: 2.5e-04
# Epoch 58/300 | Train Loss: 0.4290 | Val Loss: 0.4089 | MAE H2O: 0.3745 | RMSE H2O: 0.5608 | MAE PL: 0.2258 | RMSE PL: 0.5597 | LR: 2.5e-04
# Epoch 59/300 | Train Loss: 0.4265 | Val Loss: 0.4231 | MAE H2O: 0.3951 | RMSE H2O: 0.5781 | MAE PL: 0.2485 | RMSE PL: 0.5610 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3963)
# Epoch 60/300 | Train Loss: 0.4273 | Val Loss: 0.3963 | MAE H2O: 0.3816 | RMSE H2O: 0.5627 | MAE PL: 0.2168 | RMSE PL: 0.5347 | LR: 2.5e-04
# Epoch 61/300 | Train Loss: 0.4280 | Val Loss: 0.4082 | MAE H2O: 0.3878 | RMSE H2O: 0.5729 | MAE PL: 0.2252 | RMSE PL: 0.5370 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3935)
# Epoch 62/300 | Train Loss: 0.4290 | Val Loss: 0.3935 | MAE H2O: 0.3749 | RMSE H2O: 0.5583 | MAE PL: 0.2161 | RMSE PL: 0.5346 | LR: 2.5e-04
# Epoch 63/300 | Train Loss: 0.4244 | Val Loss: 0.4040 | MAE H2O: 0.3794 | RMSE H2O: 0.5643 | MAE PL: 0.2228 | RMSE PL: 0.5426 | LR: 2.5e-04
# Epoch 64/300 | Train Loss: 0.4304 | Val Loss: 0.4075 | MAE H2O: 0.3748 | RMSE H2O: 0.5620 | MAE PL: 0.2374 | RMSE PL: 0.5584 | LR: 2.5e-04
# Epoch 65/300 | Train Loss: 0.4288 | Val Loss: 0.3961 | MAE H2O: 0.3816 | RMSE H2O: 0.5627 | MAE PL: 0.2164 | RMSE PL: 0.5337 | LR: 2.5e-04
# Epoch 66/300 | Train Loss: 0.4249 | Val Loss: 0.4147 | MAE H2O: 0.3819 | RMSE H2O: 0.5715 | MAE PL: 0.2303 | RMSE PL: 0.5595 | LR: 2.5e-04
# Epoch 67/300 | Train Loss: 0.4270 | Val Loss: 0.3996 | MAE H2O: 0.3748 | RMSE H2O: 0.5596 | MAE PL: 0.2172 | RMSE PL: 0.5387 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3914)
# Epoch 68/300 | Train Loss: 0.4251 | Val Loss: 0.3914 | MAE H2O: 0.3763 | RMSE H2O: 0.5571 | MAE PL: 0.2183 | RMSE PL: 0.5318 | LR: 2.5e-04
# Epoch 69/300 | Train Loss: 0.4220 | Val Loss: 0.3995 | MAE H2O: 0.3863 | RMSE H2O: 0.5685 | MAE PL: 0.2201 | RMSE PL: 0.5323 | LR: 2.5e-04
# Epoch 70/300 | Train Loss: 0.4258 | Val Loss: 0.3982 | MAE H2O: 0.3809 | RMSE H2O: 0.5623 | MAE PL: 0.2203 | RMSE PL: 0.5367 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3893)
# Epoch 71/300 | Train Loss: 0.4226 | Val Loss: 0.3893 | MAE H2O: 0.3688 | RMSE H2O: 0.5550 | MAE PL: 0.2106 | RMSE PL: 0.5300 | LR: 2.5e-04
# Epoch 72/300 | Train Loss: 0.4228 | Val Loss: 0.4159 | MAE H2O: 0.3783 | RMSE H2O: 0.5754 | MAE PL: 0.2160 | RMSE PL: 0.5433 | LR: 2.5e-04
# Epoch 73/300 | Train Loss: 0.4229 | Val Loss: 0.3983 | MAE H2O: 0.3867 | RMSE H2O: 0.5683 | MAE PL: 0.2154 | RMSE PL: 0.5347 | LR: 2.5e-04
# Epoch 74/300 | Train Loss: 0.4240 | Val Loss: 0.3978 | MAE H2O: 0.3714 | RMSE H2O: 0.5585 | MAE PL: 0.2125 | RMSE PL: 0.5401 | LR: 2.5e-04
# Epoch 75/300 | Train Loss: 0.4210 | Val Loss: 0.3979 | MAE H2O: 0.3748 | RMSE H2O: 0.5612 | MAE PL: 0.2234 | RMSE PL: 0.5399 | LR: 2.5e-04
# Epoch 76/300 | Train Loss: 0.4199 | Val Loss: 0.4002 | MAE H2O: 0.3781 | RMSE H2O: 0.5649 | MAE PL: 0.2236 | RMSE PL: 0.5393 | LR: 2.5e-04
# Epoch 77/300 | Train Loss: 0.4216 | Val Loss: 0.3995 | MAE H2O: 0.3720 | RMSE H2O: 0.5605 | MAE PL: 0.2216 | RMSE PL: 0.5380 | LR: 1.3e-04
# Epoch 78/300 | Train Loss: 0.4090 | Val Loss: 0.3926 | MAE H2O: 0.3712 | RMSE H2O: 0.5552 | MAE PL: 0.2146 | RMSE PL: 0.5283 | LR: 1.3e-04
# Epoch 79/300 | Train Loss: 0.4078 | Val Loss: 0.3916 | MAE H2O: 0.3660 | RMSE H2O: 0.5494 | MAE PL: 0.2190 | RMSE PL: 0.5388 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3797)
# Epoch 80/300 | Train Loss: 0.4056 | Val Loss: 0.3797 | MAE H2O: 0.3636 | RMSE H2O: 0.5474 | MAE PL: 0.2044 | RMSE PL: 0.5197 | LR: 1.3e-04
# Epoch 81/300 | Train Loss: 0.4078 | Val Loss: 0.3869 | MAE H2O: 0.3668 | RMSE H2O: 0.5483 | MAE PL: 0.2174 | RMSE PL: 0.5343 | LR: 1.3e-04
# Epoch 82/300 | Train Loss: 0.4080 | Val Loss: 0.3871 | MAE H2O: 0.3650 | RMSE H2O: 0.5481 | MAE PL: 0.2042 | RMSE PL: 0.5311 | LR: 1.3e-04
# Epoch 83/300 | Train Loss: 0.4105 | Val Loss: 0.3870 | MAE H2O: 0.3653 | RMSE H2O: 0.5495 | MAE PL: 0.2110 | RMSE PL: 0.5303 | LR: 1.3e-04
# Epoch 84/300 | Train Loss: 0.4068 | Val Loss: 0.3818 | MAE H2O: 0.3666 | RMSE H2O: 0.5477 | MAE PL: 0.2035 | RMSE PL: 0.5228 | LR: 1.3e-04
# Epoch 85/300 | Train Loss: 0.4077 | Val Loss: 0.3809 | MAE H2O: 0.3650 | RMSE H2O: 0.5475 | MAE PL: 0.2068 | RMSE PL: 0.5198 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3771)
# Epoch 86/300 | Train Loss: 0.4013 | Val Loss: 0.3771 | MAE H2O: 0.3621 | RMSE H2O: 0.5437 | MAE PL: 0.2023 | RMSE PL: 0.5185 | LR: 1.3e-04
# Epoch 87/300 | Train Loss: 0.4050 | Val Loss: 0.3849 | MAE H2O: 0.3675 | RMSE H2O: 0.5505 | MAE PL: 0.2155 | RMSE PL: 0.5245 | LR: 1.3e-04
# Epoch 88/300 | Train Loss: 0.4029 | Val Loss: 0.3836 | MAE H2O: 0.3646 | RMSE H2O: 0.5504 | MAE PL: 0.2112 | RMSE PL: 0.5265 | LR: 1.3e-04
# Epoch 89/300 | Train Loss: 0.4061 | Val Loss: 0.3835 | MAE H2O: 0.3688 | RMSE H2O: 0.5501 | MAE PL: 0.2055 | RMSE PL: 0.5250 | LR: 1.3e-04
# Epoch 90/300 | Train Loss: 0.4032 | Val Loss: 0.3788 | MAE H2O: 0.3605 | RMSE H2O: 0.5453 | MAE PL: 0.2058 | RMSE PL: 0.5197 | LR: 1.3e-04
# Epoch 91/300 | Train Loss: 0.4041 | Val Loss: 0.3801 | MAE H2O: 0.3630 | RMSE H2O: 0.5455 | MAE PL: 0.2038 | RMSE PL: 0.5235 | LR: 1.3e-04
# Epoch 92/300 | Train Loss: 0.4011 | Val Loss: 0.3895 | MAE H2O: 0.3647 | RMSE H2O: 0.5464 | MAE PL: 0.2167 | RMSE PL: 0.5393 | LR: 6.3e-05
# Epoch 93/300 | Train Loss: 0.3981 | Val Loss: 0.3793 | MAE H2O: 0.3656 | RMSE H2O: 0.5438 | MAE PL: 0.2040 | RMSE PL: 0.5235 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3737)
# Epoch 94/300 | Train Loss: 0.3945 | Val Loss: 0.3737 | MAE H2O: 0.3555 | RMSE H2O: 0.5388 | MAE PL: 0.2003 | RMSE PL: 0.5157 | LR: 6.3e-05
# Epoch 95/300 | Train Loss: 0.3921 | Val Loss: 0.3747 | MAE H2O: 0.3577 | RMSE H2O: 0.5392 | MAE PL: 0.2057 | RMSE PL: 0.5183 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3728)
# Epoch 96/300 | Train Loss: 0.3947 | Val Loss: 0.3728 | MAE H2O: 0.3565 | RMSE H2O: 0.5366 | MAE PL: 0.2036 | RMSE PL: 0.5198 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3702)
# Epoch 97/300 | Train Loss: 0.3937 | Val Loss: 0.3702 | MAE H2O: 0.3525 | RMSE H2O: 0.5359 | MAE PL: 0.1964 | RMSE PL: 0.5139 | LR: 6.3e-05
# Epoch 98/300 | Train Loss: 0.3967 | Val Loss: 0.3821 | MAE H2O: 0.3570 | RMSE H2O: 0.5442 | MAE PL: 0.1977 | RMSE PL: 0.5237 | LR: 6.3e-05
# Epoch 99/300 | Train Loss: 0.3944 | Val Loss: 0.3766 | MAE H2O: 0.3582 | RMSE H2O: 0.5425 | MAE PL: 0.2026 | RMSE PL: 0.5170 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3700)
# Epoch 100/300 | Train Loss: 0.3924 | Val Loss: 0.3700 | MAE H2O: 0.3525 | RMSE H2O: 0.5366 | MAE PL: 0.1930 | RMSE PL: 0.5130 | LR: 6.3e-05
# Epoch 101/300 | Train Loss: 0.3911 | Val Loss: 0.3761 | MAE H2O: 0.3528 | RMSE H2O: 0.5381 | MAE PL: 0.1985 | RMSE PL: 0.5216 | LR: 6.3e-05
# Epoch 102/300 | Train Loss: 0.3908 | Val Loss: 0.3739 | MAE H2O: 0.3568 | RMSE H2O: 0.5394 | MAE PL: 0.1901 | RMSE PL: 0.5138 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3683)
# Epoch 103/300 | Train Loss: 0.3909 | Val Loss: 0.3683 | MAE H2O: 0.3487 | RMSE H2O: 0.5345 | MAE PL: 0.1943 | RMSE PL: 0.5115 | LR: 6.3e-05
# Epoch 104/300 | Train Loss: 0.3939 | Val Loss: 0.3692 | MAE H2O: 0.3522 | RMSE H2O: 0.5361 | MAE PL: 0.1998 | RMSE PL: 0.5136 | LR: 6.3e-05
# Epoch 105/300 | Train Loss: 0.3923 | Val Loss: 0.3718 | MAE H2O: 0.3531 | RMSE H2O: 0.5361 | MAE PL: 0.1975 | RMSE PL: 0.5172 | LR: 6.3e-05
# Epoch 106/300 | Train Loss: 0.3910 | Val Loss: 0.3689 | MAE H2O: 0.3506 | RMSE H2O: 0.5356 | MAE PL: 0.1942 | RMSE PL: 0.5132 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3682)
# Epoch 107/300 | Train Loss: 0.3918 | Val Loss: 0.3682 | MAE H2O: 0.3511 | RMSE H2O: 0.5343 | MAE PL: 0.1955 | RMSE PL: 0.5127 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3681)
# Epoch 108/300 | Train Loss: 0.3877 | Val Loss: 0.3681 | MAE H2O: 0.3519 | RMSE H2O: 0.5356 | MAE PL: 0.1952 | RMSE PL: 0.5117 | LR: 6.3e-05
# Epoch 109/300 | Train Loss: 0.3879 | Val Loss: 0.3703 | MAE H2O: 0.3560 | RMSE H2O: 0.5398 | MAE PL: 0.1977 | RMSE PL: 0.5104 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3671)
# Epoch 110/300 | Train Loss: 0.3922 | Val Loss: 0.3671 | MAE H2O: 0.3498 | RMSE H2O: 0.5334 | MAE PL: 0.1930 | RMSE PL: 0.5114 | LR: 6.3e-05
# Epoch 111/300 | Train Loss: 0.3899 | Val Loss: 0.3700 | MAE H2O: 0.3523 | RMSE H2O: 0.5359 | MAE PL: 0.1992 | RMSE PL: 0.5157 | LR: 6.3e-05
# Epoch 112/300 | Train Loss: 0.3890 | Val Loss: 0.3725 | MAE H2O: 0.3526 | RMSE H2O: 0.5384 | MAE PL: 0.2003 | RMSE PL: 0.5135 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3647)
# Epoch 113/300 | Train Loss: 0.3908 | Val Loss: 0.3647 | MAE H2O: 0.3521 | RMSE H2O: 0.5324 | MAE PL: 0.1926 | RMSE PL: 0.5093 | LR: 6.3e-05
# Epoch 114/300 | Train Loss: 0.3889 | Val Loss: 0.3698 | MAE H2O: 0.3526 | RMSE H2O: 0.5364 | MAE PL: 0.1954 | RMSE PL: 0.5125 | LR: 6.3e-05
# Epoch 115/300 | Train Loss: 0.3898 | Val Loss: 0.3648 | MAE H2O: 0.3494 | RMSE H2O: 0.5321 | MAE PL: 0.1923 | RMSE PL: 0.5091 | LR: 6.3e-05
# Epoch 116/300 | Train Loss: 0.3885 | Val Loss: 0.3723 | MAE H2O: 0.3559 | RMSE H2O: 0.5393 | MAE PL: 0.1964 | RMSE PL: 0.5131 | LR: 6.3e-05
# Epoch 117/300 | Train Loss: 0.3892 | Val Loss: 0.3687 | MAE H2O: 0.3527 | RMSE H2O: 0.5340 | MAE PL: 0.1967 | RMSE PL: 0.5137 | LR: 6.3e-05
# Epoch 118/300 | Train Loss: 0.3929 | Val Loss: 0.3658 | MAE H2O: 0.3480 | RMSE H2O: 0.5308 | MAE PL: 0.1923 | RMSE PL: 0.5107 | LR: 6.3e-05
# Epoch 119/300 | Train Loss: 0.3879 | Val Loss: 0.3794 | MAE H2O: 0.3580 | RMSE H2O: 0.5401 | MAE PL: 0.2136 | RMSE PL: 0.5278 | LR: 3.1e-05
# Epoch 120/300 | Train Loss: 0.3866 | Val Loss: 0.3654 | MAE H2O: 0.3528 | RMSE H2O: 0.5336 | MAE PL: 0.1904 | RMSE PL: 0.5085 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3627)
# Epoch 121/300 | Train Loss: 0.3829 | Val Loss: 0.3627 | MAE H2O: 0.3470 | RMSE H2O: 0.5307 | MAE PL: 0.1918 | RMSE PL: 0.5067 | LR: 3.1e-05
# Epoch 122/300 | Train Loss: 0.3816 | Val Loss: 0.3652 | MAE H2O: 0.3513 | RMSE H2O: 0.5351 | MAE PL: 0.1894 | RMSE PL: 0.5072 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3610)
# Epoch 123/300 | Train Loss: 0.3828 | Val Loss: 0.3610 | MAE H2O: 0.3451 | RMSE H2O: 0.5284 | MAE PL: 0.1885 | RMSE PL: 0.5056 | LR: 3.1e-05
# Epoch 124/300 | Train Loss: 0.3830 | Val Loss: 0.3615 | MAE H2O: 0.3468 | RMSE H2O: 0.5285 | MAE PL: 0.1915 | RMSE PL: 0.5076 | LR: 3.1e-05
# Epoch 125/300 | Train Loss: 0.3815 | Val Loss: 0.3610 | MAE H2O: 0.3450 | RMSE H2O: 0.5284 | MAE PL: 0.1902 | RMSE PL: 0.5064 | LR: 3.1e-05
# Epoch 126/300 | Train Loss: 0.3804 | Val Loss: 0.3620 | MAE H2O: 0.3454 | RMSE H2O: 0.5283 | MAE PL: 0.1917 | RMSE PL: 0.5082 | LR: 3.1e-05
# Epoch 127/300 | Train Loss: 0.3819 | Val Loss: 0.3643 | MAE H2O: 0.3454 | RMSE H2O: 0.5306 | MAE PL: 0.1948 | RMSE PL: 0.5111 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3602)
# Epoch 128/300 | Train Loss: 0.3843 | Val Loss: 0.3602 | MAE H2O: 0.3436 | RMSE H2O: 0.5268 | MAE PL: 0.1889 | RMSE PL: 0.5063 | LR: 3.1e-05
# Epoch 129/300 | Train Loss: 0.3811 | Val Loss: 0.3612 | MAE H2O: 0.3473 | RMSE H2O: 0.5283 | MAE PL: 0.1924 | RMSE PL: 0.5078 | LR: 3.1e-05
# Epoch 130/300 | Train Loss: 0.3817 | Val Loss: 0.3617 | MAE H2O: 0.3462 | RMSE H2O: 0.5287 | MAE PL: 0.1869 | RMSE PL: 0.5075 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3602)
# Epoch 131/300 | Train Loss: 0.3810 | Val Loss: 0.3602 | MAE H2O: 0.3453 | RMSE H2O: 0.5289 | MAE PL: 0.1856 | RMSE PL: 0.5050 | LR: 3.1e-05
# Epoch 132/300 | Train Loss: 0.3830 | Val Loss: 0.3620 | MAE H2O: 0.3477 | RMSE H2O: 0.5306 | MAE PL: 0.1931 | RMSE PL: 0.5074 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3594)
# Epoch 133/300 | Train Loss: 0.3804 | Val Loss: 0.3594 | MAE H2O: 0.3447 | RMSE H2O: 0.5268 | MAE PL: 0.1864 | RMSE PL: 0.5051 | LR: 3.1e-05
# Epoch 134/300 | Train Loss: 0.3805 | Val Loss: 0.3606 | MAE H2O: 0.3456 | RMSE H2O: 0.5268 | MAE PL: 0.1897 | RMSE PL: 0.5082 | LR: 3.1e-05
# Epoch 135/300 | Train Loss: 0.3823 | Val Loss: 0.3596 | MAE H2O: 0.3456 | RMSE H2O: 0.5271 | MAE PL: 0.1854 | RMSE PL: 0.5054 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3594)
# Epoch 136/300 | Train Loss: 0.3812 | Val Loss: 0.3594 | MAE H2O: 0.3460 | RMSE H2O: 0.5265 | MAE PL: 0.1862 | RMSE PL: 0.5060 | LR: 3.1e-05
# Epoch 137/300 | Train Loss: 0.3797 | Val Loss: 0.3632 | MAE H2O: 0.3453 | RMSE H2O: 0.5276 | MAE PL: 0.1918 | RMSE PL: 0.5118 | LR: 3.1e-05
# Epoch 138/300 | Train Loss: 0.3793 | Val Loss: 0.3597 | MAE H2O: 0.3432 | RMSE H2O: 0.5263 | MAE PL: 0.1897 | RMSE PL: 0.5070 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3588)
# Epoch 139/300 | Train Loss: 0.3806 | Val Loss: 0.3588 | MAE H2O: 0.3440 | RMSE H2O: 0.5260 | MAE PL: 0.1882 | RMSE PL: 0.5067 | LR: 3.1e-05
# Epoch 140/300 | Train Loss: 0.3792 | Val Loss: 0.3627 | MAE H2O: 0.3470 | RMSE H2O: 0.5298 | MAE PL: 0.1940 | RMSE PL: 0.5089 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3583)
# Epoch 141/300 | Train Loss: 0.3791 | Val Loss: 0.3583 | MAE H2O: 0.3434 | RMSE H2O: 0.5264 | MAE PL: 0.1881 | RMSE PL: 0.5053 | LR: 3.1e-05
# Epoch 142/300 | Train Loss: 0.3793 | Val Loss: 0.3587 | MAE H2O: 0.3417 | RMSE H2O: 0.5264 | MAE PL: 0.1874 | RMSE PL: 0.5055 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3578)
# Epoch 143/300 | Train Loss: 0.3802 | Val Loss: 0.3578 | MAE H2O: 0.3450 | RMSE H2O: 0.5261 | MAE PL: 0.1865 | RMSE PL: 0.5040 | LR: 3.1e-05
# Epoch 144/300 | Train Loss: 0.3792 | Val Loss: 0.3608 | MAE H2O: 0.3448 | RMSE H2O: 0.5275 | MAE PL: 0.1926 | RMSE PL: 0.5093 | LR: 3.1e-05
# Epoch 145/300 | Train Loss: 0.3788 | Val Loss: 0.3611 | MAE H2O: 0.3456 | RMSE H2O: 0.5277 | MAE PL: 0.1883 | RMSE PL: 0.5085 | LR: 3.1e-05
# Epoch 146/300 | Train Loss: 0.3784 | Val Loss: 0.3718 | MAE H2O: 0.3505 | RMSE H2O: 0.5360 | MAE PL: 0.1901 | RMSE PL: 0.5136 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3573)
# Epoch 147/300 | Train Loss: 0.3786 | Val Loss: 0.3573 | MAE H2O: 0.3437 | RMSE H2O: 0.5254 | MAE PL: 0.1861 | RMSE PL: 0.5037 | LR: 3.1e-05
# Epoch 148/300 | Train Loss: 0.3786 | Val Loss: 0.3579 | MAE H2O: 0.3423 | RMSE H2O: 0.5252 | MAE PL: 0.1837 | RMSE PL: 0.5042 | LR: 3.1e-05
# Epoch 149/300 | Train Loss: 0.3792 | Val Loss: 0.3598 | MAE H2O: 0.3428 | RMSE H2O: 0.5269 | MAE PL: 0.1884 | RMSE PL: 0.5062 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3569)
# Epoch 150/300 | Train Loss: 0.3780 | Val Loss: 0.3569 | MAE H2O: 0.3426 | RMSE H2O: 0.5252 | MAE PL: 0.1862 | RMSE PL: 0.5034 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3565)
# Epoch 151/300 | Train Loss: 0.3774 | Val Loss: 0.3565 | MAE H2O: 0.3422 | RMSE H2O: 0.5248 | MAE PL: 0.1873 | RMSE PL: 0.5029 | LR: 3.1e-05
# Epoch 152/300 | Train Loss: 0.3767 | Val Loss: 0.3565 | MAE H2O: 0.3438 | RMSE H2O: 0.5238 | MAE PL: 0.1864 | RMSE PL: 0.5046 | LR: 3.1e-05
# Epoch 153/300 | Train Loss: 0.3786 | Val Loss: 0.3615 | MAE H2O: 0.3475 | RMSE H2O: 0.5301 | MAE PL: 0.1935 | RMSE PL: 0.5069 | LR: 3.1e-05
# Epoch 154/300 | Train Loss: 0.3816 | Val Loss: 0.3592 | MAE H2O: 0.3444 | RMSE H2O: 0.5254 | MAE PL: 0.1886 | RMSE PL: 0.5072 | LR: 3.1e-05
# Epoch 155/300 | Train Loss: 0.3782 | Val Loss: 0.3605 | MAE H2O: 0.3419 | RMSE H2O: 0.5266 | MAE PL: 0.1849 | RMSE PL: 0.5071 | LR: 3.1e-05
# Epoch 156/300 | Train Loss: 0.3797 | Val Loss: 0.3623 | MAE H2O: 0.3449 | RMSE H2O: 0.5289 | MAE PL: 0.1870 | RMSE PL: 0.5075 | LR: 3.1e-05
# Epoch 157/300 | Train Loss: 0.3784 | Val Loss: 0.3615 | MAE H2O: 0.3455 | RMSE H2O: 0.5293 | MAE PL: 0.1861 | RMSE PL: 0.5073 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3545)
# Epoch 158/300 | Train Loss: 0.3736 | Val Loss: 0.3545 | MAE H2O: 0.3403 | RMSE H2O: 0.5230 | MAE PL: 0.1822 | RMSE PL: 0.5018 | LR: 1.6e-05
# Epoch 159/300 | Train Loss: 0.3727 | Val Loss: 0.3549 | MAE H2O: 0.3404 | RMSE H2O: 0.5230 | MAE PL: 0.1817 | RMSE PL: 0.5025 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3536)
# Epoch 160/300 | Train Loss: 0.3731 | Val Loss: 0.3536 | MAE H2O: 0.3399 | RMSE H2O: 0.5222 | MAE PL: 0.1824 | RMSE PL: 0.5012 | LR: 1.6e-05
# Epoch 161/300 | Train Loss: 0.3734 | Val Loss: 0.3590 | MAE H2O: 0.3444 | RMSE H2O: 0.5256 | MAE PL: 0.1959 | RMSE PL: 0.5076 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3535)
# Epoch 162/300 | Train Loss: 0.3754 | Val Loss: 0.3535 | MAE H2O: 0.3407 | RMSE H2O: 0.5225 | MAE PL: 0.1826 | RMSE PL: 0.5012 | LR: 1.6e-05
# Epoch 163/300 | Train Loss: 0.3724 | Val Loss: 0.3549 | MAE H2O: 0.3415 | RMSE H2O: 0.5233 | MAE PL: 0.1833 | RMSE PL: 0.5024 | LR: 1.6e-05
# Epoch 164/300 | Train Loss: 0.3738 | Val Loss: 0.3550 | MAE H2O: 0.3412 | RMSE H2O: 0.5225 | MAE PL: 0.1883 | RMSE PL: 0.5040 | LR: 1.6e-05
# Epoch 165/300 | Train Loss: 0.3739 | Val Loss: 0.3542 | MAE H2O: 0.3417 | RMSE H2O: 0.5227 | MAE PL: 0.1851 | RMSE PL: 0.5020 | LR: 1.6e-05
# Epoch 166/300 | Train Loss: 0.3730 | Val Loss: 0.3541 | MAE H2O: 0.3391 | RMSE H2O: 0.5218 | MAE PL: 0.1817 | RMSE PL: 0.5021 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3534)
# Epoch 167/300 | Train Loss: 0.3720 | Val Loss: 0.3534 | MAE H2O: 0.3414 | RMSE H2O: 0.5228 | MAE PL: 0.1836 | RMSE PL: 0.5007 | LR: 1.6e-05
# Epoch 168/300 | Train Loss: 0.3749 | Val Loss: 0.3539 | MAE H2O: 0.3398 | RMSE H2O: 0.5226 | MAE PL: 0.1815 | RMSE PL: 0.5018 | LR: 1.6e-05
# Epoch 169/300 | Train Loss: 0.3737 | Val Loss: 0.3600 | MAE H2O: 0.3418 | RMSE H2O: 0.5252 | MAE PL: 0.1952 | RMSE PL: 0.5100 | LR: 1.6e-05
# Epoch 170/300 | Train Loss: 0.3724 | Val Loss: 0.3538 | MAE H2O: 0.3405 | RMSE H2O: 0.5222 | MAE PL: 0.1813 | RMSE PL: 0.5016 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3516)
# Epoch 171/300 | Train Loss: 0.3718 | Val Loss: 0.3516 | MAE H2O: 0.3402 | RMSE H2O: 0.5212 | MAE PL: 0.1817 | RMSE PL: 0.4996 | LR: 1.6e-05
# Epoch 172/300 | Train Loss: 0.3719 | Val Loss: 0.3532 | MAE H2O: 0.3421 | RMSE H2O: 0.5227 | MAE PL: 0.1836 | RMSE PL: 0.5008 | LR: 1.6e-05
# Epoch 173/300 | Train Loss: 0.3720 | Val Loss: 0.3525 | MAE H2O: 0.3402 | RMSE H2O: 0.5213 | MAE PL: 0.1810 | RMSE PL: 0.5006 | LR: 1.6e-05
# Epoch 174/300 | Train Loss: 0.3727 | Val Loss: 0.3525 | MAE H2O: 0.3397 | RMSE H2O: 0.5211 | MAE PL: 0.1845 | RMSE PL: 0.5015 | LR: 1.6e-05
# Epoch 175/300 | Train Loss: 0.3720 | Val Loss: 0.3524 | MAE H2O: 0.3412 | RMSE H2O: 0.5214 | MAE PL: 0.1830 | RMSE PL: 0.5007 | LR: 1.6e-05
# Epoch 176/300 | Train Loss: 0.3713 | Val Loss: 0.3519 | MAE H2O: 0.3392 | RMSE H2O: 0.5210 | MAE PL: 0.1832 | RMSE PL: 0.5001 | LR: 1.6e-05
# Epoch 177/300 | Train Loss: 0.3732 | Val Loss: 0.3530 | MAE H2O: 0.3388 | RMSE H2O: 0.5215 | MAE PL: 0.1840 | RMSE PL: 0.5011 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3509)
# Epoch 178/300 | Train Loss: 0.3705 | Val Loss: 0.3509 | MAE H2O: 0.3385 | RMSE H2O: 0.5200 | MAE PL: 0.1814 | RMSE PL: 0.4997 | LR: 7.8e-06
# Epoch 179/300 | Train Loss: 0.3696 | Val Loss: 0.3512 | MAE H2O: 0.3386 | RMSE H2O: 0.5205 | MAE PL: 0.1811 | RMSE PL: 0.4992 | LR: 7.8e-06
# Epoch 180/300 | Train Loss: 0.3705 | Val Loss: 0.3513 | MAE H2O: 0.3381 | RMSE H2O: 0.5204 | MAE PL: 0.1811 | RMSE PL: 0.4996 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3508)
# Epoch 181/300 | Train Loss: 0.3684 | Val Loss: 0.3508 | MAE H2O: 0.3385 | RMSE H2O: 0.5203 | MAE PL: 0.1807 | RMSE PL: 0.4993 | LR: 7.8e-06
# Epoch 182/300 | Train Loss: 0.3717 | Val Loss: 0.3509 | MAE H2O: 0.3382 | RMSE H2O: 0.5201 | MAE PL: 0.1816 | RMSE PL: 0.4992 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3508)
# Epoch 183/300 | Train Loss: 0.3693 | Val Loss: 0.3508 | MAE H2O: 0.3387 | RMSE H2O: 0.5202 | MAE PL: 0.1811 | RMSE PL: 0.4988 | LR: 7.8e-06
# Epoch 184/300 | Train Loss: 0.3688 | Val Loss: 0.3513 | MAE H2O: 0.3380 | RMSE H2O: 0.5202 | MAE PL: 0.1817 | RMSE PL: 0.5002 | LR: 7.8e-06
# Epoch 185/300 | Train Loss: 0.3689 | Val Loss: 0.3515 | MAE H2O: 0.3392 | RMSE H2O: 0.5204 | MAE PL: 0.1806 | RMSE PL: 0.4998 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3505)
# Epoch 186/300 | Train Loss: 0.3685 | Val Loss: 0.3505 | MAE H2O: 0.3382 | RMSE H2O: 0.5197 | MAE PL: 0.1812 | RMSE PL: 0.4993 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3503)
# Epoch 187/300 | Train Loss: 0.3696 | Val Loss: 0.3503 | MAE H2O: 0.3381 | RMSE H2O: 0.5196 | MAE PL: 0.1802 | RMSE PL: 0.4992 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3495)
# Epoch 188/300 | Train Loss: 0.3682 | Val Loss: 0.3495 | MAE H2O: 0.3381 | RMSE H2O: 0.5190 | MAE PL: 0.1813 | RMSE PL: 0.4985 | LR: 7.8e-06
# Epoch 189/300 | Train Loss: 0.3700 | Val Loss: 0.3504 | MAE H2O: 0.3381 | RMSE H2O: 0.5197 | MAE PL: 0.1809 | RMSE PL: 0.4992 | LR: 7.8e-06
# Epoch 190/300 | Train Loss: 0.3701 | Val Loss: 0.3503 | MAE H2O: 0.3377 | RMSE H2O: 0.5196 | MAE PL: 0.1803 | RMSE PL: 0.4990 | LR: 7.8e-06
# Epoch 191/300 | Train Loss: 0.3693 | Val Loss: 0.3516 | MAE H2O: 0.3406 | RMSE H2O: 0.5211 | MAE PL: 0.1842 | RMSE PL: 0.5000 | LR: 7.8e-06
# Epoch 192/300 | Train Loss: 0.3697 | Val Loss: 0.3501 | MAE H2O: 0.3390 | RMSE H2O: 0.5199 | MAE PL: 0.1803 | RMSE PL: 0.4987 | LR: 7.8e-06
# Epoch 193/300 | Train Loss: 0.3695 | Val Loss: 0.3530 | MAE H2O: 0.3388 | RMSE H2O: 0.5208 | MAE PL: 0.1848 | RMSE PL: 0.5023 | LR: 7.8e-06
# Epoch 194/300 | Train Loss: 0.3695 | Val Loss: 0.3529 | MAE H2O: 0.3427 | RMSE H2O: 0.5229 | MAE PL: 0.1833 | RMSE PL: 0.5005 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3495)
# Epoch 195/300 | Train Loss: 0.3678 | Val Loss: 0.3495 | MAE H2O: 0.3373 | RMSE H2O: 0.5190 | MAE PL: 0.1798 | RMSE PL: 0.4983 | LR: 3.9e-06
# Epoch 196/300 | Train Loss: 0.3668 | Val Loss: 0.3504 | MAE H2O: 0.3382 | RMSE H2O: 0.5196 | MAE PL: 0.1801 | RMSE PL: 0.4993 | LR: 3.9e-06
# Epoch 197/300 | Train Loss: 0.3668 | Val Loss: 0.3500 | MAE H2O: 0.3388 | RMSE H2O: 0.5199 | MAE PL: 0.1785 | RMSE PL: 0.4985 | LR: 3.9e-06
# Epoch 198/300 | Train Loss: 0.3683 | Val Loss: 0.3496 | MAE H2O: 0.3373 | RMSE H2O: 0.5189 | MAE PL: 0.1794 | RMSE PL: 0.4985 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3491)
# Epoch 199/300 | Train Loss: 0.3681 | Val Loss: 0.3491 | MAE H2O: 0.3373 | RMSE H2O: 0.5186 | MAE PL: 0.1789 | RMSE PL: 0.4983 | LR: 3.9e-06
# Epoch 200/300 | Train Loss: 0.3688 | Val Loss: 0.3498 | MAE H2O: 0.3386 | RMSE H2O: 0.5193 | MAE PL: 0.1823 | RMSE PL: 0.4988 | LR: 3.9e-06
# Epoch 201/300 | Train Loss: 0.3667 | Val Loss: 0.3493 | MAE H2O: 0.3375 | RMSE H2O: 0.5190 | MAE PL: 0.1795 | RMSE PL: 0.4983 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3491)
# Epoch 202/300 | Train Loss: 0.3692 | Val Loss: 0.3491 | MAE H2O: 0.3375 | RMSE H2O: 0.5190 | MAE PL: 0.1797 | RMSE PL: 0.4979 | LR: 3.9e-06
# Epoch 203/300 | Train Loss: 0.3681 | Val Loss: 0.3492 | MAE H2O: 0.3377 | RMSE H2O: 0.5188 | MAE PL: 0.1797 | RMSE PL: 0.4983 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3490)
# Epoch 204/300 | Train Loss: 0.3675 | Val Loss: 0.3490 | MAE H2O: 0.3378 | RMSE H2O: 0.5189 | MAE PL: 0.1797 | RMSE PL: 0.4980 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3487)
# Epoch 205/300 | Train Loss: 0.3670 | Val Loss: 0.3487 | MAE H2O: 0.3376 | RMSE H2O: 0.5185 | MAE PL: 0.1799 | RMSE PL: 0.4980 | LR: 3.9e-06
# Epoch 206/300 | Train Loss: 0.3667 | Val Loss: 0.3490 | MAE H2O: 0.3374 | RMSE H2O: 0.5186 | MAE PL: 0.1793 | RMSE PL: 0.4981 | LR: 3.9e-06
# Epoch 207/300 | Train Loss: 0.3672 | Val Loss: 0.3493 | MAE H2O: 0.3373 | RMSE H2O: 0.5188 | MAE PL: 0.1790 | RMSE PL: 0.4984 | LR: 3.9e-06
# Epoch 208/300 | Train Loss: 0.3691 | Val Loss: 0.3502 | MAE H2O: 0.3380 | RMSE H2O: 0.5193 | MAE PL: 0.1828 | RMSE PL: 0.4999 | LR: 3.9e-06
# Epoch 209/300 | Train Loss: 0.3671 | Val Loss: 0.3488 | MAE H2O: 0.3377 | RMSE H2O: 0.5186 | MAE PL: 0.1800 | RMSE PL: 0.4979 | LR: 3.9e-06
# Epoch 210/300 | Train Loss: 0.3663 | Val Loss: 0.3503 | MAE H2O: 0.3381 | RMSE H2O: 0.5196 | MAE PL: 0.1823 | RMSE PL: 0.4992 | LR: 3.9e-06
# Epoch 211/300 | Train Loss: 0.3695 | Val Loss: 0.3491 | MAE H2O: 0.3372 | RMSE H2O: 0.5187 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 2.0e-06
# Epoch 212/300 | Train Loss: 0.3652 | Val Loss: 0.3489 | MAE H2O: 0.3374 | RMSE H2O: 0.5185 | MAE PL: 0.1801 | RMSE PL: 0.4982 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3486)
# Epoch 213/300 | Train Loss: 0.3663 | Val Loss: 0.3486 | MAE H2O: 0.3369 | RMSE H2O: 0.5182 | MAE PL: 0.1793 | RMSE PL: 0.4980 | LR: 2.0e-06
# Epoch 214/300 | Train Loss: 0.3669 | Val Loss: 0.3487 | MAE H2O: 0.3370 | RMSE H2O: 0.5183 | MAE PL: 0.1789 | RMSE PL: 0.4979 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3485)
# Epoch 215/300 | Train Loss: 0.3665 | Val Loss: 0.3485 | MAE H2O: 0.3375 | RMSE H2O: 0.5183 | MAE PL: 0.1787 | RMSE PL: 0.4977 | LR: 2.0e-06
# Epoch 216/300 | Train Loss: 0.3657 | Val Loss: 0.3485 | MAE H2O: 0.3371 | RMSE H2O: 0.5183 | MAE PL: 0.1793 | RMSE PL: 0.4978 | LR: 2.0e-06
# Epoch 217/300 | Train Loss: 0.3675 | Val Loss: 0.3485 | MAE H2O: 0.3371 | RMSE H2O: 0.5183 | MAE PL: 0.1793 | RMSE PL: 0.4977 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3483)
# Epoch 218/300 | Train Loss: 0.3650 | Val Loss: 0.3483 | MAE H2O: 0.3372 | RMSE H2O: 0.5182 | MAE PL: 0.1793 | RMSE PL: 0.4976 | LR: 2.0e-06
# Epoch 219/300 | Train Loss: 0.3670 | Val Loss: 0.3484 | MAE H2O: 0.3370 | RMSE H2O: 0.5182 | MAE PL: 0.1789 | RMSE PL: 0.4976 | LR: 2.0e-06
# Epoch 220/300 | Train Loss: 0.3656 | Val Loss: 0.3484 | MAE H2O: 0.3369 | RMSE H2O: 0.5182 | MAE PL: 0.1790 | RMSE PL: 0.4977 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3483)
# Epoch 221/300 | Train Loss: 0.3669 | Val Loss: 0.3483 | MAE H2O: 0.3373 | RMSE H2O: 0.5182 | MAE PL: 0.1791 | RMSE PL: 0.4976 | LR: 2.0e-06
# Epoch 222/300 | Train Loss: 0.3660 | Val Loss: 0.3487 | MAE H2O: 0.3372 | RMSE H2O: 0.5183 | MAE PL: 0.1804 | RMSE PL: 0.4982 | LR: 2.0e-06
# Epoch 223/300 | Train Loss: 0.3675 | Val Loss: 0.3487 | MAE H2O: 0.3371 | RMSE H2O: 0.5183 | MAE PL: 0.1809 | RMSE PL: 0.4984 | LR: 2.0e-06
# Epoch 224/300 | Train Loss: 0.3661 | Val Loss: 0.3483 | MAE H2O: 0.3369 | RMSE H2O: 0.5181 | MAE PL: 0.1790 | RMSE PL: 0.4976 | LR: 9.8e-07
# Epoch 225/300 | Train Loss: 0.3679 | Val Loss: 0.3483 | MAE H2O: 0.3368 | RMSE H2O: 0.5181 | MAE PL: 0.1791 | RMSE PL: 0.4976 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3483)
# Epoch 226/300 | Train Loss: 0.3669 | Val Loss: 0.3483 | MAE H2O: 0.3369 | RMSE H2O: 0.5181 | MAE PL: 0.1791 | RMSE PL: 0.4976 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3482)
# Epoch 227/300 | Train Loss: 0.3659 | Val Loss: 0.3482 | MAE H2O: 0.3368 | RMSE H2O: 0.5180 | MAE PL: 0.1791 | RMSE PL: 0.4975 | LR: 9.8e-07
# Epoch 228/300 | Train Loss: 0.3666 | Val Loss: 0.3484 | MAE H2O: 0.3369 | RMSE H2O: 0.5181 | MAE PL: 0.1790 | RMSE PL: 0.4977 | LR: 9.8e-07
# Epoch 229/300 | Train Loss: 0.3663 | Val Loss: 0.3482 | MAE H2O: 0.3368 | RMSE H2O: 0.5180 | MAE PL: 0.1787 | RMSE PL: 0.4976 | LR: 9.8e-07
# Epoch 230/300 | Train Loss: 0.3679 | Val Loss: 0.3483 | MAE H2O: 0.3369 | RMSE H2O: 0.5180 | MAE PL: 0.1788 | RMSE PL: 0.4978 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3481)
# Epoch 231/300 | Train Loss: 0.3667 | Val Loss: 0.3481 | MAE H2O: 0.3372 | RMSE H2O: 0.5180 | MAE PL: 0.1789 | RMSE PL: 0.4974 | LR: 9.8e-07
# Epoch 232/300 | Train Loss: 0.3652 | Val Loss: 0.3482 | MAE H2O: 0.3374 | RMSE H2O: 0.5181 | MAE PL: 0.1795 | RMSE PL: 0.4975 | LR: 9.8e-07
# Epoch 233/300 | Train Loss: 0.3652 | Val Loss: 0.3483 | MAE H2O: 0.3371 | RMSE H2O: 0.5180 | MAE PL: 0.1793 | RMSE PL: 0.4978 | LR: 9.8e-07
# Epoch 234/300 | Train Loss: 0.3660 | Val Loss: 0.3482 | MAE H2O: 0.3371 | RMSE H2O: 0.5181 | MAE PL: 0.1787 | RMSE PL: 0.4975 | LR: 9.8e-07
# Epoch 235/300 | Train Loss: 0.3662 | Val Loss: 0.3482 | MAE H2O: 0.3369 | RMSE H2O: 0.5180 | MAE PL: 0.1792 | RMSE PL: 0.4976 | LR: 9.8e-07
# Epoch 236/300 | Train Loss: 0.3676 | Val Loss: 0.3481 | MAE H2O: 0.3367 | RMSE H2O: 0.5179 | MAE PL: 0.1786 | RMSE PL: 0.4975 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3480)
# Epoch 237/300 | Train Loss: 0.3645 | Val Loss: 0.3480 | MAE H2O: 0.3368 | RMSE H2O: 0.5178 | MAE PL: 0.1791 | RMSE PL: 0.4975 | LR: 9.8e-07
# Epoch 238/300 | Train Loss: 0.3682 | Val Loss: 0.3481 | MAE H2O: 0.3366 | RMSE H2O: 0.5180 | MAE PL: 0.1788 | RMSE PL: 0.4975 | LR: 9.8e-07
# Epoch 239/300 | Train Loss: 0.3664 | Val Loss: 0.3482 | MAE H2O: 0.3370 | RMSE H2O: 0.5180 | MAE PL: 0.1797 | RMSE PL: 0.4977 | LR: 9.8e-07
# Epoch 240/300 | Train Loss: 0.3679 | Val Loss: 0.3484 | MAE H2O: 0.3367 | RMSE H2O: 0.5181 | MAE PL: 0.1789 | RMSE PL: 0.4978 | LR: 9.8e-07
# Epoch 241/300 | Train Loss: 0.3656 | Val Loss: 0.3480 | MAE H2O: 0.3368 | RMSE H2O: 0.5180 | MAE PL: 0.1793 | RMSE PL: 0.4974 | LR: 9.8e-07
# Epoch 242/300 | Train Loss: 0.3657 | Val Loss: 0.3480 | MAE H2O: 0.3370 | RMSE H2O: 0.5179 | MAE PL: 0.1788 | RMSE PL: 0.4975 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3479)
# Epoch 243/300 | Train Loss: 0.3658 | Val Loss: 0.3479 | MAE H2O: 0.3369 | RMSE H2O: 0.5179 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 9.8e-07
# Epoch 244/300 | Train Loss: 0.3645 | Val Loss: 0.3480 | MAE H2O: 0.3370 | RMSE H2O: 0.5179 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 9.8e-07
# Epoch 245/300 | Train Loss: 0.3667 | Val Loss: 0.3485 | MAE H2O: 0.3365 | RMSE H2O: 0.5180 | MAE PL: 0.1783 | RMSE PL: 0.4978 | LR: 9.8e-07
# Epoch 246/300 | Train Loss: 0.3656 | Val Loss: 0.3480 | MAE H2O: 0.3369 | RMSE H2O: 0.5179 | MAE PL: 0.1785 | RMSE PL: 0.4974 | LR: 9.8e-07
# Epoch 247/300 | Train Loss: 0.3663 | Val Loss: 0.3481 | MAE H2O: 0.3367 | RMSE H2O: 0.5179 | MAE PL: 0.1785 | RMSE PL: 0.4975 | LR: 9.8e-07
# Epoch 248/300 | Train Loss: 0.3681 | Val Loss: 0.3481 | MAE H2O: 0.3367 | RMSE H2O: 0.5179 | MAE PL: 0.1785 | RMSE PL: 0.4975 | LR: 9.8e-07
# Epoch 249/300 | Train Loss: 0.3652 | Val Loss: 0.3482 | MAE H2O: 0.3366 | RMSE H2O: 0.5179 | MAE PL: 0.1785 | RMSE PL: 0.4976 | LR: 4.9e-07
# ✅ Model improved and saved (val_loss = 0.3479)
# Epoch 250/300 | Train Loss: 0.3651 | Val Loss: 0.3479 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 4.9e-07
# Epoch 251/300 | Train Loss: 0.3655 | Val Loss: 0.3479 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 4.9e-07
# Epoch 252/300 | Train Loss: 0.3665 | Val Loss: 0.3479 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 4.9e-07
# Epoch 253/300 | Train Loss: 0.3681 | Val Loss: 0.3481 | MAE H2O: 0.3366 | RMSE H2O: 0.5179 | MAE PL: 0.1785 | RMSE PL: 0.4976 | LR: 4.9e-07
# Epoch 254/300 | Train Loss: 0.3657 | Val Loss: 0.3480 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 4.9e-07
# Epoch 255/300 | Train Loss: 0.3650 | Val Loss: 0.3480 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1785 | RMSE PL: 0.4975 | LR: 2.4e-07
# ✅ Model improved and saved (val_loss = 0.3479)
# Epoch 256/300 | Train Loss: 0.3661 | Val Loss: 0.3479 | MAE H2O: 0.3368 | RMSE H2O: 0.5178 | MAE PL: 0.1788 | RMSE PL: 0.4974 | LR: 2.4e-07
# ✅ Model improved and saved (val_loss = 0.3479)
# Epoch 257/300 | Train Loss: 0.3662 | Val Loss: 0.3479 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1787 | RMSE PL: 0.4974 | LR: 2.4e-07
# ✅ Model improved and saved (val_loss = 0.3478)
# Epoch 258/300 | Train Loss: 0.3659 | Val Loss: 0.3478 | MAE H2O: 0.3368 | RMSE H2O: 0.5178 | MAE PL: 0.1788 | RMSE PL: 0.4973 | LR: 2.4e-07
# Epoch 259/300 | Train Loss: 0.3653 | Val Loss: 0.3479 | MAE H2O: 0.3366 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 2.4e-07
# Epoch 260/300 | Train Loss: 0.3659 | Val Loss: 0.3478 | MAE H2O: 0.3369 | RMSE H2O: 0.5178 | MAE PL: 0.1791 | RMSE PL: 0.4973 | LR: 2.4e-07
# Epoch 261/300 | Train Loss: 0.3658 | Val Loss: 0.3479 | MAE H2O: 0.3368 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4974 | LR: 2.4e-07
# Epoch 262/300 | Train Loss: 0.3670 | Val Loss: 0.3478 | MAE H2O: 0.3368 | RMSE H2O: 0.5178 | MAE PL: 0.1790 | RMSE PL: 0.4974 | LR: 2.4e-07
# Epoch 263/300 | Train Loss: 0.3658 | Val Loss: 0.3479 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4973 | LR: 2.4e-07
# Epoch 264/300 | Train Loss: 0.3648 | Val Loss: 0.3478 | MAE H2O: 0.3366 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4973 | LR: 1.2e-07
# Epoch 265/300 | Train Loss: 0.3650 | Val Loss: 0.3478 | MAE H2O: 0.3367 | RMSE H2O: 0.5177 | MAE PL: 0.1787 | RMSE PL: 0.4973 | LR: 1.2e-07
# Epoch 266/300 | Train Loss: 0.3652 | Val Loss: 0.3478 | MAE H2O: 0.3367 | RMSE H2O: 0.5178 | MAE PL: 0.1786 | RMSE PL: 0.4973 | LR: 1.2e-07
# Epoch 267/300 | Train Loss: 0.3670 | Val Loss: 0.3478 | MAE H2O: 0.3366 | RMSE H2O: 0.5177 | MAE PL: 0.1786 | RMSE PL: 0.4973 | LR: 1.2e-07
# ⛔ Early stopping at epoch 268

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correct unpacking from evaluate
(y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl) = evaluate(model, test_loader)

# Concatenate outputs
y_pred_test_scaled = np.concatenate([y_pred_h2o, y_pred_pl], axis=1)
y_true_test_scaled = np.concatenate([y_true_h2o, y_true_pl], axis=1)

# Inverse transform
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_true_test = scaler_y.inverse_transform(y_true_test_scaled)

# Split again
y_pred_h2o = y_pred_test[:, :67]
y_pred_pl  = y_pred_test[:, 67:]

y_true_h2o = y_true_test[:, :67]
y_true_pl  = y_true_test[:, 67:]

# Optionally concatenate to compute overall metrics
y_true_test = np.concatenate([y_true_pl, y_true_h2o], axis=1)
y_pred_test = np.concatenate([y_pred_pl, y_pred_h2o], axis=1)

# Compute test metrics
test_mae = mean_absolute_error(y_true_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"\n✅ Test MAE:  {test_mae:.4f}")
print(f"✅ Test RMSE: {test_rmse:.4f}")

# You can also compute them separately:
mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

print(f"\n🌊 H2O  → MAE: {mae_h2o:.4f} | RMSE: {rmse_h2o:.4f}")
print(f"📉 PL   → MAE: {mae_pl:.4f} | RMSE: {rmse_pl:.4f}")
# Out:
# ✅ Test MAE:  1.1530
# ✅ Test RMSE: 4.3024
#
# 🌊 H2O  → MAE: 0.0004 | RMSE: 0.0011
# 📉 PL   → MAE: 2.3056 | RMSE: 6.0845

# %%
output_index = 120  # index within concatenated output (0–133)

plt.figure(figsize=(10, 5))
plt.plot(y_true_test[:, output_index], label='True', alpha=0.7)
plt.plot(y_pred_test[:, output_index], label='Predicted', alpha=0.7)
plt.title(f"True vs Predicted - Output #{output_index}")
plt.xlabel("Sample index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose a sample index
i = 120

# Extract profiles for test sample i
pl_profile_true = y_true_pl[i]
h2o_profile_true = y_true_h2o[i]

pl_profile_pred = y_pred_pl[i]
h2o_profile_pred = y_pred_h2o[i]

# Plot profile
plt.figure(figsize=(7, 6))
plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
plt.gca().invert_yaxis()
plt.xlabel("H2O content [vmr]")
plt.ylabel("Pressure Layer [mbar]")
#plt.ylim(0, 1000)
plt.title("H2O content vs Pressure Level")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for i in range(3):
    pl_profile_true = y_true_pl[i]
    h2o_profile_true = y_true_h2o[i]
    pl_profile_pred = y_pred_pl[i]
    h2o_profile_pred = y_pred_h2o[i]

    plt.figure(figsize=(7, 6))
    plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
    plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
    plt.gca().invert_yaxis()
    plt.xlabel("H2O content [vmr]")
    plt.ylabel("Pressure Layer [mbar]")
    #plt.ylim(0, 1000)
    plt.title(f"H2O vs PL — Test Sample #{i}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#torch.save(model.state_dict(), save_path)

# %%
save_path_final = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model23RES_final.pth'
torch.save(model.state_dict(), save_path_final)
