# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0'
input_pkl_path_v1 = os.path.join(data_dir, 'input_nn_ver1.pkl')
#input_pkl_path_v2 = os.path.join(data_dir, 'input_nn_ver2.pkl')

# %%
df = pd.read_pickle(input_pkl_path_v1)
#df = pd.read_pickle(input_pkl_path_v2)

# %% [markdown]
# **------------------NOISE ADDING----------------------**

# %%
def add_noise(tsky, trx=75.0, snr=1000.0):
    tsys = trx + tsky
    tnoise = tsys / snr
    tcal = tsky + tnoise * np.random.standard_normal(tsky.shape)
    return tcal

# %%
original_spectrum = np.array(df['SPECTRA_Tb[K]'].iloc[0])

# %%
frequencies = np.linspace(20.0, 26.0, len(original_spectrum))

# %%
noisy_spectrum = add_noise(original_spectrum)

# %%
df['SPECTRA_Tb[K]_NOISY'] = df['SPECTRA_Tb[K]']

# %% [markdown]
# **TRANING WAY 1: USING DIFFERENT COLUMNS BETWEEN PL AND H2O**

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['SPECTRA_Tb[K]_NOISY'].tolist())
PL = np.array(df['PL[mbar]'].tolist())
H2O = np.array(df['H2O[vmr]'].tolist())
Y = np.concatenate([H2O, PL], axis=1)

# %%
print(H2O.shape, PL.shape)
# Out:
# (21024, 67) (21024, 67)

# %%
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.4, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)

# %%
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **SECOND FRAMEWORK TORCH**

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **-NORMALIZATION-**

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_val_scaled = scaler.transform(X_val)
#X_test_scaled = scaler.transform(X_test)
X_train = scaler_x.fit_transform(X_train)
X_val = scaler_x.transform(X_val)
X_test = scaler_x.transform(X_test)

# %%
scaler_y = StandardScaler()
Y_train = scaler_y.fit_transform(Y_train)
Y_val   = scaler_y.transform(Y_val)
Y_test  = scaler_y.transform(Y_test)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **-----------------------**

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
Y_val   = torch.tensor(Y_val, dtype=torch.float32)
X_test  = torch.tensor(X_test, dtype=torch.float32)
Y_test  = torch.tensor(Y_test, dtype=torch.float32)

# %%
batch_size = 64

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds  = TensorDataset(X_test, Y_test)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, out_features, dropout):
        super(ResidualBlock, self).__init__()
        self.linear = nn.Linear(in_features, out_features)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

        # Project input if dimensions don’t match
        self.shortcut = nn.Identity()
        if in_features != out_features:
            self.shortcut = nn.Linear(in_features, out_features)

    def forward(self, x):
        identity = self.shortcut(x)
        out = self.linear(x)
        out = self.relu(out)
        out = self.dropout(out)
        return identity + out  # Residual connection

# %%
class PedroSplitMLPResidual(nn.Module):
    def __init__(self):
        super(PedroSplitMLPResidual, self).__init__()
        self.fc_in = nn.Linear(12001, 1024)
        self.dropout_in = nn.Dropout(0.1)

        # Residual blocks
        self.res1 = ResidualBlock(1024, 512, dropout=0.1)
        self.res2 = ResidualBlock(512, 256, dropout=0.1)
        self.res3 = ResidualBlock(256, 128, dropout=0.1)

        # Output heads
        self.h2o_head = nn.Linear(128, 67)
        self.pl_head = nn.Linear(128, 67)

    def forward(self, x):
        x = torch.relu(self.fc_in(x))
        x = self.dropout_in(x)

        x = self.res1(x)
        x = self.res2(x)
        x = self.res3(x)

        h2o_out = self.h2o_head(x)
        pl_out = self.pl_head(x)
        return h2o_out, pl_out

model = PedroSplitMLPResidual()

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super(WeightedMSELoss, self).__init__()
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def forward(self, pred, target):
        diff = pred - target
        weighted_diff = diff * self.weights
        loss = torch.mean(weighted_diff ** 2)
        return loss

#def smoothness_penalty(h2o_pred, alpha):
#    diff = h2o_pred[:, 1:] - h2o_pred[:, :-1]
#    return alpha * torch.mean(diff ** 2)

# Construct weights to emphasize lower pressures (higher in atmosphere)
n_levels = 67
pl_weights = np.linspace(1.0, 0.5, n_levels)      # Normal weights for PL
h2o_weights = np.logspace(np.log10(2.0), np.log10(0.8), n_levels)     # Emphasize high-altitude H2O, modified for higher-pressure performance

pl_weights_tensor = torch.tensor(pl_weights, dtype=torch.float32)
h2o_weights_tensor = torch.tensor(h2o_weights, dtype=torch.float32)

combined_weights = np.concatenate([pl_weights, h2o_weights])
criterion_h2o = WeightedMSELoss(weights=h2o_weights_tensor)
criterion_pl  = WeightedMSELoss(weights=pl_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
# Out:
# /tmp/ipython-input-26-1101997656.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.weights = torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, loader, val_loader, criterion_h2o, criterion_pl, optimizer, epochs, save_path, lambda_h2o):
    train_losses, val_losses = [], []
    val_mae_list, val_rmse_list = [], []

    best_val_loss = float('inf')
    patience = 10
    counter = 0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        for xb, yb in loader:
            optimizer.zero_grad()

            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            loss_h2o = criterion_h2o(h2o_pred, h2o_target)
            loss_pl = criterion_pl(pl_pred, pl_target)

            loss = lambda_h2o * loss_h2o + loss_pl
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(loader))

        # VALIDATION
        model.eval()
        val_loss_total = 0
        y_true_h2o, y_pred_h2o = [], []
        y_true_pl, y_pred_pl = [], []

        with torch.no_grad():
            for xb, yb in val_loader:
                h2o_pred, pl_pred = model(xb)
                h2o_target = yb[:, :n_levels]
                pl_target = yb[:, n_levels:]

                loss_h2o_val = criterion_h2o(h2o_pred, h2o_target)
                loss_pl_val = criterion_pl(pl_pred, pl_target)

                batch_val_loss = lambda_h2o * loss_h2o_val + loss_pl_val
                val_loss_total += batch_val_loss.item()

                y_true_h2o.append(h2o_target.cpu().numpy())
                y_pred_h2o.append(h2o_pred.cpu().numpy())

                y_true_pl.append(pl_target.cpu().numpy())
                y_pred_pl.append(pl_pred.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_losses.append(val_loss)

        y_true_h2o = np.concatenate(y_true_h2o, axis=0)
        y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

        y_true_pl = np.concatenate(y_true_pl, axis=0)
        y_pred_pl = np.concatenate(y_pred_pl, axis=0)

        # METRICS
        val_mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
        val_rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

        val_mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
        val_rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

        val_mae_list.append((val_mae_h2o, val_mae_pl))
        val_rmse_list.append((val_rmse_h2o, val_rmse_pl))

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        # EARLY STOPPING
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), save_path)
            counter = 0
            print(f"✅ Model improved and saved (val_loss = {best_val_loss:.4f})")
        else:
            counter += 1
            if counter >= patience:
                print(f"⛔ Early stopping at epoch {epoch+1}")
                break

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f} | "
              f"MAE H2O: {val_mae_h2o:.4f} | RMSE H2O: {val_rmse_h2o:.4f} | "
              f"MAE PL: {val_mae_pl:.4f} | RMSE PL: {val_rmse_pl:.4f} | LR: {current_lr:.1e}")

    model.load_state_dict(torch.load(save_path))
    return train_losses, val_losses, val_mae_list, val_rmse_list

# %%
def evaluate(model, loader):
    model.eval()
    y_true_h2o, y_pred_h2o = [], []
    y_true_pl, y_pred_pl = [], []

    with torch.no_grad():
        for xb, yb in loader:
            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            y_true_h2o.append(h2o_target.cpu().numpy())
            y_pred_h2o.append(h2o_pred.cpu().numpy())

            y_true_pl.append(pl_target.cpu().numpy())
            y_pred_pl.append(pl_pred.cpu().numpy())

    y_true_h2o = np.concatenate(y_true_h2o, axis=0)
    y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

    y_true_pl = np.concatenate(y_true_pl, axis=0)
    y_pred_pl = np.concatenate(y_pred_pl, axis=0)

    return (y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl)

# %%
save_path = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model25RES.pth'

# %%
epochs = 300
lambda_h2o=0.3
train_losses, val_losses, val_mae, val_rmse = train(
    model,
    train_loader,
    val_loader,
    criterion_h2o,
    criterion_pl,
    optimizer,
    epochs,
    save_path=save_path,
    lambda_h2o=lambda_h2o
)
# Out:
# ✅ Model improved and saved (val_loss = 0.7976)
# Epoch 1/300 | Train Loss: 0.8246 | Val Loss: 0.7976 | MAE H2O: 0.6289 | RMSE H2O: 0.8366 | MAE PL: 0.4720 | RMSE PL: 0.7942 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5401)
# Epoch 2/300 | Train Loss: 0.5841 | Val Loss: 0.5401 | MAE H2O: 0.4847 | RMSE H2O: 0.6536 | MAE PL: 0.4000 | RMSE PL: 0.6766 | LR: 5.0e-04
# Epoch 3/300 | Train Loss: 0.5482 | Val Loss: 0.6403 | MAE H2O: 0.4892 | RMSE H2O: 0.7012 | MAE PL: 0.3092 | RMSE PL: 0.7192 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5100)
# Epoch 4/300 | Train Loss: 0.5291 | Val Loss: 0.5100 | MAE H2O: 0.4347 | RMSE H2O: 0.6140 | MAE PL: 0.3124 | RMSE PL: 0.6733 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4794)
# Epoch 5/300 | Train Loss: 0.5117 | Val Loss: 0.4794 | MAE H2O: 0.4303 | RMSE H2O: 0.6144 | MAE PL: 0.2825 | RMSE PL: 0.6132 | LR: 5.0e-04
# Epoch 6/300 | Train Loss: 0.5031 | Val Loss: 0.6139 | MAE H2O: 0.4690 | RMSE H2O: 0.6791 | MAE PL: 0.3146 | RMSE PL: 0.7151 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4514)
# Epoch 7/300 | Train Loss: 0.4933 | Val Loss: 0.4514 | MAE H2O: 0.4158 | RMSE H2O: 0.5978 | MAE PL: 0.2749 | RMSE PL: 0.5929 | LR: 5.0e-04
# Epoch 8/300 | Train Loss: 0.4814 | Val Loss: 0.4979 | MAE H2O: 0.4579 | RMSE H2O: 0.6587 | MAE PL: 0.2632 | RMSE PL: 0.5926 | LR: 5.0e-04
# Epoch 9/300 | Train Loss: 0.4906 | Val Loss: 0.4624 | MAE H2O: 0.4174 | RMSE H2O: 0.6008 | MAE PL: 0.2991 | RMSE PL: 0.6098 | LR: 5.0e-04
# Epoch 10/300 | Train Loss: 0.4821 | Val Loss: 0.4534 | MAE H2O: 0.4224 | RMSE H2O: 0.6084 | MAE PL: 0.2808 | RMSE PL: 0.5772 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4473)
# Epoch 11/300 | Train Loss: 0.4741 | Val Loss: 0.4473 | MAE H2O: 0.4058 | RMSE H2O: 0.5895 | MAE PL: 0.2990 | RMSE PL: 0.6034 | LR: 5.0e-04
# Epoch 12/300 | Train Loss: 0.4726 | Val Loss: 0.4701 | MAE H2O: 0.4262 | RMSE H2O: 0.6120 | MAE PL: 0.3201 | RMSE PL: 0.6215 | LR: 5.0e-04
# Epoch 13/300 | Train Loss: 0.4729 | Val Loss: 0.4734 | MAE H2O: 0.4136 | RMSE H2O: 0.6033 | MAE PL: 0.2784 | RMSE PL: 0.6211 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4444)
# Epoch 14/300 | Train Loss: 0.4684 | Val Loss: 0.4444 | MAE H2O: 0.4146 | RMSE H2O: 0.5984 | MAE PL: 0.2809 | RMSE PL: 0.5817 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4389)
# Epoch 15/300 | Train Loss: 0.4644 | Val Loss: 0.4389 | MAE H2O: 0.4090 | RMSE H2O: 0.5944 | MAE PL: 0.2631 | RMSE PL: 0.5759 | LR: 5.0e-04
# Epoch 16/300 | Train Loss: 0.4616 | Val Loss: 0.4461 | MAE H2O: 0.4054 | RMSE H2O: 0.5860 | MAE PL: 0.2872 | RMSE PL: 0.6005 | LR: 5.0e-04
# Epoch 17/300 | Train Loss: 0.4598 | Val Loss: 0.4507 | MAE H2O: 0.4241 | RMSE H2O: 0.6057 | MAE PL: 0.2640 | RMSE PL: 0.5785 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4262)
# Epoch 18/300 | Train Loss: 0.4565 | Val Loss: 0.4262 | MAE H2O: 0.4039 | RMSE H2O: 0.5855 | MAE PL: 0.2459 | RMSE PL: 0.5609 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4226)
# Epoch 19/300 | Train Loss: 0.4599 | Val Loss: 0.4226 | MAE H2O: 0.4003 | RMSE H2O: 0.5852 | MAE PL: 0.2453 | RMSE PL: 0.5625 | LR: 5.0e-04
# Epoch 20/300 | Train Loss: 0.4537 | Val Loss: 0.4409 | MAE H2O: 0.3983 | RMSE H2O: 0.5964 | MAE PL: 0.2533 | RMSE PL: 0.5685 | LR: 5.0e-04
# Epoch 21/300 | Train Loss: 0.4552 | Val Loss: 0.4722 | MAE H2O: 0.4276 | RMSE H2O: 0.6113 | MAE PL: 0.2542 | RMSE PL: 0.6031 | LR: 5.0e-04
# Epoch 22/300 | Train Loss: 0.4566 | Val Loss: 0.4667 | MAE H2O: 0.4117 | RMSE H2O: 0.5938 | MAE PL: 0.3247 | RMSE PL: 0.6404 | LR: 5.0e-04
# Epoch 23/300 | Train Loss: 0.4513 | Val Loss: 0.4434 | MAE H2O: 0.4199 | RMSE H2O: 0.6132 | MAE PL: 0.2402 | RMSE PL: 0.5659 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4128)
# Epoch 24/300 | Train Loss: 0.4516 | Val Loss: 0.4128 | MAE H2O: 0.3968 | RMSE H2O: 0.5760 | MAE PL: 0.2445 | RMSE PL: 0.5528 | LR: 5.0e-04
# Epoch 25/300 | Train Loss: 0.4502 | Val Loss: 0.4287 | MAE H2O: 0.4136 | RMSE H2O: 0.6035 | MAE PL: 0.2478 | RMSE PL: 0.5522 | LR: 5.0e-04
# Epoch 26/300 | Train Loss: 0.4584 | Val Loss: 0.4442 | MAE H2O: 0.4059 | RMSE H2O: 0.5918 | MAE PL: 0.2498 | RMSE PL: 0.5838 | LR: 5.0e-04
# Epoch 27/300 | Train Loss: 0.4499 | Val Loss: 0.4359 | MAE H2O: 0.4061 | RMSE H2O: 0.5892 | MAE PL: 0.2500 | RMSE PL: 0.5725 | LR: 5.0e-04
# Epoch 28/300 | Train Loss: 0.4456 | Val Loss: 0.4435 | MAE H2O: 0.4168 | RMSE H2O: 0.5998 | MAE PL: 0.2776 | RMSE PL: 0.5807 | LR: 5.0e-04
# Epoch 29/300 | Train Loss: 0.4453 | Val Loss: 0.4410 | MAE H2O: 0.3971 | RMSE H2O: 0.5921 | MAE PL: 0.2551 | RMSE PL: 0.5707 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4094)
# Epoch 30/300 | Train Loss: 0.4427 | Val Loss: 0.4094 | MAE H2O: 0.3885 | RMSE H2O: 0.5728 | MAE PL: 0.2482 | RMSE PL: 0.5455 | LR: 5.0e-04
# Epoch 31/300 | Train Loss: 0.4493 | Val Loss: 0.4268 | MAE H2O: 0.3940 | RMSE H2O: 0.5849 | MAE PL: 0.2405 | RMSE PL: 0.5650 | LR: 5.0e-04
# Epoch 32/300 | Train Loss: 0.4502 | Val Loss: 0.4273 | MAE H2O: 0.3953 | RMSE H2O: 0.5759 | MAE PL: 0.2712 | RMSE PL: 0.5702 | LR: 5.0e-04
# Epoch 33/300 | Train Loss: 0.4479 | Val Loss: 0.4130 | MAE H2O: 0.3939 | RMSE H2O: 0.5754 | MAE PL: 0.2290 | RMSE PL: 0.5461 | LR: 5.0e-04
# Epoch 34/300 | Train Loss: 0.4473 | Val Loss: 0.4422 | MAE H2O: 0.4205 | RMSE H2O: 0.6036 | MAE PL: 0.2776 | RMSE PL: 0.5878 | LR: 5.0e-04
# Epoch 35/300 | Train Loss: 0.4441 | Val Loss: 0.4375 | MAE H2O: 0.3947 | RMSE H2O: 0.5787 | MAE PL: 0.2654 | RMSE PL: 0.5998 | LR: 5.0e-04
# Epoch 36/300 | Train Loss: 0.4418 | Val Loss: 0.4559 | MAE H2O: 0.4278 | RMSE H2O: 0.6147 | MAE PL: 0.2681 | RMSE PL: 0.5897 | LR: 2.5e-04
# Epoch 37/300 | Train Loss: 0.4217 | Val Loss: 0.4155 | MAE H2O: 0.3886 | RMSE H2O: 0.5740 | MAE PL: 0.2350 | RMSE PL: 0.5579 | LR: 2.5e-04
# Epoch 38/300 | Train Loss: 0.4202 | Val Loss: 0.4211 | MAE H2O: 0.3854 | RMSE H2O: 0.5729 | MAE PL: 0.2333 | RMSE PL: 0.5710 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4029)
# Epoch 39/300 | Train Loss: 0.4179 | Val Loss: 0.4029 | MAE H2O: 0.3725 | RMSE H2O: 0.5607 | MAE PL: 0.2270 | RMSE PL: 0.5493 | LR: 2.5e-04
# Epoch 40/300 | Train Loss: 0.4190 | Val Loss: 0.4185 | MAE H2O: 0.3888 | RMSE H2O: 0.5733 | MAE PL: 0.2385 | RMSE PL: 0.5671 | LR: 2.5e-04
# Epoch 41/300 | Train Loss: 0.4150 | Val Loss: 0.4071 | MAE H2O: 0.3899 | RMSE H2O: 0.5647 | MAE PL: 0.2421 | RMSE PL: 0.5577 | LR: 2.5e-04
# Epoch 42/300 | Train Loss: 0.4162 | Val Loss: 0.4064 | MAE H2O: 0.3716 | RMSE H2O: 0.5604 | MAE PL: 0.2275 | RMSE PL: 0.5525 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3947)
# Epoch 43/300 | Train Loss: 0.4144 | Val Loss: 0.3947 | MAE H2O: 0.3782 | RMSE H2O: 0.5607 | MAE PL: 0.2150 | RMSE PL: 0.5358 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3936)
# Epoch 44/300 | Train Loss: 0.4161 | Val Loss: 0.3936 | MAE H2O: 0.3721 | RMSE H2O: 0.5583 | MAE PL: 0.2099 | RMSE PL: 0.5310 | LR: 2.5e-04
# Epoch 45/300 | Train Loss: 0.4135 | Val Loss: 0.4011 | MAE H2O: 0.3754 | RMSE H2O: 0.5613 | MAE PL: 0.2280 | RMSE PL: 0.5494 | LR: 2.5e-04
# Epoch 46/300 | Train Loss: 0.4128 | Val Loss: 0.3948 | MAE H2O: 0.3837 | RMSE H2O: 0.5593 | MAE PL: 0.2258 | RMSE PL: 0.5379 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3917)
# Epoch 47/300 | Train Loss: 0.4163 | Val Loss: 0.3917 | MAE H2O: 0.3682 | RMSE H2O: 0.5544 | MAE PL: 0.2190 | RMSE PL: 0.5352 | LR: 2.5e-04
# Epoch 48/300 | Train Loss: 0.4198 | Val Loss: 0.3980 | MAE H2O: 0.3778 | RMSE H2O: 0.5645 | MAE PL: 0.2168 | RMSE PL: 0.5271 | LR: 2.5e-04
# Epoch 49/300 | Train Loss: 0.4155 | Val Loss: 0.4057 | MAE H2O: 0.3819 | RMSE H2O: 0.5675 | MAE PL: 0.2192 | RMSE PL: 0.5318 | LR: 2.5e-04
# Epoch 50/300 | Train Loss: 0.4162 | Val Loss: 0.4086 | MAE H2O: 0.4010 | RMSE H2O: 0.5927 | MAE PL: 0.2172 | RMSE PL: 0.5310 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3913)
# Epoch 51/300 | Train Loss: 0.4137 | Val Loss: 0.3913 | MAE H2O: 0.3784 | RMSE H2O: 0.5593 | MAE PL: 0.2189 | RMSE PL: 0.5281 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3898)
# Epoch 52/300 | Train Loss: 0.4144 | Val Loss: 0.3898 | MAE H2O: 0.3738 | RMSE H2O: 0.5555 | MAE PL: 0.2181 | RMSE PL: 0.5303 | LR: 2.5e-04
# Epoch 53/300 | Train Loss: 0.4097 | Val Loss: 0.4009 | MAE H2O: 0.3667 | RMSE H2O: 0.5557 | MAE PL: 0.2293 | RMSE PL: 0.5476 | LR: 2.5e-04
# Epoch 54/300 | Train Loss: 0.4139 | Val Loss: 0.3945 | MAE H2O: 0.3827 | RMSE H2O: 0.5699 | MAE PL: 0.2183 | RMSE PL: 0.5260 | LR: 2.5e-04
# Epoch 55/300 | Train Loss: 0.4116 | Val Loss: 0.4051 | MAE H2O: 0.3801 | RMSE H2O: 0.5655 | MAE PL: 0.2104 | RMSE PL: 0.5422 | LR: 2.5e-04
# Epoch 56/300 | Train Loss: 0.4115 | Val Loss: 0.4158 | MAE H2O: 0.3754 | RMSE H2O: 0.5603 | MAE PL: 0.2511 | RMSE PL: 0.5721 | LR: 2.5e-04
# Epoch 57/300 | Train Loss: 0.4129 | Val Loss: 0.4025 | MAE H2O: 0.3896 | RMSE H2O: 0.5825 | MAE PL: 0.2125 | RMSE PL: 0.5325 | LR: 2.5e-04
# Epoch 58/300 | Train Loss: 0.4131 | Val Loss: 0.3901 | MAE H2O: 0.3700 | RMSE H2O: 0.5571 | MAE PL: 0.2104 | RMSE PL: 0.5275 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3786)
# Epoch 59/300 | Train Loss: 0.4005 | Val Loss: 0.3786 | MAE H2O: 0.3656 | RMSE H2O: 0.5455 | MAE PL: 0.2084 | RMSE PL: 0.5213 | LR: 1.3e-04
# Epoch 60/300 | Train Loss: 0.3959 | Val Loss: 0.3907 | MAE H2O: 0.3661 | RMSE H2O: 0.5552 | MAE PL: 0.1967 | RMSE PL: 0.5204 | LR: 1.3e-04
# Epoch 61/300 | Train Loss: 0.4006 | Val Loss: 0.3866 | MAE H2O: 0.3726 | RMSE H2O: 0.5552 | MAE PL: 0.2086 | RMSE PL: 0.5280 | LR: 1.3e-04
# Epoch 62/300 | Train Loss: 0.3950 | Val Loss: 0.3790 | MAE H2O: 0.3622 | RMSE H2O: 0.5456 | MAE PL: 0.2075 | RMSE PL: 0.5212 | LR: 1.3e-04
# Epoch 63/300 | Train Loss: 0.3965 | Val Loss: 0.3803 | MAE H2O: 0.3605 | RMSE H2O: 0.5461 | MAE PL: 0.2025 | RMSE PL: 0.5219 | LR: 1.3e-04
# Epoch 64/300 | Train Loss: 0.3948 | Val Loss: 0.3890 | MAE H2O: 0.3597 | RMSE H2O: 0.5487 | MAE PL: 0.2035 | RMSE PL: 0.5287 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3778)
# Epoch 65/300 | Train Loss: 0.3946 | Val Loss: 0.3778 | MAE H2O: 0.3614 | RMSE H2O: 0.5436 | MAE PL: 0.2069 | RMSE PL: 0.5209 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3713)
# Epoch 66/300 | Train Loss: 0.3977 | Val Loss: 0.3713 | MAE H2O: 0.3576 | RMSE H2O: 0.5387 | MAE PL: 0.2035 | RMSE PL: 0.5148 | LR: 1.3e-04
# Epoch 67/300 | Train Loss: 0.3988 | Val Loss: 0.3797 | MAE H2O: 0.3595 | RMSE H2O: 0.5433 | MAE PL: 0.2045 | RMSE PL: 0.5211 | LR: 1.3e-04
# Epoch 68/300 | Train Loss: 0.3937 | Val Loss: 0.3845 | MAE H2O: 0.3701 | RMSE H2O: 0.5571 | MAE PL: 0.2098 | RMSE PL: 0.5221 | LR: 1.3e-04
# Epoch 69/300 | Train Loss: 0.3958 | Val Loss: 0.3781 | MAE H2O: 0.3632 | RMSE H2O: 0.5468 | MAE PL: 0.2066 | RMSE PL: 0.5175 | LR: 1.3e-04
# Epoch 70/300 | Train Loss: 0.3938 | Val Loss: 0.3920 | MAE H2O: 0.3725 | RMSE H2O: 0.5608 | MAE PL: 0.2042 | RMSE PL: 0.5251 | LR: 1.3e-04
# Epoch 71/300 | Train Loss: 0.3938 | Val Loss: 0.3720 | MAE H2O: 0.3577 | RMSE H2O: 0.5392 | MAE PL: 0.1973 | RMSE PL: 0.5156 | LR: 1.3e-04
# Epoch 72/300 | Train Loss: 0.3933 | Val Loss: 0.3755 | MAE H2O: 0.3602 | RMSE H2O: 0.5453 | MAE PL: 0.1979 | RMSE PL: 0.5142 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3713)
# Epoch 73/300 | Train Loss: 0.3856 | Val Loss: 0.3713 | MAE H2O: 0.3545 | RMSE H2O: 0.5366 | MAE PL: 0.2058 | RMSE PL: 0.5183 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3659)
# Epoch 74/300 | Train Loss: 0.3843 | Val Loss: 0.3659 | MAE H2O: 0.3505 | RMSE H2O: 0.5335 | MAE PL: 0.1942 | RMSE PL: 0.5106 | LR: 6.3e-05
# Epoch 75/300 | Train Loss: 0.3842 | Val Loss: 0.3665 | MAE H2O: 0.3515 | RMSE H2O: 0.5349 | MAE PL: 0.1928 | RMSE PL: 0.5091 | LR: 6.3e-05
# Epoch 76/300 | Train Loss: 0.3858 | Val Loss: 0.3700 | MAE H2O: 0.3507 | RMSE H2O: 0.5370 | MAE PL: 0.1960 | RMSE PL: 0.5136 | LR: 6.3e-05
# Epoch 77/300 | Train Loss: 0.3842 | Val Loss: 0.3671 | MAE H2O: 0.3507 | RMSE H2O: 0.5342 | MAE PL: 0.2002 | RMSE PL: 0.5123 | LR: 6.3e-05
# Epoch 78/300 | Train Loss: 0.3838 | Val Loss: 0.3702 | MAE H2O: 0.3541 | RMSE H2O: 0.5386 | MAE PL: 0.1933 | RMSE PL: 0.5121 | LR: 6.3e-05
# Epoch 79/300 | Train Loss: 0.3823 | Val Loss: 0.3743 | MAE H2O: 0.3560 | RMSE H2O: 0.5439 | MAE PL: 0.2015 | RMSE PL: 0.5169 | LR: 6.3e-05
# Epoch 80/300 | Train Loss: 0.3839 | Val Loss: 0.3849 | MAE H2O: 0.3631 | RMSE H2O: 0.5435 | MAE PL: 0.2185 | RMSE PL: 0.5349 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3626)
# Epoch 81/300 | Train Loss: 0.3792 | Val Loss: 0.3626 | MAE H2O: 0.3479 | RMSE H2O: 0.5305 | MAE PL: 0.1902 | RMSE PL: 0.5076 | LR: 3.1e-05
# Epoch 82/300 | Train Loss: 0.3809 | Val Loss: 0.3628 | MAE H2O: 0.3486 | RMSE H2O: 0.5302 | MAE PL: 0.1908 | RMSE PL: 0.5078 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3617)
# Epoch 83/300 | Train Loss: 0.3784 | Val Loss: 0.3617 | MAE H2O: 0.3470 | RMSE H2O: 0.5304 | MAE PL: 0.1869 | RMSE PL: 0.5060 | LR: 3.1e-05
# Epoch 84/300 | Train Loss: 0.3772 | Val Loss: 0.3618 | MAE H2O: 0.3463 | RMSE H2O: 0.5291 | MAE PL: 0.1939 | RMSE PL: 0.5067 | LR: 3.1e-05
# Epoch 85/300 | Train Loss: 0.3776 | Val Loss: 0.3621 | MAE H2O: 0.3459 | RMSE H2O: 0.5288 | MAE PL: 0.1923 | RMSE PL: 0.5076 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3610)
# Epoch 86/300 | Train Loss: 0.3811 | Val Loss: 0.3610 | MAE H2O: 0.3461 | RMSE H2O: 0.5293 | MAE PL: 0.1868 | RMSE PL: 0.5060 | LR: 3.1e-05
# Epoch 87/300 | Train Loss: 0.3785 | Val Loss: 0.3627 | MAE H2O: 0.3469 | RMSE H2O: 0.5307 | MAE PL: 0.1888 | RMSE PL: 0.5074 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3604)
# Epoch 88/300 | Train Loss: 0.3772 | Val Loss: 0.3604 | MAE H2O: 0.3458 | RMSE H2O: 0.5295 | MAE PL: 0.1892 | RMSE PL: 0.5045 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3603)
# Epoch 89/300 | Train Loss: 0.3784 | Val Loss: 0.3603 | MAE H2O: 0.3471 | RMSE H2O: 0.5277 | MAE PL: 0.1906 | RMSE PL: 0.5061 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3602)
# Epoch 90/300 | Train Loss: 0.3767 | Val Loss: 0.3602 | MAE H2O: 0.3433 | RMSE H2O: 0.5282 | MAE PL: 0.1876 | RMSE PL: 0.5049 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3597)
# Epoch 91/300 | Train Loss: 0.3764 | Val Loss: 0.3597 | MAE H2O: 0.3457 | RMSE H2O: 0.5270 | MAE PL: 0.1884 | RMSE PL: 0.5067 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3586)
# Epoch 92/300 | Train Loss: 0.3768 | Val Loss: 0.3586 | MAE H2O: 0.3457 | RMSE H2O: 0.5271 | MAE PL: 0.1883 | RMSE PL: 0.5035 | LR: 3.1e-05
# Epoch 93/300 | Train Loss: 0.3757 | Val Loss: 0.3596 | MAE H2O: 0.3457 | RMSE H2O: 0.5277 | MAE PL: 0.1905 | RMSE PL: 0.5064 | LR: 3.1e-05
# Epoch 94/300 | Train Loss: 0.3777 | Val Loss: 0.3589 | MAE H2O: 0.3451 | RMSE H2O: 0.5265 | MAE PL: 0.1879 | RMSE PL: 0.5059 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3571)
# Epoch 95/300 | Train Loss: 0.3758 | Val Loss: 0.3571 | MAE H2O: 0.3423 | RMSE H2O: 0.5263 | MAE PL: 0.1864 | RMSE PL: 0.5029 | LR: 3.1e-05
# Epoch 96/300 | Train Loss: 0.3745 | Val Loss: 0.3584 | MAE H2O: 0.3424 | RMSE H2O: 0.5256 | MAE PL: 0.1900 | RMSE PL: 0.5060 | LR: 3.1e-05
# Epoch 97/300 | Train Loss: 0.3742 | Val Loss: 0.3584 | MAE H2O: 0.3441 | RMSE H2O: 0.5265 | MAE PL: 0.1901 | RMSE PL: 0.5054 | LR: 3.1e-05
# Epoch 98/300 | Train Loss: 0.3743 | Val Loss: 0.3579 | MAE H2O: 0.3442 | RMSE H2O: 0.5269 | MAE PL: 0.1855 | RMSE PL: 0.5038 | LR: 3.1e-05
# Epoch 99/300 | Train Loss: 0.3742 | Val Loss: 0.3617 | MAE H2O: 0.3450 | RMSE H2O: 0.5277 | MAE PL: 0.1920 | RMSE PL: 0.5088 | LR: 3.1e-05
# Epoch 100/300 | Train Loss: 0.3985 | Val Loss: 0.3572 | MAE H2O: 0.3438 | RMSE H2O: 0.5257 | MAE PL: 0.1903 | RMSE PL: 0.5044 | LR: 3.1e-05
# Epoch 101/300 | Train Loss: 0.3742 | Val Loss: 0.3584 | MAE H2O: 0.3438 | RMSE H2O: 0.5280 | MAE PL: 0.1881 | RMSE PL: 0.5045 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3563)
# Epoch 102/300 | Train Loss: 0.3714 | Val Loss: 0.3563 | MAE H2O: 0.3414 | RMSE H2O: 0.5246 | MAE PL: 0.1845 | RMSE PL: 0.5036 | LR: 1.6e-05
# Epoch 103/300 | Train Loss: 0.3722 | Val Loss: 0.3579 | MAE H2O: 0.3444 | RMSE H2O: 0.5258 | MAE PL: 0.1879 | RMSE PL: 0.5042 | LR: 1.6e-05
# Epoch 104/300 | Train Loss: 0.3719 | Val Loss: 0.3573 | MAE H2O: 0.3414 | RMSE H2O: 0.5243 | MAE PL: 0.1867 | RMSE PL: 0.5049 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3539)
# Epoch 105/300 | Train Loss: 0.3707 | Val Loss: 0.3539 | MAE H2O: 0.3401 | RMSE H2O: 0.5226 | MAE PL: 0.1833 | RMSE PL: 0.5014 | LR: 1.6e-05
# Epoch 106/300 | Train Loss: 0.3706 | Val Loss: 0.3549 | MAE H2O: 0.3417 | RMSE H2O: 0.5244 | MAE PL: 0.1847 | RMSE PL: 0.5016 | LR: 1.6e-05
# Epoch 107/300 | Train Loss: 0.3719 | Val Loss: 0.3547 | MAE H2O: 0.3402 | RMSE H2O: 0.5231 | MAE PL: 0.1832 | RMSE PL: 0.5018 | LR: 1.6e-05
# Epoch 108/300 | Train Loss: 0.3710 | Val Loss: 0.3544 | MAE H2O: 0.3399 | RMSE H2O: 0.5236 | MAE PL: 0.1820 | RMSE PL: 0.5014 | LR: 1.6e-05
# Epoch 109/300 | Train Loss: 0.3721 | Val Loss: 0.3567 | MAE H2O: 0.3403 | RMSE H2O: 0.5241 | MAE PL: 0.1850 | RMSE PL: 0.5041 | LR: 1.6e-05
# Epoch 110/300 | Train Loss: 0.3717 | Val Loss: 0.3574 | MAE H2O: 0.3423 | RMSE H2O: 0.5246 | MAE PL: 0.1892 | RMSE PL: 0.5055 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3534)
# Epoch 111/300 | Train Loss: 0.3709 | Val Loss: 0.3534 | MAE H2O: 0.3406 | RMSE H2O: 0.5218 | MAE PL: 0.1846 | RMSE PL: 0.5017 | LR: 1.6e-05
# Epoch 112/300 | Train Loss: 0.3702 | Val Loss: 0.3558 | MAE H2O: 0.3415 | RMSE H2O: 0.5241 | MAE PL: 0.1873 | RMSE PL: 0.5040 | LR: 1.6e-05
# Epoch 113/300 | Train Loss: 0.3698 | Val Loss: 0.3548 | MAE H2O: 0.3436 | RMSE H2O: 0.5244 | MAE PL: 0.1870 | RMSE PL: 0.5020 | LR: 1.6e-05
# Epoch 114/300 | Train Loss: 0.3699 | Val Loss: 0.3537 | MAE H2O: 0.3401 | RMSE H2O: 0.5229 | MAE PL: 0.1834 | RMSE PL: 0.5010 | LR: 1.6e-05
# Epoch 115/300 | Train Loss: 0.3722 | Val Loss: 0.3547 | MAE H2O: 0.3401 | RMSE H2O: 0.5231 | MAE PL: 0.1819 | RMSE PL: 0.5020 | LR: 1.6e-05
# Epoch 116/300 | Train Loss: 0.3691 | Val Loss: 0.3535 | MAE H2O: 0.3425 | RMSE H2O: 0.5231 | MAE PL: 0.1843 | RMSE PL: 0.5012 | LR: 1.6e-05
# Epoch 117/300 | Train Loss: 0.3714 | Val Loss: 0.3578 | MAE H2O: 0.3412 | RMSE H2O: 0.5253 | MAE PL: 0.1827 | RMSE PL: 0.5046 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3522)
# Epoch 118/300 | Train Loss: 0.3686 | Val Loss: 0.3522 | MAE H2O: 0.3394 | RMSE H2O: 0.5215 | MAE PL: 0.1826 | RMSE PL: 0.5001 | LR: 7.8e-06
# Epoch 119/300 | Train Loss: 0.3677 | Val Loss: 0.3538 | MAE H2O: 0.3404 | RMSE H2O: 0.5221 | MAE PL: 0.1850 | RMSE PL: 0.5018 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3518)
# Epoch 120/300 | Train Loss: 0.3676 | Val Loss: 0.3518 | MAE H2O: 0.3385 | RMSE H2O: 0.5211 | MAE PL: 0.1810 | RMSE PL: 0.4999 | LR: 7.8e-06
# Epoch 121/300 | Train Loss: 0.3698 | Val Loss: 0.3519 | MAE H2O: 0.3395 | RMSE H2O: 0.5215 | MAE PL: 0.1816 | RMSE PL: 0.4998 | LR: 7.8e-06
# Epoch 122/300 | Train Loss: 0.3677 | Val Loss: 0.3534 | MAE H2O: 0.3398 | RMSE H2O: 0.5222 | MAE PL: 0.1804 | RMSE PL: 0.5011 | LR: 7.8e-06
# Epoch 123/300 | Train Loss: 0.3675 | Val Loss: 0.3529 | MAE H2O: 0.3389 | RMSE H2O: 0.5215 | MAE PL: 0.1809 | RMSE PL: 0.5011 | LR: 7.8e-06
# Epoch 124/300 | Train Loss: 0.3672 | Val Loss: 0.3523 | MAE H2O: 0.3384 | RMSE H2O: 0.5211 | MAE PL: 0.1806 | RMSE PL: 0.5005 | LR: 7.8e-06
# ✅ Model improved and saved (val_loss = 0.3518)
# Epoch 125/300 | Train Loss: 0.3670 | Val Loss: 0.3518 | MAE H2O: 0.3380 | RMSE H2O: 0.5206 | MAE PL: 0.1821 | RMSE PL: 0.5005 | LR: 7.8e-06
# Epoch 126/300 | Train Loss: 0.3659 | Val Loss: 0.3527 | MAE H2O: 0.3398 | RMSE H2O: 0.5219 | MAE PL: 0.1830 | RMSE PL: 0.5010 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3512)
# Epoch 127/300 | Train Loss: 0.3662 | Val Loss: 0.3512 | MAE H2O: 0.3387 | RMSE H2O: 0.5206 | MAE PL: 0.1812 | RMSE PL: 0.4993 | LR: 3.9e-06
# Epoch 128/300 | Train Loss: 0.3659 | Val Loss: 0.3519 | MAE H2O: 0.3394 | RMSE H2O: 0.5213 | MAE PL: 0.1833 | RMSE PL: 0.5002 | LR: 3.9e-06
# Epoch 129/300 | Train Loss: 0.3683 | Val Loss: 0.3512 | MAE H2O: 0.3390 | RMSE H2O: 0.5205 | MAE PL: 0.1800 | RMSE PL: 0.4995 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3508)
# Epoch 130/300 | Train Loss: 0.3662 | Val Loss: 0.3508 | MAE H2O: 0.3380 | RMSE H2O: 0.5202 | MAE PL: 0.1810 | RMSE PL: 0.4994 | LR: 3.9e-06
# Epoch 131/300 | Train Loss: 0.3661 | Val Loss: 0.3510 | MAE H2O: 0.3392 | RMSE H2O: 0.5205 | MAE PL: 0.1810 | RMSE PL: 0.4992 | LR: 3.9e-06
# Epoch 132/300 | Train Loss: 0.3664 | Val Loss: 0.3514 | MAE H2O: 0.3379 | RMSE H2O: 0.5203 | MAE PL: 0.1812 | RMSE PL: 0.5000 | LR: 3.9e-06
# Epoch 133/300 | Train Loss: 0.3692 | Val Loss: 0.3515 | MAE H2O: 0.3389 | RMSE H2O: 0.5208 | MAE PL: 0.1826 | RMSE PL: 0.4997 | LR: 3.9e-06
# Epoch 134/300 | Train Loss: 0.3653 | Val Loss: 0.3514 | MAE H2O: 0.3382 | RMSE H2O: 0.5204 | MAE PL: 0.1803 | RMSE PL: 0.4998 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3508)
# Epoch 135/300 | Train Loss: 0.3669 | Val Loss: 0.3508 | MAE H2O: 0.3378 | RMSE H2O: 0.5201 | MAE PL: 0.1803 | RMSE PL: 0.4993 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3507)
# Epoch 136/300 | Train Loss: 0.3659 | Val Loss: 0.3507 | MAE H2O: 0.3381 | RMSE H2O: 0.5201 | MAE PL: 0.1807 | RMSE PL: 0.4992 | LR: 3.9e-06
# Epoch 137/300 | Train Loss: 0.3665 | Val Loss: 0.3509 | MAE H2O: 0.3381 | RMSE H2O: 0.5201 | MAE PL: 0.1822 | RMSE PL: 0.4997 | LR: 3.9e-06
# Epoch 138/300 | Train Loss: 0.3658 | Val Loss: 0.3513 | MAE H2O: 0.3388 | RMSE H2O: 0.5205 | MAE PL: 0.1811 | RMSE PL: 0.4996 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3504)
# Epoch 139/300 | Train Loss: 0.3654 | Val Loss: 0.3504 | MAE H2O: 0.3381 | RMSE H2O: 0.5198 | MAE PL: 0.1806 | RMSE PL: 0.4990 | LR: 3.9e-06
# Epoch 140/300 | Train Loss: 0.3659 | Val Loss: 0.3511 | MAE H2O: 0.3382 | RMSE H2O: 0.5202 | MAE PL: 0.1802 | RMSE PL: 0.4996 | LR: 3.9e-06
# Epoch 141/300 | Train Loss: 0.3659 | Val Loss: 0.3506 | MAE H2O: 0.3375 | RMSE H2O: 0.5199 | MAE PL: 0.1801 | RMSE PL: 0.4992 | LR: 3.9e-06
# Epoch 142/300 | Train Loss: 0.3653 | Val Loss: 0.3506 | MAE H2O: 0.3379 | RMSE H2O: 0.5201 | MAE PL: 0.1805 | RMSE PL: 0.4991 | LR: 3.9e-06
# Epoch 143/300 | Train Loss: 0.3648 | Val Loss: 0.3508 | MAE H2O: 0.3374 | RMSE H2O: 0.5201 | MAE PL: 0.1799 | RMSE PL: 0.4994 | LR: 3.9e-06
# ✅ Model improved and saved (val_loss = 0.3504)
# Epoch 144/300 | Train Loss: 0.3649 | Val Loss: 0.3504 | MAE H2O: 0.3385 | RMSE H2O: 0.5199 | MAE PL: 0.1800 | RMSE PL: 0.4990 | LR: 3.9e-06
# Epoch 145/300 | Train Loss: 0.3678 | Val Loss: 0.3506 | MAE H2O: 0.3384 | RMSE H2O: 0.5202 | MAE PL: 0.1802 | RMSE PL: 0.4991 | LR: 2.0e-06
# Epoch 146/300 | Train Loss: 0.3647 | Val Loss: 0.3504 | MAE H2O: 0.3381 | RMSE H2O: 0.5198 | MAE PL: 0.1811 | RMSE PL: 0.4990 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3501)
# Epoch 147/300 | Train Loss: 0.3656 | Val Loss: 0.3501 | MAE H2O: 0.3381 | RMSE H2O: 0.5197 | MAE PL: 0.1810 | RMSE PL: 0.4987 | LR: 2.0e-06
# Epoch 148/300 | Train Loss: 0.3663 | Val Loss: 0.3502 | MAE H2O: 0.3377 | RMSE H2O: 0.5197 | MAE PL: 0.1798 | RMSE PL: 0.4988 | LR: 2.0e-06
# Epoch 149/300 | Train Loss: 0.3640 | Val Loss: 0.3501 | MAE H2O: 0.3388 | RMSE H2O: 0.5198 | MAE PL: 0.1808 | RMSE PL: 0.4987 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3500)
# Epoch 150/300 | Train Loss: 0.3655 | Val Loss: 0.3500 | MAE H2O: 0.3378 | RMSE H2O: 0.5196 | MAE PL: 0.1799 | RMSE PL: 0.4987 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3499)
# Epoch 151/300 | Train Loss: 0.3638 | Val Loss: 0.3499 | MAE H2O: 0.3380 | RMSE H2O: 0.5195 | MAE PL: 0.1806 | RMSE PL: 0.4987 | LR: 2.0e-06
# Epoch 152/300 | Train Loss: 0.3648 | Val Loss: 0.3504 | MAE H2O: 0.3374 | RMSE H2O: 0.5197 | MAE PL: 0.1807 | RMSE PL: 0.4992 | LR: 2.0e-06
# Epoch 153/300 | Train Loss: 0.3638 | Val Loss: 0.3501 | MAE H2O: 0.3378 | RMSE H2O: 0.5196 | MAE PL: 0.1814 | RMSE PL: 0.4989 | LR: 2.0e-06
# Epoch 154/300 | Train Loss: 0.3650 | Val Loss: 0.3501 | MAE H2O: 0.3375 | RMSE H2O: 0.5196 | MAE PL: 0.1800 | RMSE PL: 0.4988 | LR: 2.0e-06
# Epoch 155/300 | Train Loss: 0.3651 | Val Loss: 0.3504 | MAE H2O: 0.3378 | RMSE H2O: 0.5199 | MAE PL: 0.1801 | RMSE PL: 0.4990 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3499)
# Epoch 156/300 | Train Loss: 0.3660 | Val Loss: 0.3499 | MAE H2O: 0.3375 | RMSE H2O: 0.5194 | MAE PL: 0.1801 | RMSE PL: 0.4987 | LR: 2.0e-06
# Epoch 157/300 | Train Loss: 0.3659 | Val Loss: 0.3501 | MAE H2O: 0.3379 | RMSE H2O: 0.5196 | MAE PL: 0.1815 | RMSE PL: 0.4991 | LR: 2.0e-06
# Epoch 158/300 | Train Loss: 0.3640 | Val Loss: 0.3509 | MAE H2O: 0.3375 | RMSE H2O: 0.5202 | MAE PL: 0.1801 | RMSE PL: 0.4995 | LR: 2.0e-06
# Epoch 159/300 | Train Loss: 0.3650 | Val Loss: 0.3500 | MAE H2O: 0.3380 | RMSE H2O: 0.5195 | MAE PL: 0.1810 | RMSE PL: 0.4989 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3497)
# Epoch 160/300 | Train Loss: 0.3645 | Val Loss: 0.3497 | MAE H2O: 0.3378 | RMSE H2O: 0.5194 | MAE PL: 0.1806 | RMSE PL: 0.4986 | LR: 2.0e-06
# Epoch 161/300 | Train Loss: 0.3637 | Val Loss: 0.3497 | MAE H2O: 0.3376 | RMSE H2O: 0.5193 | MAE PL: 0.1800 | RMSE PL: 0.4986 | LR: 2.0e-06
# ✅ Model improved and saved (val_loss = 0.3496)
# Epoch 162/300 | Train Loss: 0.3666 | Val Loss: 0.3496 | MAE H2O: 0.3376 | RMSE H2O: 0.5192 | MAE PL: 0.1799 | RMSE PL: 0.4985 | LR: 2.0e-06
# Epoch 163/300 | Train Loss: 0.3642 | Val Loss: 0.3505 | MAE H2O: 0.3372 | RMSE H2O: 0.5197 | MAE PL: 0.1808 | RMSE PL: 0.4994 | LR: 2.0e-06
# Epoch 164/300 | Train Loss: 0.3648 | Val Loss: 0.3499 | MAE H2O: 0.3372 | RMSE H2O: 0.5196 | MAE PL: 0.1802 | RMSE PL: 0.4986 | LR: 2.0e-06
# Epoch 165/300 | Train Loss: 0.3632 | Val Loss: 0.3496 | MAE H2O: 0.3377 | RMSE H2O: 0.5194 | MAE PL: 0.1803 | RMSE PL: 0.4983 | LR: 2.0e-06
# Epoch 166/300 | Train Loss: 0.3653 | Val Loss: 0.3497 | MAE H2O: 0.3374 | RMSE H2O: 0.5192 | MAE PL: 0.1807 | RMSE PL: 0.4988 | LR: 2.0e-06
# Epoch 167/300 | Train Loss: 0.3639 | Val Loss: 0.3497 | MAE H2O: 0.3375 | RMSE H2O: 0.5193 | MAE PL: 0.1804 | RMSE PL: 0.4987 | LR: 2.0e-06
# Epoch 168/300 | Train Loss: 0.3670 | Val Loss: 0.3496 | MAE H2O: 0.3374 | RMSE H2O: 0.5193 | MAE PL: 0.1803 | RMSE PL: 0.4984 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3495)
# Epoch 169/300 | Train Loss: 0.3640 | Val Loss: 0.3495 | MAE H2O: 0.3372 | RMSE H2O: 0.5192 | MAE PL: 0.1797 | RMSE PL: 0.4984 | LR: 9.8e-07
# Epoch 170/300 | Train Loss: 0.3650 | Val Loss: 0.3500 | MAE H2O: 0.3372 | RMSE H2O: 0.5194 | MAE PL: 0.1801 | RMSE PL: 0.4989 | LR: 9.8e-07
# Epoch 171/300 | Train Loss: 0.3636 | Val Loss: 0.3496 | MAE H2O: 0.3374 | RMSE H2O: 0.5192 | MAE PL: 0.1799 | RMSE PL: 0.4984 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3495)
# Epoch 172/300 | Train Loss: 0.3625 | Val Loss: 0.3495 | MAE H2O: 0.3373 | RMSE H2O: 0.5190 | MAE PL: 0.1802 | RMSE PL: 0.4985 | LR: 9.8e-07
# Epoch 173/300 | Train Loss: 0.3645 | Val Loss: 0.3496 | MAE H2O: 0.3371 | RMSE H2O: 0.5191 | MAE PL: 0.1796 | RMSE PL: 0.4986 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3494)
# Epoch 174/300 | Train Loss: 0.3648 | Val Loss: 0.3494 | MAE H2O: 0.3372 | RMSE H2O: 0.5190 | MAE PL: 0.1795 | RMSE PL: 0.4984 | LR: 9.8e-07
# Epoch 175/300 | Train Loss: 0.3653 | Val Loss: 0.3495 | MAE H2O: 0.3379 | RMSE H2O: 0.5192 | MAE PL: 0.1804 | RMSE PL: 0.4984 | LR: 9.8e-07
# Epoch 176/300 | Train Loss: 0.3625 | Val Loss: 0.3495 | MAE H2O: 0.3379 | RMSE H2O: 0.5193 | MAE PL: 0.1808 | RMSE PL: 0.4984 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3493)
# Epoch 177/300 | Train Loss: 0.3644 | Val Loss: 0.3493 | MAE H2O: 0.3373 | RMSE H2O: 0.5190 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3492)
# Epoch 178/300 | Train Loss: 0.3641 | Val Loss: 0.3492 | MAE H2O: 0.3374 | RMSE H2O: 0.5190 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 9.8e-07
# Epoch 179/300 | Train Loss: 0.3634 | Val Loss: 0.3493 | MAE H2O: 0.3374 | RMSE H2O: 0.5191 | MAE PL: 0.1797 | RMSE PL: 0.4983 | LR: 9.8e-07
# Epoch 180/300 | Train Loss: 0.3636 | Val Loss: 0.3500 | MAE H2O: 0.3372 | RMSE H2O: 0.5194 | MAE PL: 0.1794 | RMSE PL: 0.4989 | LR: 9.8e-07
# Epoch 181/300 | Train Loss: 0.3659 | Val Loss: 0.3493 | MAE H2O: 0.3373 | RMSE H2O: 0.5191 | MAE PL: 0.1798 | RMSE PL: 0.4982 | LR: 9.8e-07
# Epoch 182/300 | Train Loss: 0.3639 | Val Loss: 0.3494 | MAE H2O: 0.3372 | RMSE H2O: 0.5192 | MAE PL: 0.1796 | RMSE PL: 0.4982 | LR: 9.8e-07
# ✅ Model improved and saved (val_loss = 0.3492)
# Epoch 183/300 | Train Loss: 0.3657 | Val Loss: 0.3492 | MAE H2O: 0.3371 | RMSE H2O: 0.5190 | MAE PL: 0.1798 | RMSE PL: 0.4982 | LR: 9.8e-07
# Epoch 184/300 | Train Loss: 0.3638 | Val Loss: 0.3493 | MAE H2O: 0.3374 | RMSE H2O: 0.5190 | MAE PL: 0.1803 | RMSE PL: 0.4982 | LR: 4.9e-07
# Epoch 185/300 | Train Loss: 0.3630 | Val Loss: 0.3495 | MAE H2O: 0.3370 | RMSE H2O: 0.5191 | MAE PL: 0.1795 | RMSE PL: 0.4985 | LR: 4.9e-07
# Epoch 186/300 | Train Loss: 0.3629 | Val Loss: 0.3493 | MAE H2O: 0.3372 | RMSE H2O: 0.5190 | MAE PL: 0.1799 | RMSE PL: 0.4983 | LR: 4.9e-07
# Epoch 187/300 | Train Loss: 0.3641 | Val Loss: 0.3492 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1797 | RMSE PL: 0.4982 | LR: 4.9e-07
# Epoch 188/300 | Train Loss: 0.3641 | Val Loss: 0.3493 | MAE H2O: 0.3372 | RMSE H2O: 0.5190 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 4.9e-07
# Epoch 189/300 | Train Loss: 0.3636 | Val Loss: 0.3493 | MAE H2O: 0.3370 | RMSE H2O: 0.5190 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 4.9e-07
# ✅ Model improved and saved (val_loss = 0.3491)
# Epoch 190/300 | Train Loss: 0.3637 | Val Loss: 0.3491 | MAE H2O: 0.3373 | RMSE H2O: 0.5190 | MAE PL: 0.1797 | RMSE PL: 0.4981 | LR: 4.9e-07
# ✅ Model improved and saved (val_loss = 0.3491)
# Epoch 191/300 | Train Loss: 0.3633 | Val Loss: 0.3491 | MAE H2O: 0.3372 | RMSE H2O: 0.5189 | MAE PL: 0.1798 | RMSE PL: 0.4981 | LR: 4.9e-07
# Epoch 192/300 | Train Loss: 0.3639 | Val Loss: 0.3493 | MAE H2O: 0.3370 | RMSE H2O: 0.5190 | MAE PL: 0.1795 | RMSE PL: 0.4983 | LR: 4.9e-07
# Epoch 193/300 | Train Loss: 0.3649 | Val Loss: 0.3493 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1797 | RMSE PL: 0.4983 | LR: 4.9e-07
# Epoch 194/300 | Train Loss: 0.3651 | Val Loss: 0.3492 | MAE H2O: 0.3371 | RMSE H2O: 0.5190 | MAE PL: 0.1797 | RMSE PL: 0.4982 | LR: 4.9e-07
# ✅ Model improved and saved (val_loss = 0.3491)
# Epoch 195/300 | Train Loss: 0.3645 | Val Loss: 0.3491 | MAE H2O: 0.3372 | RMSE H2O: 0.5189 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 4.9e-07
# ✅ Model improved and saved (val_loss = 0.3491)
# Epoch 196/300 | Train Loss: 0.3643 | Val Loss: 0.3491 | MAE H2O: 0.3373 | RMSE H2O: 0.5189 | MAE PL: 0.1797 | RMSE PL: 0.4981 | LR: 2.4e-07
# Epoch 197/300 | Train Loss: 0.3628 | Val Loss: 0.3491 | MAE H2O: 0.3371 | RMSE H2O: 0.5189 | MAE PL: 0.1796 | RMSE PL: 0.4981 | LR: 2.4e-07
# ✅ Model improved and saved (val_loss = 0.3491)
# Epoch 198/300 | Train Loss: 0.3683 | Val Loss: 0.3491 | MAE H2O: 0.3372 | RMSE H2O: 0.5189 | MAE PL: 0.1797 | RMSE PL: 0.4981 | LR: 2.4e-07
# Epoch 199/300 | Train Loss: 0.3645 | Val Loss: 0.3492 | MAE H2O: 0.3369 | RMSE H2O: 0.5189 | MAE PL: 0.1795 | RMSE PL: 0.4983 | LR: 2.4e-07
# Epoch 200/300 | Train Loss: 0.3645 | Val Loss: 0.3491 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1795 | RMSE PL: 0.4981 | LR: 2.4e-07
# Epoch 201/300 | Train Loss: 0.3639 | Val Loss: 0.3492 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 2.4e-07
# Epoch 202/300 | Train Loss: 0.3647 | Val Loss: 0.3492 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1795 | RMSE PL: 0.4983 | LR: 1.2e-07
# Epoch 203/300 | Train Loss: 0.3626 | Val Loss: 0.3491 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 1.2e-07
# Epoch 204/300 | Train Loss: 0.3662 | Val Loss: 0.3492 | MAE H2O: 0.3371 | RMSE H2O: 0.5189 | MAE PL: 0.1794 | RMSE PL: 0.4982 | LR: 1.2e-07
# Epoch 205/300 | Train Loss: 0.3628 | Val Loss: 0.3491 | MAE H2O: 0.3371 | RMSE H2O: 0.5189 | MAE PL: 0.1795 | RMSE PL: 0.4982 | LR: 1.2e-07
# Epoch 206/300 | Train Loss: 0.3647 | Val Loss: 0.3491 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1796 | RMSE PL: 0.4982 | LR: 1.2e-07
# Epoch 207/300 | Train Loss: 0.3623 | Val Loss: 0.3491 | MAE H2O: 0.3370 | RMSE H2O: 0.5189 | MAE PL: 0.1796 | RMSE PL: 0.4982 | LR: 1.2e-07
# ⛔ Early stopping at epoch 208

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correct unpacking from evaluate
(y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl) = evaluate(model, test_loader)

# Concatenate outputs
y_pred_test_scaled = np.concatenate([y_pred_h2o, y_pred_pl], axis=1)
y_true_test_scaled = np.concatenate([y_true_h2o, y_true_pl], axis=1)

# Inverse transform
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_true_test = scaler_y.inverse_transform(y_true_test_scaled)

# Split again
y_pred_h2o = y_pred_test[:, :67]
y_pred_pl  = y_pred_test[:, 67:]

y_true_h2o = y_true_test[:, :67]
y_true_pl  = y_true_test[:, 67:]

# Optionally concatenate to compute overall metrics
y_true_test = np.concatenate([y_true_pl, y_true_h2o], axis=1)
y_pred_test = np.concatenate([y_pred_pl, y_pred_h2o], axis=1)

# Compute test metrics
test_mae = mean_absolute_error(y_true_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"\n✅ Test MAE:  {test_mae:.4f}")
print(f"✅ Test RMSE: {test_rmse:.4f}")

# You can also compute them separately:
mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

print(f"\n🌊 H2O  → MAE: {mae_h2o:.4f} | RMSE: {rmse_h2o:.4f}")
print(f"📉 PL   → MAE: {mae_pl:.4f} | RMSE: {rmse_pl:.4f}")
# Out:
# ✅ Test MAE:  1.1593
# ✅ Test RMSE: 4.2883
#
# 🌊 H2O  → MAE: 0.0004 | RMSE: 0.0011
# 📉 PL   → MAE: 2.3181 | RMSE: 6.0645

# %%
output_index = 120  # index within concatenated output (0–133)

plt.figure(figsize=(10, 5))
plt.plot(y_true_test[:, output_index], label='True', alpha=0.7)
plt.plot(y_pred_test[:, output_index], label='Predicted', alpha=0.7)
plt.title(f"True vs Predicted - Output #{output_index}")
plt.xlabel("Sample index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose a sample index
i = 120

# Extract profiles for test sample i
pl_profile_true = y_true_pl[i]
h2o_profile_true = y_true_h2o[i]

pl_profile_pred = y_pred_pl[i]
h2o_profile_pred = y_pred_h2o[i]

# Plot profile
plt.figure(figsize=(7, 6))
plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
plt.gca().invert_yaxis()
plt.xlabel("H2O content [vmr]")
plt.ylabel("Pressure Layer [mbar]")
#plt.ylim(0, 1000)
plt.title("H2O content vs Pressure Level")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for i in range(3):
    pl_profile_true = y_true_pl[i]
    h2o_profile_true = y_true_h2o[i]
    pl_profile_pred = y_pred_pl[i]
    h2o_profile_pred = y_pred_h2o[i]

    plt.figure(figsize=(7, 6))
    plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
    plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
    plt.gca().invert_yaxis()
    plt.xlabel("H2O content [vmr]")
    plt.ylabel("Pressure Layer [mbar]")
    #plt.ylim(0, 1000)
    plt.title(f"H2O vs PL — Test Sample #{i}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#torch.save(model.state_dict(), save_path)

# %%
save_path_final = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model25RES_final.pth'
torch.save(model.state_dict(), save_path_final)
