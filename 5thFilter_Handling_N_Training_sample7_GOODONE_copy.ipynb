# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_dir = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0'
input_pkl_path_v1 = os.path.join(data_dir, 'input_nn_ver1.pkl')
#input_pkl_path_v2 = os.path.join(data_dir, 'input_nn_ver2.pkl')

# %%
df = pd.read_pickle(input_pkl_path_v1)
#df = pd.read_pickle(input_pkl_path_v2)

# %% [markdown]
# **------------------NOISE ADDING----------------------**

# %%
def add_noise(tsky, trx=75.0, snr=1000.0):
    tsys = trx + tsky
    tnoise = tsys / snr
    tcal = tsky + tnoise * np.random.standard_normal(tsky.shape)
    return tcal

# %%
original_spectrum = np.array(df['SPECTRA_Tb[K]'].iloc[0])

# %%
frequencies = np.linspace(20.0, 26.0, len(original_spectrum))

# %%
noisy_spectrum = add_noise(original_spectrum)

# %%
df['SPECTRA_Tb[K]_NOISY'] = df['SPECTRA_Tb[K]'].apply(lambda spec: add_noise(np.array(spec)))

# %% [markdown]
# **TRANING WAY 1: USING DIFFERENT COLUMNS BETWEEN PL AND H2O**

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['SPECTRA_Tb[K]_NOISY'].tolist())
PL = np.array(df['PL[mbar]'].tolist())
H2O = np.array(df['H2O[vmr]'].tolist())
Y = np.concatenate([PL, H2O], axis=1)

# %%
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.4, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)

# %%
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **SECOND FRAMEWORK TORCH**

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **-NORMALIZATION-**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_val_scaled = scaler.transform(X_val)
#X_test_scaled = scaler.transform(X_test)
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# **-----------------------**

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
Y_val   = torch.tensor(Y_val, dtype=torch.float32)
X_test  = torch.tensor(X_test, dtype=torch.float32)
Y_test  = torch.tensor(Y_test, dtype=torch.float32)

# %%
batch_size = 64

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds  = TensorDataset(X_test, Y_test)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
class PedroSplitMLP(nn.Module):
    def __init__(self):
        super(PedroSplitMLP, self).__init__()
        self.shared_fc1 = nn.Linear(12001, 1024)
        self.dropout1 = nn.Dropout(p=0.2)
        self.shared_fc2 = nn.Linear(1024, 512)
        self.dropout2 = nn.Dropout(p=0.2)
        self.shared_fc3 = nn.Linear(512, 256)
        self.dropout3 = nn.Dropout(p=0.2)
        self.shared_fc4 = nn.Linear(256, 128)
        self.dropout4 = nn.Dropout(p=0.2)

        # Separate heads
        self.h2o_head = nn.Linear(128, 67)
        self.pl_head = nn.Linear(128, 67)

    def forward(self, x):
        x = torch.relu(self.shared_fc1(x))
        x = self.dropout1(x)
        x = torch.relu(self.shared_fc2(x))
        x = self.dropout2(x)
        x = torch.relu(self.shared_fc3(x))
        x = self.dropout3(x)
        x = torch.relu(self.shared_fc4(x))
        x = self.dropout4(x)

        h2o_out = self.h2o_head(x)
        pl_out = self.pl_head(x)
        return h2o_out, pl_out

model = PedroSplitMLP()

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super(WeightedMSELoss, self).__init__()
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def forward(self, pred, target):
        diff = pred - target
        weighted_diff = diff * self.weights
        loss = torch.mean(weighted_diff ** 2)
        return loss

def smoothness_penalty(h2o_pred, alpha=1.0):
    diff = h2o_pred[:, 1:] - h2o_pred[:, :-1]
    return alpha * torch.mean(diff ** 2)

# Construct weights to emphasize lower pressures (higher in atmosphere)
n_levels = 67
pl_weights = np.linspace(1.0, 0.5, n_levels)      # Normal weights for PL
h2o_weights = np.logspace(np.log10(2.0), np.log10(0.8), n_levels)     # Emphasize high-altitude H2O, modified for higher-pressure performance

pl_weights_tensor = torch.tensor(pl_weights, dtype=torch.float32)
h2o_weights_tensor = torch.tensor(h2o_weights, dtype=torch.float32)

combined_weights = np.concatenate([pl_weights, h2o_weights])
criterion_h2o = WeightedMSELoss(weights=h2o_weights_tensor)
criterion_pl  = WeightedMSELoss(weights=pl_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
# Out:
# /tmp/ipython-input-22-1415743074.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.weights = torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, loader, val_loader, criterion_h2o, criterion_pl, optimizer, epochs, save_path, alpha=0.5):
    train_losses, val_losses = [], []
    val_mae_list, val_rmse_list = [], []

    best_val_loss = float('inf')
    patience = 10
    counter = 0

    # Scheduler para reducir LR cuando la validación no mejore
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        for xb, yb in loader:
            optimizer.zero_grad()

            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            loss_h2o = criterion_h2o(h2o_pred, h2o_target)
            loss_pl = criterion_pl(pl_pred, pl_target)
            smooth_loss = smoothness_penalty(h2o_pred, alpha=alpha)

            loss = loss_h2o + loss_pl + smooth_loss
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(loader))

        # Validación
        model.eval()
        val_loss_total = 0
        y_true_h2o, y_pred_h2o = [], []
        y_true_pl, y_pred_pl = [], []

        with torch.no_grad():
            for xb, yb in val_loader:
                h2o_pred, pl_pred = model(xb)
                h2o_target = yb[:, :n_levels]
                pl_target = yb[:, n_levels:]

                loss_h2o_val = criterion_h2o(h2o_pred, h2o_target)
                loss_pl_val = criterion_pl(pl_pred, pl_target)
                smooth_loss_val = smoothness_penalty(h2o_pred, alpha=alpha)

                batch_val_loss = loss_h2o_val + loss_pl_val + smooth_loss_val
                val_loss_total += batch_val_loss.item()

                y_true_h2o.append(h2o_target.cpu().numpy())
                y_pred_h2o.append(h2o_pred.cpu().numpy())

                y_true_pl.append(pl_target.cpu().numpy())
                y_pred_pl.append(pl_pred.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_losses.append(val_loss)

        y_true_h2o = np.concatenate(y_true_h2o, axis=0)
        y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

        y_true_pl = np.concatenate(y_true_pl, axis=0)
        y_pred_pl = np.concatenate(y_pred_pl, axis=0)

        # Métricas para H2O
        val_mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
        val_rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

        # Métricas para PL
        val_mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
        val_rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

        val_mae_list.append((val_mae_h2o, val_mae_pl))
        val_rmse_list.append((val_rmse_h2o, val_rmse_pl))

        # Scheduler LR
        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), save_path)
            counter = 0
            print(f"✅ Model improved and saved (val_loss = {best_val_loss:.4f})")
        else:
            counter += 1
            if counter >= patience:
                print(f"⛔ Early stopping at epoch {epoch+1}")
                break

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f} | "
              f"MAE H2O: {val_mae_h2o:.4f} | RMSE H2O: {val_rmse_h2o:.4f} | "
              f"MAE PL: {val_mae_pl:.4f} | RMSE PL: {val_rmse_pl:.4f} | LR: {current_lr:.1e}")

    # Cargar mejor modelo al final del entrenamiento
    model.load_state_dict(torch.load(save_path))

    return train_losses, val_losses, val_mae_list, val_rmse_list

# %%
def evaluate(model, loader):
    model.eval()
    y_true_h2o, y_pred_h2o = [], []
    y_true_pl, y_pred_pl = [], []

    with torch.no_grad():
        for xb, yb in loader:
            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            y_true_h2o.append(h2o_target.cpu().numpy())
            y_pred_h2o.append(h2o_pred.cpu().numpy())

            y_true_pl.append(pl_target.cpu().numpy())
            y_pred_pl.append(pl_pred.cpu().numpy())

    y_true_h2o = np.concatenate(y_true_h2o, axis=0)
    y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

    y_true_pl = np.concatenate(y_true_pl, axis=0)
    y_pred_pl = np.concatenate(y_pred_pl, axis=0)

    return (y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl)

# %%
save_path = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model7.pth'

# %%
epochs = 100
alpha = 0.5  # Regularization strength for smoothness penalty

train_losses, val_losses, val_mae, val_rmse = train(
    model,
    train_loader,
    val_loader,
    criterion_h2o,
    criterion_pl,
    optimizer,
    epochs,
    save_path,
    alpha=alpha
)
# Out:
# ✅ Model improved and saved (val_loss = 63156.3052)
# Epoch 1/100 | Train Loss: 85069.2187 | Val Loss: 63156.3052 | MAE H2O: 155.0801 | RMSE H2O: 269.6708 | MAE PL: 2.6394 | RMSE PL: 4.0443 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 52432.6852)
# Epoch 2/100 | Train Loss: 50085.9477 | Val Loss: 52432.6852 | MAE H2O: 132.5151 | RMSE H2O: 245.6374 | MAE PL: 1.4465 | RMSE PL: 2.0881 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 34269.4448)
# Epoch 3/100 | Train Loss: 39166.0272 | Val Loss: 34269.4448 | MAE H2O: 108.9676 | RMSE H2O: 198.4979 | MAE PL: 1.0631 | RMSE PL: 1.4149 | LR: 5.0e-04
# Epoch 4/100 | Train Loss: 38858.2859 | Val Loss: 36281.1120 | MAE H2O: 111.0206 | RMSE H2O: 204.4678 | MAE PL: 0.5964 | RMSE PL: 0.8293 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 33633.5777)
# Epoch 5/100 | Train Loss: 36977.8113 | Val Loss: 33633.5777 | MAE H2O: 107.9705 | RMSE H2O: 196.6198 | MAE PL: 0.6024 | RMSE PL: 0.8215 | LR: 5.0e-04
# Epoch 6/100 | Train Loss: 35633.3395 | Val Loss: 33636.3573 | MAE H2O: 106.7761 | RMSE H2O: 196.5976 | MAE PL: 0.2710 | RMSE PL: 0.3793 | LR: 5.0e-04
# Epoch 7/100 | Train Loss: 34275.5052 | Val Loss: 35222.8163 | MAE H2O: 112.0401 | RMSE H2O: 201.4293 | MAE PL: 0.1804 | RMSE PL: 0.2532 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 30477.3583)
# Epoch 8/100 | Train Loss: 34352.1018 | Val Loss: 30477.3583 | MAE H2O: 102.4390 | RMSE H2O: 187.2497 | MAE PL: 0.0943 | RMSE PL: 0.1553 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 25517.1536)
# Epoch 9/100 | Train Loss: 30901.4485 | Val Loss: 25517.1536 | MAE H2O: 96.0613 | RMSE H2O: 171.0580 | MAE PL: 0.0876 | RMSE PL: 0.1578 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 22583.7108)
# Epoch 10/100 | Train Loss: 25571.0672 | Val Loss: 22583.7108 | MAE H2O: 92.6720 | RMSE H2O: 161.1854 | MAE PL: 0.0669 | RMSE PL: 0.0974 | LR: 5.0e-04
# Epoch 11/100 | Train Loss: 22693.1804 | Val Loss: 23356.5797 | MAE H2O: 92.8898 | RMSE H2O: 163.7786 | MAE PL: 0.0326 | RMSE PL: 0.0726 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 13102.1239)
# Epoch 12/100 | Train Loss: 19222.4090 | Val Loss: 13102.1239 | MAE H2O: 65.1141 | RMSE H2O: 122.0792 | MAE PL: 0.0684 | RMSE PL: 0.0955 | LR: 5.0e-04
# Epoch 13/100 | Train Loss: 17228.7746 | Val Loss: 38374.0190 | MAE H2O: 110.0149 | RMSE H2O: 209.1902 | MAE PL: 0.0998 | RMSE PL: 0.1274 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 7065.3863)
# Epoch 14/100 | Train Loss: 18084.2959 | Val Loss: 7065.3863 | MAE H2O: 46.1436 | RMSE H2O: 89.0936 | MAE PL: 0.0896 | RMSE PL: 0.1375 | LR: 5.0e-04
# Epoch 15/100 | Train Loss: 14463.5068 | Val Loss: 17450.4136 | MAE H2O: 80.6499 | RMSE H2O: 141.2110 | MAE PL: 0.1440 | RMSE PL: 0.1901 | LR: 5.0e-04
# Epoch 16/100 | Train Loss: 13052.9377 | Val Loss: 8449.8812 | MAE H2O: 53.4393 | RMSE H2O: 98.0690 | MAE PL: 0.0202 | RMSE PL: 0.0304 | LR: 5.0e-04
# Epoch 17/100 | Train Loss: 13832.5266 | Val Loss: 48299.9210 | MAE H2O: 122.8784 | RMSE H2O: 234.7647 | MAE PL: 0.1316 | RMSE PL: 0.1724 | LR: 5.0e-04
# Epoch 18/100 | Train Loss: 13912.2134 | Val Loss: 8173.3856 | MAE H2O: 51.6642 | RMSE H2O: 96.2135 | MAE PL: 0.0294 | RMSE PL: 0.0365 | LR: 5.0e-04
# Epoch 19/100 | Train Loss: 12453.9515 | Val Loss: 17362.7021 | MAE H2O: 75.1178 | RMSE H2O: 141.1880 | MAE PL: 0.0642 | RMSE PL: 0.0908 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 6180.8754)
# Epoch 20/100 | Train Loss: 11548.6068 | Val Loss: 6180.8754 | MAE H2O: 46.5722 | RMSE H2O: 83.4346 | MAE PL: 0.0366 | RMSE PL: 0.0504 | LR: 5.0e-04
# Epoch 21/100 | Train Loss: 9426.7634 | Val Loss: 10244.8778 | MAE H2O: 62.9847 | RMSE H2O: 108.1509 | MAE PL: 0.0441 | RMSE PL: 0.0713 | LR: 5.0e-04
# Epoch 22/100 | Train Loss: 8468.9421 | Val Loss: 7754.8922 | MAE H2O: 52.4147 | RMSE H2O: 93.5909 | MAE PL: 0.0996 | RMSE PL: 0.1576 | LR: 5.0e-04
# Epoch 23/100 | Train Loss: 10101.9691 | Val Loss: 17725.5910 | MAE H2O: 73.0842 | RMSE H2O: 142.0973 | MAE PL: 0.0219 | RMSE PL: 0.0310 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 2501.4200)
# Epoch 24/100 | Train Loss: 8147.8706 | Val Loss: 2501.4200 | MAE H2O: 26.1687 | RMSE H2O: 51.9937 | MAE PL: 0.1422 | RMSE PL: 0.2181 | LR: 5.0e-04
# Epoch 25/100 | Train Loss: 9082.0664 | Val Loss: 3313.1356 | MAE H2O: 28.8298 | RMSE H2O: 59.9387 | MAE PL: 0.1130 | RMSE PL: 0.1860 | LR: 5.0e-04
# Epoch 26/100 | Train Loss: 6643.9893 | Val Loss: 5127.6856 | MAE H2O: 39.3987 | RMSE H2O: 75.4596 | MAE PL: 0.1251 | RMSE PL: 0.3232 | LR: 5.0e-04
# Epoch 27/100 | Train Loss: 8144.9817 | Val Loss: 9553.5789 | MAE H2O: 56.2635 | RMSE H2O: 104.0220 | MAE PL: 0.0857 | RMSE PL: 0.1400 | LR: 5.0e-04
# Epoch 28/100 | Train Loss: 8950.0221 | Val Loss: 2717.4490 | MAE H2O: 28.8414 | RMSE H2O: 54.1684 | MAE PL: 0.0715 | RMSE PL: 0.1657 | LR: 5.0e-04
# Epoch 29/100 | Train Loss: 7550.7440 | Val Loss: 7588.2568 | MAE H2O: 53.6007 | RMSE H2O: 92.7410 | MAE PL: 0.0930 | RMSE PL: 0.1799 | LR: 5.0e-04
# Epoch 30/100 | Train Loss: 7394.9070 | Val Loss: 5196.8796 | MAE H2O: 43.9439 | RMSE H2O: 76.3012 | MAE PL: 0.4300 | RMSE PL: 1.0284 | LR: 2.5e-04
# Epoch 31/100 | Train Loss: 4183.8780 | Val Loss: 3224.0265 | MAE H2O: 32.4771 | RMSE H2O: 59.2555 | MAE PL: 0.0101 | RMSE PL: 0.0258 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 1104.8534)
# Epoch 32/100 | Train Loss: 4298.1015 | Val Loss: 1104.8534 | MAE H2O: 16.8774 | RMSE H2O: 32.6419 | MAE PL: 0.1353 | RMSE PL: 0.3035 | LR: 2.5e-04
# Epoch 33/100 | Train Loss: 3875.0153 | Val Loss: 2066.4485 | MAE H2O: 24.4746 | RMSE H2O: 46.5570 | MAE PL: 0.0588 | RMSE PL: 0.1115 | LR: 2.5e-04
# Epoch 34/100 | Train Loss: 4483.5686 | Val Loss: 1568.7904 | MAE H2O: 20.4553 | RMSE H2O: 40.1315 | MAE PL: 0.0336 | RMSE PL: 0.1620 | LR: 2.5e-04
# Epoch 35/100 | Train Loss: 3960.5912 | Val Loss: 5688.8114 | MAE H2O: 43.1934 | RMSE H2O: 79.4091 | MAE PL: 0.1183 | RMSE PL: 0.3502 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 915.9121)
# Epoch 36/100 | Train Loss: 3586.4481 | Val Loss: 915.9121 | MAE H2O: 12.1467 | RMSE H2O: 29.1140 | MAE PL: 0.0691 | RMSE PL: 0.1805 | LR: 2.5e-04
# Epoch 37/100 | Train Loss: 4106.0461 | Val Loss: 4583.8882 | MAE H2O: 38.2096 | RMSE H2O: 71.4006 | MAE PL: 0.0656 | RMSE PL: 0.3096 | LR: 2.5e-04
# Epoch 38/100 | Train Loss: 4820.1464 | Val Loss: 1090.1677 | MAE H2O: 16.7269 | RMSE H2O: 32.3473 | MAE PL: 0.0740 | RMSE PL: 0.1901 | LR: 2.5e-04
# Epoch 39/100 | Train Loss: 3742.8999 | Val Loss: 8974.4088 | MAE H2O: 48.7628 | RMSE H2O: 100.1457 | MAE PL: 0.0336 | RMSE PL: 0.0697 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 841.8712)
# Epoch 40/100 | Train Loss: 4434.4121 | Val Loss: 841.8712 | MAE H2O: 13.1543 | RMSE H2O: 27.5098 | MAE PL: 0.0331 | RMSE PL: 0.0741 | LR: 2.5e-04
# Epoch 41/100 | Train Loss: 3678.9178 | Val Loss: 2381.7082 | MAE H2O: 26.3652 | RMSE H2O: 50.4326 | MAE PL: 0.1758 | RMSE PL: 0.3361 | LR: 2.5e-04
# Epoch 42/100 | Train Loss: 3795.1415 | Val Loss: 3891.2100 | MAE H2O: 37.0836 | RMSE H2O: 65.3729 | MAE PL: 0.0270 | RMSE PL: 0.0571 | LR: 2.5e-04
# Epoch 43/100 | Train Loss: 4130.0482 | Val Loss: 3289.1184 | MAE H2O: 32.8674 | RMSE H2O: 59.6094 | MAE PL: 0.0284 | RMSE PL: 0.0942 | LR: 2.5e-04
# Epoch 44/100 | Train Loss: 4022.2585 | Val Loss: 4936.1436 | MAE H2O: 41.7638 | RMSE H2O: 73.8328 | MAE PL: 0.4897 | RMSE PL: 0.8200 | LR: 2.5e-04
# Epoch 45/100 | Train Loss: 4089.5633 | Val Loss: 962.7889 | MAE H2O: 15.5258 | RMSE H2O: 29.8071 | MAE PL: 0.0557 | RMSE PL: 0.2428 | LR: 2.5e-04
# Epoch 46/100 | Train Loss: 3665.6091 | Val Loss: 1062.3211 | MAE H2O: 16.5487 | RMSE H2O: 31.9373 | MAE PL: 0.0064 | RMSE PL: 0.0181 | LR: 1.3e-04
# Epoch 47/100 | Train Loss: 2720.6508 | Val Loss: 2489.2147 | MAE H2O: 28.5926 | RMSE H2O: 51.7221 | MAE PL: 0.0074 | RMSE PL: 0.0226 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 748.8072)
# Epoch 48/100 | Train Loss: 2944.9607 | Val Loss: 748.8072 | MAE H2O: 10.6508 | RMSE H2O: 25.3814 | MAE PL: 0.0524 | RMSE PL: 0.2686 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 740.9635)
# Epoch 49/100 | Train Loss: 2679.4601 | Val Loss: 740.9635 | MAE H2O: 12.4103 | RMSE H2O: 25.2879 | MAE PL: 0.0033 | RMSE PL: 0.0072 | LR: 1.3e-04
# Epoch 50/100 | Train Loss: 2896.1236 | Val Loss: 3233.5305 | MAE H2O: 32.5721 | RMSE H2O: 59.4118 | MAE PL: 0.0133 | RMSE PL: 0.0526 | LR: 1.3e-04
# Epoch 51/100 | Train Loss: 2854.6462 | Val Loss: 854.3750 | MAE H2O: 14.5550 | RMSE H2O: 27.7535 | MAE PL: 0.0051 | RMSE PL: 0.0108 | LR: 1.3e-04
# Epoch 52/100 | Train Loss: 2659.5976 | Val Loss: 2117.3827 | MAE H2O: 25.4064 | RMSE H2O: 47.0462 | MAE PL: 0.2692 | RMSE PL: 0.6010 | LR: 1.3e-04
# Epoch 53/100 | Train Loss: 2692.1495 | Val Loss: 1308.1081 | MAE H2O: 18.0639 | RMSE H2O: 35.8382 | MAE PL: 0.0045 | RMSE PL: 0.0077 | LR: 1.3e-04
# Epoch 54/100 | Train Loss: 3121.8896 | Val Loss: 2563.7050 | MAE H2O: 28.7833 | RMSE H2O: 52.4843 | MAE PL: 0.1901 | RMSE PL: 0.3763 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 595.1638)
# Epoch 55/100 | Train Loss: 2625.3706 | Val Loss: 595.1638 | MAE H2O: 10.2185 | RMSE H2O: 21.5063 | MAE PL: 0.0290 | RMSE PL: 0.0787 | LR: 1.3e-04
# Epoch 56/100 | Train Loss: 2760.0613 | Val Loss: 1186.5687 | MAE H2O: 15.4335 | RMSE H2O: 33.7983 | MAE PL: 0.0474 | RMSE PL: 0.1916 | LR: 1.3e-04
# Epoch 57/100 | Train Loss: 2719.0205 | Val Loss: 873.8652 | MAE H2O: 13.2350 | RMSE H2O: 27.9323 | MAE PL: 0.0099 | RMSE PL: 0.0367 | LR: 1.3e-04
# Epoch 58/100 | Train Loss: 2902.0952 | Val Loss: 762.9212 | MAE H2O: 12.8480 | RMSE H2O: 25.6246 | MAE PL: 0.1135 | RMSE PL: 0.2437 | LR: 1.3e-04
# Epoch 59/100 | Train Loss: 2740.2121 | Val Loss: 832.8842 | MAE H2O: 14.8470 | RMSE H2O: 27.1782 | MAE PL: 0.0060 | RMSE PL: 0.0112 | LR: 1.3e-04
# Epoch 60/100 | Train Loss: 2816.3886 | Val Loss: 3387.1667 | MAE H2O: 35.6496 | RMSE H2O: 60.6816 | MAE PL: 0.0545 | RMSE PL: 0.1382 | LR: 1.3e-04
# Epoch 61/100 | Train Loss: 2923.1474 | Val Loss: 962.6084 | MAE H2O: 14.1269 | RMSE H2O: 29.7577 | MAE PL: 0.1259 | RMSE PL: 0.2494 | LR: 6.3e-05
# Epoch 62/100 | Train Loss: 2342.0296 | Val Loss: 1509.7054 | MAE H2O: 21.2628 | RMSE H2O: 38.9671 | MAE PL: 0.0029 | RMSE PL: 0.0050 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 581.8069)
# Epoch 63/100 | Train Loss: 2484.1840 | Val Loss: 581.8069 | MAE H2O: 10.5076 | RMSE H2O: 20.8802 | MAE PL: 0.0317 | RMSE PL: 0.1295 | LR: 6.3e-05
# Epoch 64/100 | Train Loss: 2301.1847 | Val Loss: 817.1880 | MAE H2O: 13.3767 | RMSE H2O: 26.8575 | MAE PL: 0.0035 | RMSE PL: 0.0083 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 523.0112)
# Epoch 65/100 | Train Loss: 2331.8855 | Val Loss: 523.0112 | MAE H2O: 9.2738 | RMSE H2O: 19.4149 | MAE PL: 0.0038 | RMSE PL: 0.0084 | LR: 6.3e-05
# Epoch 66/100 | Train Loss: 2370.4656 | Val Loss: 539.5659 | MAE H2O: 9.6100 | RMSE H2O: 19.8318 | MAE PL: 0.0042 | RMSE PL: 0.0107 | LR: 6.3e-05
# Epoch 67/100 | Train Loss: 2293.9983 | Val Loss: 731.8478 | MAE H2O: 12.0702 | RMSE H2O: 25.0601 | MAE PL: 0.0020 | RMSE PL: 0.0040 | LR: 6.3e-05
# Epoch 68/100 | Train Loss: 2445.8183 | Val Loss: 811.2640 | MAE H2O: 13.7684 | RMSE H2O: 26.5522 | MAE PL: 0.0129 | RMSE PL: 0.0519 | LR: 6.3e-05
# Epoch 69/100 | Train Loss: 2327.3343 | Val Loss: 614.7140 | MAE H2O: 10.4281 | RMSE H2O: 21.9105 | MAE PL: 0.0019 | RMSE PL: 0.0040 | LR: 6.3e-05
# Epoch 70/100 | Train Loss: 2228.2689 | Val Loss: 528.8378 | MAE H2O: 9.3204 | RMSE H2O: 19.6841 | MAE PL: 0.0031 | RMSE PL: 0.0060 | LR: 6.3e-05
# Epoch 71/100 | Train Loss: 2269.3636 | Val Loss: 617.6396 | MAE H2O: 10.4169 | RMSE H2O: 22.2074 | MAE PL: 0.0298 | RMSE PL: 0.0720 | LR: 3.1e-05
# Epoch 72/100 | Train Loss: 2132.0688 | Val Loss: 583.7277 | MAE H2O: 10.4553 | RMSE H2O: 20.9960 | MAE PL: 0.0027 | RMSE PL: 0.0050 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 516.6519)
# Epoch 73/100 | Train Loss: 2103.6066 | Val Loss: 516.6519 | MAE H2O: 9.2280 | RMSE H2O: 19.2164 | MAE PL: 0.0024 | RMSE PL: 0.0047 | LR: 3.1e-05
# Epoch 74/100 | Train Loss: 2174.1877 | Val Loss: 614.5586 | MAE H2O: 11.1950 | RMSE H2O: 22.0640 | MAE PL: 0.0022 | RMSE PL: 0.0046 | LR: 3.1e-05
# Epoch 75/100 | Train Loss: 2220.5775 | Val Loss: 615.1198 | MAE H2O: 11.3336 | RMSE H2O: 21.9482 | MAE PL: 0.0020 | RMSE PL: 0.0041 | LR: 3.1e-05
# Epoch 76/100 | Train Loss: 2117.4504 | Val Loss: 1041.5622 | MAE H2O: 16.8765 | RMSE H2O: 31.2818 | MAE PL: 0.0024 | RMSE PL: 0.0047 | LR: 3.1e-05
# Epoch 77/100 | Train Loss: 2100.5284 | Val Loss: 666.9209 | MAE H2O: 12.6156 | RMSE H2O: 23.2756 | MAE PL: 0.0021 | RMSE PL: 0.0044 | LR: 3.1e-05
# Epoch 78/100 | Train Loss: 2085.1636 | Val Loss: 597.6315 | MAE H2O: 10.7579 | RMSE H2O: 21.4849 | MAE PL: 0.0043 | RMSE PL: 0.0080 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 496.1510)
# Epoch 79/100 | Train Loss: 2112.4643 | Val Loss: 496.1510 | MAE H2O: 8.8623 | RMSE H2O: 18.5508 | MAE PL: 0.0175 | RMSE PL: 0.0418 | LR: 3.1e-05
# Epoch 80/100 | Train Loss: 2071.9826 | Val Loss: 684.7812 | MAE H2O: 12.4579 | RMSE H2O: 23.9014 | MAE PL: 0.0106 | RMSE PL: 0.0254 | LR: 3.1e-05
# Epoch 81/100 | Train Loss: 2064.6794 | Val Loss: 538.0255 | MAE H2O: 9.6256 | RMSE H2O: 19.8228 | MAE PL: 0.0244 | RMSE PL: 0.0504 | LR: 3.1e-05
# Epoch 82/100 | Train Loss: 2050.3500 | Val Loss: 839.7743 | MAE H2O: 14.5699 | RMSE H2O: 27.1448 | MAE PL: 0.0085 | RMSE PL: 0.0173 | LR: 3.1e-05
# Epoch 83/100 | Train Loss: 2063.0098 | Val Loss: 542.3035 | MAE H2O: 10.0826 | RMSE H2O: 19.9846 | MAE PL: 0.0093 | RMSE PL: 0.0265 | LR: 3.1e-05
# Epoch 84/100 | Train Loss: 2074.2683 | Val Loss: 640.9353 | MAE H2O: 11.9188 | RMSE H2O: 22.8517 | MAE PL: 0.0054 | RMSE PL: 0.0096 | LR: 3.1e-05
# Epoch 85/100 | Train Loss: 2048.0921 | Val Loss: 1031.5524 | MAE H2O: 16.5697 | RMSE H2O: 31.1824 | MAE PL: 0.0237 | RMSE PL: 0.0456 | LR: 1.6e-05
# Epoch 86/100 | Train Loss: 2000.9383 | Val Loss: 513.8214 | MAE H2O: 9.3321 | RMSE H2O: 19.2106 | MAE PL: 0.0019 | RMSE PL: 0.0039 | LR: 1.6e-05
# Epoch 87/100 | Train Loss: 2010.5625 | Val Loss: 657.4036 | MAE H2O: 12.3115 | RMSE H2O: 22.9617 | MAE PL: 0.0019 | RMSE PL: 0.0038 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 485.0086)
# Epoch 88/100 | Train Loss: 1965.9545 | Val Loss: 485.0086 | MAE H2O: 8.6746 | RMSE H2O: 18.2203 | MAE PL: 0.0023 | RMSE PL: 0.0054 | LR: 1.6e-05
# Epoch 89/100 | Train Loss: 2004.8047 | Val Loss: 637.2517 | MAE H2O: 11.4507 | RMSE H2O: 22.6388 | MAE PL: 0.0020 | RMSE PL: 0.0041 | LR: 1.6e-05
# Epoch 90/100 | Train Loss: 1976.0960 | Val Loss: 528.7298 | MAE H2O: 9.8340 | RMSE H2O: 19.6625 | MAE PL: 0.0029 | RMSE PL: 0.0060 | LR: 1.6e-05
# Epoch 91/100 | Train Loss: 1967.1048 | Val Loss: 518.1188 | MAE H2O: 9.4757 | RMSE H2O: 19.2374 | MAE PL: 0.0035 | RMSE PL: 0.0075 | LR: 1.6e-05
# Epoch 92/100 | Train Loss: 1971.3501 | Val Loss: 537.7930 | MAE H2O: 9.8282 | RMSE H2O: 19.9056 | MAE PL: 0.0022 | RMSE PL: 0.0041 | LR: 1.6e-05
# Epoch 93/100 | Train Loss: 1980.4020 | Val Loss: 527.9536 | MAE H2O: 9.7855 | RMSE H2O: 19.4960 | MAE PL: 0.0034 | RMSE PL: 0.0065 | LR: 1.6e-05
# Epoch 94/100 | Train Loss: 1991.7822 | Val Loss: 735.8504 | MAE H2O: 12.6239 | RMSE H2O: 24.8558 | MAE PL: 0.0035 | RMSE PL: 0.0061 | LR: 7.8e-06
# Epoch 95/100 | Train Loss: 1930.5622 | Val Loss: 590.9196 | MAE H2O: 10.8671 | RMSE H2O: 21.4442 | MAE PL: 0.0022 | RMSE PL: 0.0047 | LR: 7.8e-06
# Epoch 96/100 | Train Loss: 1960.0135 | Val Loss: 485.7877 | MAE H2O: 8.7712 | RMSE H2O: 18.1940 | MAE PL: 0.0020 | RMSE PL: 0.0042 | LR: 7.8e-06
# Epoch 97/100 | Train Loss: 1954.8648 | Val Loss: 566.1548 | MAE H2O: 10.8744 | RMSE H2O: 20.6246 | MAE PL: 0.0027 | RMSE PL: 0.0054 | LR: 7.8e-06
# ⛔ Early stopping at epoch 98

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correct unpacking from evaluate
(y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl) = evaluate(model, test_loader)

# Optionally concatenate to compute overall metrics
y_true_test = np.concatenate([y_true_pl, y_true_h2o], axis=1)
y_pred_test = np.concatenate([y_pred_pl, y_pred_h2o], axis=1)

# Compute test metrics
test_mae = mean_absolute_error(y_true_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"\n✅ Test MAE:  {test_mae:.4f}")
print(f"✅ Test RMSE: {test_rmse:.4f}")

# You can also compute them separately:
mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

print(f"\n🌊 H2O  → MAE: {mae_h2o:.4f} | RMSE: {rmse_h2o:.4f}")
print(f"📉 PL   → MAE: {mae_pl:.4f} | RMSE: {rmse_pl:.4f}")
# Out:
# ✅ Test MAE:  4.4682
# ✅ Test RMSE: 13.3863
#
# 🌊 H2O  → MAE: 8.9341 | RMSE: 18.9311
# 📉 PL   → MAE: 0.0022 | RMSE: 0.0053

# %%
output_index = 120  # index within concatenated output (0–133)

plt.figure(figsize=(10, 5))
plt.plot(y_true_test[:, output_index], label='True', alpha=0.7)
plt.plot(y_pred_test[:, output_index], label='Predicted', alpha=0.7)
plt.title(f"True vs Predicted - Output #{output_index}")
plt.xlabel("Sample index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose a sample index
i = 120

# Extract profiles for test sample i
pl_profile_true = y_true_pl[i]
h2o_profile_true = y_true_h2o[i]

pl_profile_pred = y_pred_pl[i]
h2o_profile_pred = y_pred_h2o[i]

# Plot profile
plt.figure(figsize=(7, 6))
plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
plt.gca().invert_yaxis()
plt.ylabel("H2O content [vmr]")
plt.xlabel("Pressure Layer [mbar]")
#plt.ylim(0, 1000)
plt.title("H2O content vs Pressure Level")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for i in range(3):
    pl_profile_true = y_true_pl[i]
    h2o_profile_true = y_true_h2o[i]
    pl_profile_pred = y_pred_pl[i]
    h2o_profile_pred = y_pred_h2o[i]

    plt.figure(figsize=(7, 6))
    plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
    plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
    plt.gca().invert_yaxis()
    plt.ylabel("H2O content [vmr]")
    plt.xlabel("Pressure Layer [mbar]")
    #plt.ylim(0, 1000)
    plt.title(f"H2O vs PL — Test Sample #{i}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#torch.save(model.state_dict(), save_path)

# %%
save_path_final = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model7_final.pth'
torch.save(model.state_dict(), save_path_final)
