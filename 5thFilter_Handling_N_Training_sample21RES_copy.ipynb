# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0'
input_pkl_path_v1 = os.path.join(data_dir, 'input_nn_ver1.pkl')
#input_pkl_path_v2 = os.path.join(data_dir, 'input_nn_ver2.pkl')

# %%
df = pd.read_pickle(input_pkl_path_v1)
#df = pd.read_pickle(input_pkl_path_v2)

# %% [markdown]
# **------------------NOISE ADDING----------------------**

# %%
def add_noise(tsky, trx=75.0, snr=1000.0):
    tsys = trx + tsky
    tnoise = tsys / snr
    tcal = tsky + tnoise * np.random.standard_normal(tsky.shape)
    return tcal

# %%
original_spectrum = np.array(df['SPECTRA_Tb[K]'].iloc[0])

# %%
frequencies = np.linspace(20.0, 26.0, len(original_spectrum))

# %%
noisy_spectrum = add_noise(original_spectrum)

# %%
df['SPECTRA_Tb[K]_NOISY'] = df['SPECTRA_Tb[K]']

# %% [markdown]
# **TRANING WAY 1: USING DIFFERENT COLUMNS BETWEEN PL AND H2O**

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(df['SPECTRA_Tb[K]_NOISY'].tolist())
PL = np.array(df['PL[mbar]'].tolist())
H2O = np.array(df['H2O[vmr]'].tolist())
Y = np.concatenate([H2O, PL], axis=1)

# %%
print(H2O.shape, PL.shape)
# Out:
# (21024, 67) (21024, 67)

# %%
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.4, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)

# %%
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **SECOND FRAMEWORK TORCH**

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **-NORMALIZATION-**

# %%
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
#X_train_scaled = scaler.fit_transform(X_train)
#X_val_scaled = scaler.transform(X_val)
#X_test_scaled = scaler.transform(X_test)
X_train = scaler_x.fit_transform(X_train)
X_val = scaler_x.transform(X_val)
X_test = scaler_x.transform(X_test)

# %%
scaler_y = StandardScaler()
Y_train = scaler_y.fit_transform(Y_train)
Y_val   = scaler_y.transform(Y_val)
Y_test  = scaler_y.transform(Y_test)

# %%
print("X_train:", X_train.shape)
print("X_val:  ", X_val.shape)
print("X_test: ", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_val:  ", Y_val.shape)
print("Y_test: ", Y_test.shape)
# Out:
# X_train: (12614, 12001)
# X_val:   (4205, 12001)
# X_test:  (4205, 12001)
# Y_train: (12614, 134)
# Y_val:   (4205, 134)
# Y_test:  (4205, 134)

# %% [markdown]
# **-----------------------**

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val   = torch.tensor(X_val, dtype=torch.float32)
Y_val   = torch.tensor(Y_val, dtype=torch.float32)
X_test  = torch.tensor(X_test, dtype=torch.float32)
Y_test  = torch.tensor(Y_test, dtype=torch.float32)

# %%
batch_size = 64

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val, Y_val)
test_ds  = TensorDataset(X_test, Y_test)

# %%
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, out_features, dropout=0.2):
        super(ResidualBlock, self).__init__()
        self.linear = nn.Linear(in_features, out_features)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

        # Project input if dimensions don’t match
        self.shortcut = nn.Identity()
        if in_features != out_features:
            self.shortcut = nn.Linear(in_features, out_features)

    def forward(self, x):
        identity = self.shortcut(x)
        out = self.linear(x)
        out = self.relu(out)
        out = self.dropout(out)
        return identity + out  # Residual connection

# %%
class PedroSplitMLPResidual(nn.Module):
    def __init__(self):
        super(PedroSplitMLPResidual, self).__init__()
        self.fc_in = nn.Linear(12001, 1024)
        self.dropout_in = nn.Dropout(0.2)

        # Residual blocks
        self.res1 = ResidualBlock(1024, 512, dropout=0.2)
        self.res2 = ResidualBlock(512, 256, dropout=0.2)
        self.res3 = ResidualBlock(256, 128, dropout=0.2)

        # Output heads
        self.h2o_head = nn.Linear(128, 67)
        self.pl_head = nn.Linear(128, 67)

    def forward(self, x):
        x = torch.relu(self.fc_in(x))
        x = self.dropout_in(x)

        x = self.res1(x)
        x = self.res2(x)
        x = self.res3(x)

        h2o_out = self.h2o_head(x)
        pl_out = self.pl_head(x)
        return h2o_out, pl_out

model = PedroSplitMLPResidual()

# %%
class WeightedMSELoss(nn.Module):
    def __init__(self, weights):
        super(WeightedMSELoss, self).__init__()
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def forward(self, pred, target):
        diff = pred - target
        weighted_diff = diff * self.weights
        loss = torch.mean(weighted_diff ** 2)
        return loss

def smoothness_penalty(h2o_pred, alpha):
    diff = h2o_pred[:, 1:] - h2o_pred[:, :-1]
    return alpha * torch.mean(diff ** 2)

# Construct weights to emphasize lower pressures (higher in atmosphere)
n_levels = 67
pl_weights = np.linspace(1.0, 0.5, n_levels)      # Normal weights for PL
h2o_weights = np.logspace(np.log10(2.0), np.log10(0.8), n_levels)     # Emphasize high-altitude H2O, modified for higher-pressure performance

pl_weights_tensor = torch.tensor(pl_weights, dtype=torch.float32)
h2o_weights_tensor = torch.tensor(h2o_weights, dtype=torch.float32)

combined_weights = np.concatenate([pl_weights, h2o_weights])
criterion_h2o = WeightedMSELoss(weights=h2o_weights_tensor)
criterion_pl  = WeightedMSELoss(weights=pl_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-5)
# Out:
# /tmp/ipython-input-26-2966828005.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.weights = torch.tensor(weights, dtype=torch.float32)

# %%
def train(model, loader, val_loader, criterion_h2o, criterion_pl, optimizer, epochs, save_path, alpha, lambda_h2o):
    train_losses, val_losses = [], []
    val_mae_list, val_rmse_list = [], []

    best_val_loss = float('inf')
    patience = 15
    counter = 0

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        for xb, yb in loader:
            optimizer.zero_grad()

            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            loss_h2o = criterion_h2o(h2o_pred, h2o_target)
            loss_pl = criterion_pl(pl_pred, pl_target)
            smooth_loss = smoothness_penalty(h2o_pred, alpha=alpha)

            loss = lambda_h2o * loss_h2o + loss_pl + smooth_loss
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
        train_losses.append(epoch_loss / len(loader))

        # VALIDATION
        model.eval()
        val_loss_total = 0
        y_true_h2o, y_pred_h2o = [], []
        y_true_pl, y_pred_pl = [], []

        with torch.no_grad():
            for xb, yb in val_loader:
                h2o_pred, pl_pred = model(xb)
                h2o_target = yb[:, :n_levels]
                pl_target = yb[:, n_levels:]

                loss_h2o_val = criterion_h2o(h2o_pred, h2o_target)
                loss_pl_val = criterion_pl(pl_pred, pl_target)
                smooth_loss_val = smoothness_penalty(h2o_pred, alpha=alpha)

                batch_val_loss = lambda_h2o * loss_h2o_val + loss_pl_val + smooth_loss_val
                val_loss_total += batch_val_loss.item()

                y_true_h2o.append(h2o_target.cpu().numpy())
                y_pred_h2o.append(h2o_pred.cpu().numpy())

                y_true_pl.append(pl_target.cpu().numpy())
                y_pred_pl.append(pl_pred.cpu().numpy())

        val_loss = val_loss_total / len(val_loader)
        val_losses.append(val_loss)

        y_true_h2o = np.concatenate(y_true_h2o, axis=0)
        y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

        y_true_pl = np.concatenate(y_true_pl, axis=0)
        y_pred_pl = np.concatenate(y_pred_pl, axis=0)

        # METRICS
        val_mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
        val_rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

        val_mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
        val_rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

        val_mae_list.append((val_mae_h2o, val_mae_pl))
        val_rmse_list.append((val_rmse_h2o, val_rmse_pl))

        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        # EARLY STOPPING
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), save_path)
            counter = 0
            print(f"✅ Model improved and saved (val_loss = {best_val_loss:.4f})")
        else:
            counter += 1
            if counter >= patience:
                print(f"⛔ Early stopping at epoch {epoch+1}")
                break

        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_losses[-1]:.4f} | Val Loss: {val_loss:.4f} | "
              f"MAE H2O: {val_mae_h2o:.4f} | RMSE H2O: {val_rmse_h2o:.4f} | "
              f"MAE PL: {val_mae_pl:.4f} | RMSE PL: {val_rmse_pl:.4f} | LR: {current_lr:.1e}")

    model.load_state_dict(torch.load(save_path))
    return train_losses, val_losses, val_mae_list, val_rmse_list

# %%
def evaluate(model, loader):
    model.eval()
    y_true_h2o, y_pred_h2o = [], []
    y_true_pl, y_pred_pl = [], []

    with torch.no_grad():
        for xb, yb in loader:
            h2o_pred, pl_pred = model(xb)
            h2o_target = yb[:, :n_levels]
            pl_target = yb[:, n_levels:]

            y_true_h2o.append(h2o_target.cpu().numpy())
            y_pred_h2o.append(h2o_pred.cpu().numpy())

            y_true_pl.append(pl_target.cpu().numpy())
            y_pred_pl.append(pl_pred.cpu().numpy())

    y_true_h2o = np.concatenate(y_true_h2o, axis=0)
    y_pred_h2o = np.concatenate(y_pred_h2o, axis=0)

    y_true_pl = np.concatenate(y_true_pl, axis=0)
    y_pred_pl = np.concatenate(y_pred_pl, axis=0)

    return (y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl)

# %%
save_path = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model21RES.pth'

# %%
epochs = 100
alpha = 0.01  # Regularization strength for smoothness penalty
lambda_h2o=0.3
train_losses, val_losses, val_mae, val_rmse = train(
    model,
    train_loader,
    val_loader,
    criterion_h2o,
    criterion_pl,
    optimizer,
    epochs,
    save_path=save_path,
    alpha=alpha,
    lambda_h2o=lambda_h2o
)
# Out:
# ✅ Model improved and saved (val_loss = 0.6547)
# Epoch 1/100 | Train Loss: 0.8449 | Val Loss: 0.6547 | MAE H2O: 0.5102 | RMSE H2O: 0.6848 | MAE PL: 0.5056 | RMSE PL: 0.8245 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5806)
# Epoch 2/100 | Train Loss: 0.5746 | Val Loss: 0.5806 | MAE H2O: 0.4709 | RMSE H2O: 0.6534 | MAE PL: 0.3636 | RMSE PL: 0.7298 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.5134)
# Epoch 3/100 | Train Loss: 0.5490 | Val Loss: 0.5134 | MAE H2O: 0.4654 | RMSE H2O: 0.6583 | MAE PL: 0.3233 | RMSE PL: 0.6340 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4977)
# Epoch 4/100 | Train Loss: 0.5354 | Val Loss: 0.4977 | MAE H2O: 0.4386 | RMSE H2O: 0.6152 | MAE PL: 0.3077 | RMSE PL: 0.6507 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4869)
# Epoch 5/100 | Train Loss: 0.5197 | Val Loss: 0.4869 | MAE H2O: 0.4534 | RMSE H2O: 0.6267 | MAE PL: 0.2930 | RMSE PL: 0.6149 | LR: 5.0e-04
# Epoch 6/100 | Train Loss: 0.5167 | Val Loss: 0.5255 | MAE H2O: 0.4735 | RMSE H2O: 0.6418 | MAE PL: 0.3647 | RMSE PL: 0.6733 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4748)
# Epoch 7/100 | Train Loss: 0.5109 | Val Loss: 0.4748 | MAE H2O: 0.4342 | RMSE H2O: 0.6106 | MAE PL: 0.2971 | RMSE PL: 0.6195 | LR: 5.0e-04
# Epoch 8/100 | Train Loss: 0.5095 | Val Loss: 0.5454 | MAE H2O: 0.4595 | RMSE H2O: 0.6468 | MAE PL: 0.3363 | RMSE PL: 0.6862 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4594)
# Epoch 9/100 | Train Loss: 0.5037 | Val Loss: 0.4594 | MAE H2O: 0.4260 | RMSE H2O: 0.6094 | MAE PL: 0.2811 | RMSE PL: 0.5967 | LR: 5.0e-04
# Epoch 10/100 | Train Loss: 0.4973 | Val Loss: 0.4622 | MAE H2O: 0.4184 | RMSE H2O: 0.6000 | MAE PL: 0.2860 | RMSE PL: 0.6102 | LR: 5.0e-04
# Epoch 11/100 | Train Loss: 0.4898 | Val Loss: 0.4687 | MAE H2O: 0.4116 | RMSE H2O: 0.5977 | MAE PL: 0.3036 | RMSE PL: 0.6256 | LR: 5.0e-04
# Epoch 12/100 | Train Loss: 0.4876 | Val Loss: 0.4720 | MAE H2O: 0.4247 | RMSE H2O: 0.6187 | MAE PL: 0.2619 | RMSE PL: 0.5968 | LR: 5.0e-04
# Epoch 13/100 | Train Loss: 0.4963 | Val Loss: 0.4736 | MAE H2O: 0.4525 | RMSE H2O: 0.6376 | MAE PL: 0.2985 | RMSE PL: 0.5966 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4544)
# Epoch 14/100 | Train Loss: 0.4880 | Val Loss: 0.4544 | MAE H2O: 0.4129 | RMSE H2O: 0.5949 | MAE PL: 0.2803 | RMSE PL: 0.6058 | LR: 5.0e-04
# Epoch 15/100 | Train Loss: 0.4844 | Val Loss: 0.4621 | MAE H2O: 0.4263 | RMSE H2O: 0.6145 | MAE PL: 0.2762 | RMSE PL: 0.5857 | LR: 5.0e-04
# Epoch 16/100 | Train Loss: 0.4764 | Val Loss: 0.4662 | MAE H2O: 0.4443 | RMSE H2O: 0.6314 | MAE PL: 0.2449 | RMSE PL: 0.5812 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4440)
# Epoch 17/100 | Train Loss: 0.4804 | Val Loss: 0.4440 | MAE H2O: 0.4160 | RMSE H2O: 0.5950 | MAE PL: 0.2701 | RMSE PL: 0.5863 | LR: 5.0e-04
# Epoch 18/100 | Train Loss: 0.4789 | Val Loss: 0.4497 | MAE H2O: 0.4126 | RMSE H2O: 0.5922 | MAE PL: 0.2802 | RMSE PL: 0.5973 | LR: 5.0e-04
# Epoch 19/100 | Train Loss: 0.4745 | Val Loss: 0.4639 | MAE H2O: 0.4324 | RMSE H2O: 0.6219 | MAE PL: 0.2787 | RMSE PL: 0.5923 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4432)
# Epoch 20/100 | Train Loss: 0.4751 | Val Loss: 0.4432 | MAE H2O: 0.4097 | RMSE H2O: 0.5925 | MAE PL: 0.2496 | RMSE PL: 0.5850 | LR: 5.0e-04
# Epoch 21/100 | Train Loss: 0.4744 | Val Loss: 0.4548 | MAE H2O: 0.4129 | RMSE H2O: 0.5982 | MAE PL: 0.2622 | RMSE PL: 0.5922 | LR: 5.0e-04
# Epoch 22/100 | Train Loss: 0.4700 | Val Loss: 0.4454 | MAE H2O: 0.4125 | RMSE H2O: 0.6020 | MAE PL: 0.2526 | RMSE PL: 0.5799 | LR: 5.0e-04
# Epoch 23/100 | Train Loss: 0.4735 | Val Loss: 0.4735 | MAE H2O: 0.4332 | RMSE H2O: 0.6176 | MAE PL: 0.2933 | RMSE PL: 0.5909 | LR: 5.0e-04
# Epoch 24/100 | Train Loss: 0.4765 | Val Loss: 0.4577 | MAE H2O: 0.4146 | RMSE H2O: 0.5962 | MAE PL: 0.2879 | RMSE PL: 0.6135 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4405)
# Epoch 25/100 | Train Loss: 0.4654 | Val Loss: 0.4405 | MAE H2O: 0.4105 | RMSE H2O: 0.5912 | MAE PL: 0.2695 | RMSE PL: 0.5862 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4402)
# Epoch 26/100 | Train Loss: 0.4704 | Val Loss: 0.4402 | MAE H2O: 0.4062 | RMSE H2O: 0.5948 | MAE PL: 0.2535 | RMSE PL: 0.5757 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4303)
# Epoch 27/100 | Train Loss: 0.4630 | Val Loss: 0.4303 | MAE H2O: 0.4123 | RMSE H2O: 0.5915 | MAE PL: 0.2469 | RMSE PL: 0.5657 | LR: 5.0e-04
# Epoch 28/100 | Train Loss: 0.4653 | Val Loss: 0.4864 | MAE H2O: 0.4218 | RMSE H2O: 0.6204 | MAE PL: 0.2929 | RMSE PL: 0.6197 | LR: 5.0e-04
# Epoch 29/100 | Train Loss: 0.4661 | Val Loss: 0.4399 | MAE H2O: 0.4143 | RMSE H2O: 0.5973 | MAE PL: 0.2724 | RMSE PL: 0.5785 | LR: 5.0e-04
# Epoch 30/100 | Train Loss: 0.4650 | Val Loss: 0.4527 | MAE H2O: 0.4113 | RMSE H2O: 0.5970 | MAE PL: 0.2844 | RMSE PL: 0.5865 | LR: 5.0e-04
# Epoch 31/100 | Train Loss: 0.4676 | Val Loss: 0.4363 | MAE H2O: 0.4005 | RMSE H2O: 0.5900 | MAE PL: 0.2570 | RMSE PL: 0.5692 | LR: 5.0e-04
# ✅ Model improved and saved (val_loss = 0.4232)
# Epoch 32/100 | Train Loss: 0.4655 | Val Loss: 0.4232 | MAE H2O: 0.3992 | RMSE H2O: 0.5817 | MAE PL: 0.2525 | RMSE PL: 0.5614 | LR: 5.0e-04
# Epoch 33/100 | Train Loss: 0.4617 | Val Loss: 0.4355 | MAE H2O: 0.3994 | RMSE H2O: 0.5841 | MAE PL: 0.2541 | RMSE PL: 0.5808 | LR: 5.0e-04
# Epoch 34/100 | Train Loss: 0.4563 | Val Loss: 0.4389 | MAE H2O: 0.4025 | RMSE H2O: 0.5956 | MAE PL: 0.2651 | RMSE PL: 0.5775 | LR: 5.0e-04
# Epoch 35/100 | Train Loss: 0.4610 | Val Loss: 0.4306 | MAE H2O: 0.4144 | RMSE H2O: 0.5947 | MAE PL: 0.2385 | RMSE PL: 0.5621 | LR: 5.0e-04
# Epoch 36/100 | Train Loss: 0.4586 | Val Loss: 0.4249 | MAE H2O: 0.4015 | RMSE H2O: 0.5804 | MAE PL: 0.2423 | RMSE PL: 0.5697 | LR: 5.0e-04
# Epoch 37/100 | Train Loss: 0.4563 | Val Loss: 0.4298 | MAE H2O: 0.4087 | RMSE H2O: 0.5933 | MAE PL: 0.2562 | RMSE PL: 0.5721 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4126)
# Epoch 38/100 | Train Loss: 0.4444 | Val Loss: 0.4126 | MAE H2O: 0.3903 | RMSE H2O: 0.5726 | MAE PL: 0.2355 | RMSE PL: 0.5531 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4101)
# Epoch 39/100 | Train Loss: 0.4374 | Val Loss: 0.4101 | MAE H2O: 0.3879 | RMSE H2O: 0.5718 | MAE PL: 0.2352 | RMSE PL: 0.5499 | LR: 2.5e-04
# Epoch 40/100 | Train Loss: 0.4397 | Val Loss: 0.4210 | MAE H2O: 0.3938 | RMSE H2O: 0.5830 | MAE PL: 0.2328 | RMSE PL: 0.5603 | LR: 2.5e-04
# Epoch 41/100 | Train Loss: 0.4375 | Val Loss: 0.4303 | MAE H2O: 0.3962 | RMSE H2O: 0.5777 | MAE PL: 0.2689 | RMSE PL: 0.5812 | LR: 2.5e-04
# Epoch 42/100 | Train Loss: 0.4380 | Val Loss: 0.4203 | MAE H2O: 0.3882 | RMSE H2O: 0.5772 | MAE PL: 0.2398 | RMSE PL: 0.5679 | LR: 2.5e-04
# Epoch 43/100 | Train Loss: 0.4352 | Val Loss: 0.4152 | MAE H2O: 0.3982 | RMSE H2O: 0.5723 | MAE PL: 0.2418 | RMSE PL: 0.5628 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4070)
# Epoch 44/100 | Train Loss: 0.4346 | Val Loss: 0.4070 | MAE H2O: 0.3918 | RMSE H2O: 0.5724 | MAE PL: 0.2313 | RMSE PL: 0.5453 | LR: 2.5e-04
# Epoch 45/100 | Train Loss: 0.4354 | Val Loss: 0.4089 | MAE H2O: 0.3901 | RMSE H2O: 0.5766 | MAE PL: 0.2355 | RMSE PL: 0.5442 | LR: 2.5e-04
# Epoch 46/100 | Train Loss: 0.4386 | Val Loss: 0.4188 | MAE H2O: 0.3961 | RMSE H2O: 0.5848 | MAE PL: 0.2517 | RMSE PL: 0.5627 | LR: 2.5e-04
# Epoch 47/100 | Train Loss: 0.4336 | Val Loss: 0.4425 | MAE H2O: 0.3897 | RMSE H2O: 0.5765 | MAE PL: 0.2551 | RMSE PL: 0.6120 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.4014)
# Epoch 48/100 | Train Loss: 0.4344 | Val Loss: 0.4014 | MAE H2O: 0.3787 | RMSE H2O: 0.5670 | MAE PL: 0.2242 | RMSE PL: 0.5403 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3983)
# Epoch 49/100 | Train Loss: 0.4294 | Val Loss: 0.3983 | MAE H2O: 0.3835 | RMSE H2O: 0.5642 | MAE PL: 0.2187 | RMSE PL: 0.5393 | LR: 2.5e-04
# ✅ Model improved and saved (val_loss = 0.3981)
# Epoch 50/100 | Train Loss: 0.4306 | Val Loss: 0.3981 | MAE H2O: 0.3735 | RMSE H2O: 0.5604 | MAE PL: 0.2254 | RMSE PL: 0.5412 | LR: 2.5e-04
# Epoch 51/100 | Train Loss: 0.4324 | Val Loss: 0.4143 | MAE H2O: 0.3859 | RMSE H2O: 0.5727 | MAE PL: 0.2376 | RMSE PL: 0.5602 | LR: 2.5e-04
# Epoch 52/100 | Train Loss: 0.4307 | Val Loss: 0.4045 | MAE H2O: 0.3820 | RMSE H2O: 0.5667 | MAE PL: 0.2244 | RMSE PL: 0.5462 | LR: 2.5e-04
# Epoch 53/100 | Train Loss: 0.4293 | Val Loss: 0.4009 | MAE H2O: 0.3794 | RMSE H2O: 0.5636 | MAE PL: 0.2213 | RMSE PL: 0.5431 | LR: 2.5e-04
# Epoch 54/100 | Train Loss: 0.4297 | Val Loss: 0.4032 | MAE H2O: 0.3882 | RMSE H2O: 0.5677 | MAE PL: 0.2308 | RMSE PL: 0.5438 | LR: 2.5e-04
# Epoch 55/100 | Train Loss: 0.4247 | Val Loss: 0.4084 | MAE H2O: 0.3910 | RMSE H2O: 0.5690 | MAE PL: 0.2300 | RMSE PL: 0.5516 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3976)
# Epoch 56/100 | Train Loss: 0.4193 | Val Loss: 0.3976 | MAE H2O: 0.3814 | RMSE H2O: 0.5655 | MAE PL: 0.2148 | RMSE PL: 0.5363 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3970)
# Epoch 57/100 | Train Loss: 0.4163 | Val Loss: 0.3970 | MAE H2O: 0.3743 | RMSE H2O: 0.5580 | MAE PL: 0.2239 | RMSE PL: 0.5405 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3936)
# Epoch 58/100 | Train Loss: 0.4186 | Val Loss: 0.3936 | MAE H2O: 0.3697 | RMSE H2O: 0.5532 | MAE PL: 0.2194 | RMSE PL: 0.5377 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3870)
# Epoch 59/100 | Train Loss: 0.4163 | Val Loss: 0.3870 | MAE H2O: 0.3656 | RMSE H2O: 0.5520 | MAE PL: 0.2097 | RMSE PL: 0.5290 | LR: 1.3e-04
# ✅ Model improved and saved (val_loss = 0.3837)
# Epoch 60/100 | Train Loss: 0.4128 | Val Loss: 0.3837 | MAE H2O: 0.3682 | RMSE H2O: 0.5491 | MAE PL: 0.2080 | RMSE PL: 0.5258 | LR: 1.3e-04
# Epoch 61/100 | Train Loss: 0.4108 | Val Loss: 0.3860 | MAE H2O: 0.3625 | RMSE H2O: 0.5508 | MAE PL: 0.2109 | RMSE PL: 0.5272 | LR: 1.3e-04
# Epoch 62/100 | Train Loss: 0.4116 | Val Loss: 0.3860 | MAE H2O: 0.3701 | RMSE H2O: 0.5517 | MAE PL: 0.2141 | RMSE PL: 0.5288 | LR: 1.3e-04
# Epoch 63/100 | Train Loss: 0.4120 | Val Loss: 0.3904 | MAE H2O: 0.3685 | RMSE H2O: 0.5544 | MAE PL: 0.2123 | RMSE PL: 0.5295 | LR: 1.3e-04
# Epoch 64/100 | Train Loss: 0.4110 | Val Loss: 0.3986 | MAE H2O: 0.3728 | RMSE H2O: 0.5583 | MAE PL: 0.2143 | RMSE PL: 0.5382 | LR: 1.3e-04
# Epoch 65/100 | Train Loss: 0.4088 | Val Loss: 0.3986 | MAE H2O: 0.3782 | RMSE H2O: 0.5604 | MAE PL: 0.2187 | RMSE PL: 0.5352 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3769)
# Epoch 66/100 | Train Loss: 0.4018 | Val Loss: 0.3769 | MAE H2O: 0.3603 | RMSE H2O: 0.5416 | MAE PL: 0.2046 | RMSE PL: 0.5197 | LR: 6.3e-05
# Epoch 67/100 | Train Loss: 0.3992 | Val Loss: 0.3779 | MAE H2O: 0.3612 | RMSE H2O: 0.5451 | MAE PL: 0.1977 | RMSE PL: 0.5182 | LR: 6.3e-05
# Epoch 68/100 | Train Loss: 0.4000 | Val Loss: 0.3800 | MAE H2O: 0.3662 | RMSE H2O: 0.5479 | MAE PL: 0.2033 | RMSE PL: 0.5194 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3743)
# Epoch 69/100 | Train Loss: 0.3984 | Val Loss: 0.3743 | MAE H2O: 0.3563 | RMSE H2O: 0.5400 | MAE PL: 0.2037 | RMSE PL: 0.5178 | LR: 6.3e-05
# Epoch 70/100 | Train Loss: 0.3994 | Val Loss: 0.3774 | MAE H2O: 0.3574 | RMSE H2O: 0.5418 | MAE PL: 0.1976 | RMSE PL: 0.5198 | LR: 6.3e-05
# Epoch 71/100 | Train Loss: 0.3977 | Val Loss: 0.3758 | MAE H2O: 0.3578 | RMSE H2O: 0.5403 | MAE PL: 0.1962 | RMSE PL: 0.5181 | LR: 6.3e-05
# ✅ Model improved and saved (val_loss = 0.3733)
# Epoch 72/100 | Train Loss: 0.3956 | Val Loss: 0.3733 | MAE H2O: 0.3553 | RMSE H2O: 0.5389 | MAE PL: 0.1941 | RMSE PL: 0.5153 | LR: 6.3e-05
# Epoch 73/100 | Train Loss: 0.4013 | Val Loss: 0.3806 | MAE H2O: 0.3626 | RMSE H2O: 0.5431 | MAE PL: 0.2097 | RMSE PL: 0.5281 | LR: 6.3e-05
# Epoch 74/100 | Train Loss: 0.3973 | Val Loss: 0.3737 | MAE H2O: 0.3561 | RMSE H2O: 0.5398 | MAE PL: 0.1985 | RMSE PL: 0.5161 | LR: 6.3e-05
# Epoch 75/100 | Train Loss: 0.3939 | Val Loss: 0.3743 | MAE H2O: 0.3599 | RMSE H2O: 0.5410 | MAE PL: 0.1990 | RMSE PL: 0.5165 | LR: 6.3e-05
# Epoch 76/100 | Train Loss: 0.3980 | Val Loss: 0.3750 | MAE H2O: 0.3529 | RMSE H2O: 0.5382 | MAE PL: 0.2064 | RMSE PL: 0.5220 | LR: 6.3e-05
# Epoch 77/100 | Train Loss: 0.3940 | Val Loss: 0.3808 | MAE H2O: 0.3659 | RMSE H2O: 0.5430 | MAE PL: 0.2038 | RMSE PL: 0.5242 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3700)
# Epoch 78/100 | Train Loss: 0.4110 | Val Loss: 0.3700 | MAE H2O: 0.3531 | RMSE H2O: 0.5369 | MAE PL: 0.1924 | RMSE PL: 0.5122 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3685)
# Epoch 79/100 | Train Loss: 0.3882 | Val Loss: 0.3685 | MAE H2O: 0.3531 | RMSE H2O: 0.5360 | MAE PL: 0.1941 | RMSE PL: 0.5112 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3682)
# Epoch 80/100 | Train Loss: 0.3893 | Val Loss: 0.3682 | MAE H2O: 0.3519 | RMSE H2O: 0.5351 | MAE PL: 0.1949 | RMSE PL: 0.5117 | LR: 3.1e-05
# Epoch 81/100 | Train Loss: 0.3890 | Val Loss: 0.3695 | MAE H2O: 0.3519 | RMSE H2O: 0.5359 | MAE PL: 0.1904 | RMSE PL: 0.5115 | LR: 3.1e-05
# Epoch 82/100 | Train Loss: 0.3886 | Val Loss: 0.3703 | MAE H2O: 0.3538 | RMSE H2O: 0.5361 | MAE PL: 0.1977 | RMSE PL: 0.5143 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3681)
# Epoch 83/100 | Train Loss: 0.3878 | Val Loss: 0.3681 | MAE H2O: 0.3507 | RMSE H2O: 0.5346 | MAE PL: 0.1901 | RMSE PL: 0.5110 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3667)
# Epoch 84/100 | Train Loss: 0.3857 | Val Loss: 0.3667 | MAE H2O: 0.3477 | RMSE H2O: 0.5331 | MAE PL: 0.1902 | RMSE PL: 0.5103 | LR: 3.1e-05
# Epoch 85/100 | Train Loss: 0.3871 | Val Loss: 0.3691 | MAE H2O: 0.3507 | RMSE H2O: 0.5355 | MAE PL: 0.1927 | RMSE PL: 0.5113 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3662)
# Epoch 86/100 | Train Loss: 0.3876 | Val Loss: 0.3662 | MAE H2O: 0.3496 | RMSE H2O: 0.5327 | MAE PL: 0.1893 | RMSE PL: 0.5097 | LR: 3.1e-05
# Epoch 87/100 | Train Loss: 0.3885 | Val Loss: 0.3665 | MAE H2O: 0.3486 | RMSE H2O: 0.5335 | MAE PL: 0.1922 | RMSE PL: 0.5093 | LR: 3.1e-05
# Epoch 88/100 | Train Loss: 0.3869 | Val Loss: 0.3685 | MAE H2O: 0.3497 | RMSE H2O: 0.5337 | MAE PL: 0.1922 | RMSE PL: 0.5115 | LR: 3.1e-05
# Epoch 89/100 | Train Loss: 0.3890 | Val Loss: 0.3695 | MAE H2O: 0.3520 | RMSE H2O: 0.5360 | MAE PL: 0.1961 | RMSE PL: 0.5130 | LR: 3.1e-05
# ✅ Model improved and saved (val_loss = 0.3660)
# Epoch 90/100 | Train Loss: 0.3876 | Val Loss: 0.3660 | MAE H2O: 0.3509 | RMSE H2O: 0.5339 | MAE PL: 0.1907 | RMSE PL: 0.5091 | LR: 3.1e-05
# Epoch 91/100 | Train Loss: 0.3877 | Val Loss: 0.3673 | MAE H2O: 0.3524 | RMSE H2O: 0.5346 | MAE PL: 0.1945 | RMSE PL: 0.5114 | LR: 3.1e-05
# Epoch 92/100 | Train Loss: 0.3859 | Val Loss: 0.3750 | MAE H2O: 0.3545 | RMSE H2O: 0.5358 | MAE PL: 0.2079 | RMSE PL: 0.5266 | LR: 3.1e-05
# Epoch 93/100 | Train Loss: 0.3858 | Val Loss: 0.3665 | MAE H2O: 0.3497 | RMSE H2O: 0.5325 | MAE PL: 0.1923 | RMSE PL: 0.5103 | LR: 3.1e-05
# Epoch 94/100 | Train Loss: 0.3878 | Val Loss: 0.3689 | MAE H2O: 0.3540 | RMSE H2O: 0.5357 | MAE PL: 0.1964 | RMSE PL: 0.5116 | LR: 3.1e-05
# Epoch 95/100 | Train Loss: 0.3861 | Val Loss: 0.3691 | MAE H2O: 0.3504 | RMSE H2O: 0.5364 | MAE PL: 0.1911 | RMSE PL: 0.5106 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3643)
# Epoch 96/100 | Train Loss: 0.3820 | Val Loss: 0.3643 | MAE H2O: 0.3468 | RMSE H2O: 0.5311 | MAE PL: 0.1898 | RMSE PL: 0.5087 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3636)
# Epoch 97/100 | Train Loss: 0.3826 | Val Loss: 0.3636 | MAE H2O: 0.3471 | RMSE H2O: 0.5310 | MAE PL: 0.1894 | RMSE PL: 0.5075 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3635)
# Epoch 98/100 | Train Loss: 0.3826 | Val Loss: 0.3635 | MAE H2O: 0.3469 | RMSE H2O: 0.5311 | MAE PL: 0.1902 | RMSE PL: 0.5072 | LR: 1.6e-05
# ✅ Model improved and saved (val_loss = 0.3627)
# Epoch 99/100 | Train Loss: 0.3810 | Val Loss: 0.3627 | MAE H2O: 0.3464 | RMSE H2O: 0.5298 | MAE PL: 0.1876 | RMSE PL: 0.5070 | LR: 1.6e-05
# Epoch 100/100 | Train Loss: 0.3818 | Val Loss: 0.3634 | MAE H2O: 0.3469 | RMSE H2O: 0.5309 | MAE PL: 0.1879 | RMSE PL: 0.5074 | LR: 1.6e-05

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correct unpacking from evaluate
(y_true_h2o, y_pred_h2o), (y_true_pl, y_pred_pl) = evaluate(model, test_loader)

# Concatenate outputs
y_pred_test_scaled = np.concatenate([y_pred_h2o, y_pred_pl], axis=1)
y_true_test_scaled = np.concatenate([y_true_h2o, y_true_pl], axis=1)

# Inverse transform
y_pred_test = scaler_y.inverse_transform(y_pred_test_scaled)
y_true_test = scaler_y.inverse_transform(y_true_test_scaled)

# Split again
y_pred_h2o = y_pred_test[:, :67]
y_pred_pl  = y_pred_test[:, 67:]

y_true_h2o = y_true_test[:, :67]
y_true_pl  = y_true_test[:, 67:]

# Optionally concatenate to compute overall metrics
y_true_test = np.concatenate([y_true_pl, y_true_h2o], axis=1)
y_pred_test = np.concatenate([y_pred_pl, y_pred_h2o], axis=1)

# Compute test metrics
test_mae = mean_absolute_error(y_true_test, y_pred_test)
test_rmse = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"\n✅ Test MAE:  {test_mae:.4f}")
print(f"✅ Test RMSE: {test_rmse:.4f}")

# You can also compute them separately:
mae_h2o = mean_absolute_error(y_true_h2o, y_pred_h2o)
rmse_h2o = np.sqrt(mean_squared_error(y_true_h2o, y_pred_h2o))

mae_pl = mean_absolute_error(y_true_pl, y_pred_pl)
rmse_pl = np.sqrt(mean_squared_error(y_true_pl, y_pred_pl))

print(f"\n🌊 H2O  → MAE: {mae_h2o:.4f} | RMSE: {rmse_h2o:.4f}")
print(f"📉 PL   → MAE: {mae_pl:.4f} | RMSE: {rmse_pl:.4f}")
# Out:
# ✅ Test MAE:  1.2650
# ✅ Test RMSE: 4.6099
#
# 🌊 H2O  → MAE: 0.0004 | RMSE: 0.0011
# 📉 PL   → MAE: 2.5297 | RMSE: 6.5194

# %%
output_index = 120  # index within concatenated output (0–133)

plt.figure(figsize=(10, 5))
plt.plot(y_true_test[:, output_index], label='True', alpha=0.7)
plt.plot(y_pred_test[:, output_index], label='Predicted', alpha=0.7)
plt.title(f"True vs Predicted - Output #{output_index}")
plt.xlabel("Sample index")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose a sample index
i = 120

# Extract profiles for test sample i
pl_profile_true = y_true_pl[i]
h2o_profile_true = y_true_h2o[i]

pl_profile_pred = y_pred_pl[i]
h2o_profile_pred = y_pred_h2o[i]

# Plot profile
plt.figure(figsize=(7, 6))
plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
plt.gca().invert_yaxis()
plt.xlabel("H2O content [vmr]")
plt.ylabel("Pressure Layer [mbar]")
#plt.ylim(0, 1000)
plt.title("H2O content vs Pressure Level")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
for i in range(3):
    pl_profile_true = y_true_pl[i]
    h2o_profile_true = y_true_h2o[i]
    pl_profile_pred = y_pred_pl[i]
    h2o_profile_pred = y_pred_h2o[i]

    plt.figure(figsize=(7, 6))
    plt.plot(h2o_profile_true, pl_profile_true, label="True", marker='o')
    plt.plot(h2o_profile_pred, pl_profile_pred, label="Predicted", marker='x')
    plt.gca().invert_yaxis()
    plt.xlabel("H2O content [vmr]")
    plt.ylabel("Pressure Layer [mbar]")
    #plt.ylim(0, 1000)
    plt.title(f"H2O vs PL — Test Sample #{i}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#torch.save(model.state_dict(), save_path)

# %%
save_path_final = '/content/drive/MyDrive/NICOS_NN/SOLSTICIO2_0/pedro_model21RES_final.pth'
torch.save(model.state_dict(), save_path_final)
